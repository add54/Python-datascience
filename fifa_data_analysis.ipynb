# %% [markdown]
# <a href="https://colab.research.google.com/github/add54/Python-datascience/blob/master/fifa_data_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
pd.set_option('display.max_columns', 100)

# %%
df = pd.read_csv("/content/drive/MyDrive/Fifa_analysis/fifa.csv")
df.shape
# Out:
# (286, 7)

# %%
data = pd.read_excel('/content/drive/MyDrive/Fifa_analysis/Career Mode player datasets - FIFA 15-21.xlsx')

# %%
data.head(10)
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2       9014  https://sofifa.com/player/9014/arjen-robben/15...
# 3      41236  https://sofifa.com/player/41236/zlatan-ibrahim...
# 4     167495  https://sofifa.com/player/167495/manuel-neuer/...
# 5     176580  https://sofifa.com/player/176580/luis-suarez/1...
# 6         41  https://sofifa.com/player/41/andres-iniesta-lu...
# 7     183277  https://sofifa.com/player/183277/eden-hazard/1...
# 8       7826  https://sofifa.com/player/7826/robin-van-persi...
# 9     121944  https://sofifa.com/player/121944/bastian-schwe...
#
#           short_name                            long_name  age        dob  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini   27 1987-06-24
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   29 1985-02-05
# 2          A. Robben                         Arjen Robben   30 1984-01-23
# 3     Z. Ibrahimović                   Zlatan Ibrahimović   32 1981-10-03
# 4           M. Neuer                         Manuel Neuer   28 1986-03-27
# 5          L. Suárez             Luis Alberto Suárez Díaz   27 1987-01-24
# 6            Iniesta                 Andrés Iniesta Luján   30 1984-05-11
# 7          E. Hazard                          Eden Hazard   23 1991-01-07
# 8      R. van Persie                     Robin van Persie   30 1983-08-06
# 9  B. Schweinsteiger               Bastian Schweinsteiger   29 1984-08-01
#
#    height_cm  weight_kg  nationality            club_name  \
# 0        169         67    Argentina         FC Barcelona
# 1        185         80     Portugal          Real Madrid
# 2        180         80  Netherlands    FC Bayern München
# 3        195         95       Sweden  Paris Saint-Germain
# 4        193         92      Germany    FC Bayern München
# 5        181         81      Uruguay         FC Barcelona
# 6        170         65        Spain         FC Barcelona
# 7        173         74      Belgium              Chelsea
# 8        187         71  Netherlands    Manchester United
# 9        183         79      Germany    FC Bayern München
#
#               league_name  league_rank  overall  potential  value_eur  \
# 0  Spain Primera Division          1.0       93         95  100500000
# 1  Spain Primera Division          1.0       92         92   79000000
# 2    German 1. Bundesliga          1.0       90         90   54500000
# 3          French Ligue 1          1.0       90         90   52500000
# 4    German 1. Bundesliga          1.0       90         90   63500000
# 5  Spain Primera Division          1.0       89         91   49500000
# 6  Spain Primera Division          1.0       89         89   36000000
# 7  English Premier League          1.0       88         90   40500000
# 8  English Premier League          1.0       88         88   40500000
# 9    German 1. Bundesliga          1.0       88         88   39000000
#
#    wage_eur player_positions preferred_foot  international_reputation  \
# 0    550000               CF           Left                         5
# 1    375000           LW, LM          Right                         5
# 2    275000       RM, LM, RW           Left                         5
# 3    275000               ST          Right                         5
# 4    300000               GK          Right                         5
# 5    300000           ST, CF          Right                         5
# 6    250000           CM, LW          Right                         5
# 7    210000           LM, RM          Right                         4
# 8    230000               ST           Left                         5
# 9    200000          CM, CDM          Right                         4
#
#    weak_foot  skill_moves      work_rate body_type real_face  \
# 0          3            4     Medium/Low    Normal       Yes
# 1          4            5       High/Low    Normal       Yes
# 2          2            4       High/Low    Normal       Yes
# 3          4            4     Medium/Low    Normal       Yes
# 4          4            1  Medium/Medium    Normal       Yes
# 5          4            4    High/Medium    Normal       Yes
# 6          4            4    High/Medium    Normal       Yes
# 7          4            4    High/Medium    Normal       Yes
# 8          3            4     Medium/Low    Normal       Yes
# 9          3            3      High/High    Normal       Yes
#
#    release_clause_eur                                        player_tags  \
# 0                 NaN  #Speedster, #Dribbler, #FK Specialist, #Acroba...
# 1                 NaN  #Speedster, #Dribbler, #Distance Shooter, #Acr...
# 2                 NaN  #Speedster, #Dribbler, #Distance Shooter, #Acr...
# 3                 NaN  #Poacher, #Aerial Threat, #Distance Shooter, #...
# 4                 NaN                                                NaN
# 5                 NaN                       #Acrobat, #Clinical Finisher
# 6                 NaN                              #Dribbler, #Playmaker
# 7                 NaN                    #Speedster, #Dribbler, #Acrobat
# 8                 NaN              #Distance Shooter, #Clinical Finisher
# 9                 NaN                    #Playmaker, #Engine, #Tactician
#
#   team_position  team_jersey_number loaned_from     joined  \
# 0            CF                10.0         NaN 2004-07-01
# 1            LW                 7.0         NaN 2009-07-01
# 2           SUB                10.0         NaN 2009-08-28
# 3            ST                10.0         NaN 2012-07-01
# 4            GK                 1.0         NaN 2011-07-01
# 5           RES                 9.0         NaN 2014-07-11
# 6           LCM                 8.0         NaN 2002-07-01
# 7            LM                10.0         NaN 2012-07-01
# 8            RS                20.0         NaN 2012-08-17
# 9           SUB                31.0         NaN 2002-07-01
#
#    contract_valid_until nation_position  nation_jersey_number  pace  shooting  \
# 0                2018.0              CF                  10.0  93.0      89.0
# 1                2018.0              LW                   7.0  93.0      93.0
# 2                2017.0              RS                  11.0  93.0      86.0
# 3                2016.0              ST                  10.0  76.0      91.0
# 4                2019.0              GK                   1.0   NaN       NaN
# 5                2019.0             NaN                   NaN  83.0      87.0
# 6                2018.0              LW                   6.0  75.0      72.0
# 7                2017.0              LM                  10.0  90.0      82.0
# 8                2016.0              LS                   9.0  74.0      90.0
# 9                2016.0             SUB                   7.0  61.0      81.0
#
#    passing  dribbling  defending  physic  gk_diving  gk_handling  gk_kicking  \
# 0     86.0       96.0       27.0    63.0        NaN          NaN         NaN
# 1     81.0       91.0       32.0    79.0        NaN          NaN         NaN
# 2     83.0       92.0       32.0    64.0        NaN          NaN         NaN
# 3     81.0       86.0       34.0    86.0        NaN          NaN         NaN
# 4      NaN        NaN        NaN     NaN       87.0         85.0        92.0
# 5     79.0       88.0       42.0    79.0        NaN          NaN         NaN
# 6     89.0       91.0       59.0    63.0        NaN          NaN         NaN
# 7     84.0       91.0       32.0    64.0        NaN          NaN         NaN
# 8     82.0       83.0       33.0    68.0        NaN          NaN         NaN
# 9     85.0       82.0       78.0    80.0        NaN          NaN         NaN
#
#    gk_reflexes  gk_speed  gk_positioning  \
# 0          NaN       NaN             NaN
# 1          NaN       NaN             NaN
# 2          NaN       NaN             NaN
# 3          NaN       NaN             NaN
# 4         86.0      60.0            90.0
# 5          NaN       NaN             NaN
# 6          NaN       NaN             NaN
# 7          NaN       NaN             NaN
# 8          NaN       NaN             NaN
# 9          NaN       NaN             NaN
#
#                                        player_traits  attacking_crossing  \
# 0  Finesse Shot, Speed Dribbler (AI), One Club Pl...                  84
# 1  Power Free-Kick, Flair, Long Shot Taker (AI), ...                  83
# 2  Diver, Injury Prone, Avoids Using Weaker Foot,...                  80
# 3  Power Free-Kick, Leadership, Flair, Long Shot ...                  76
# 4      GK Up for Corners, GK Long Throw, 1-on-1 Rush                  25
# 5  Diver, Beat Offside Trap, Selfish, Flair, Tech...                  77
# 6  Finesse Shot, Playmaker (AI), Technical Dribbl...                  85
# 7  Injury Free, Selfish, Finesse Shot, Flair, Pla...                  78
# 8  Injury Prone, Flair, Long Shot Taker (AI), Tec...                  81
# 9  Injury Prone, Leadership, Playmaker (AI), One ...                  81
#
#    attacking_finishing  attacking_heading_accuracy  attacking_short_passing  \
# 0                   94                          71                       89
# 1                   95                          86                       82
# 2                   85                          50                       86
# 3                   91                          76                       84
# 4                   25                          25                       42
# 5                   91                          75                       82
# 6                   73                          54                       93
# 7                   83                          57                       87
# 8                   91                          73                       85
# 9                   76                          79                       88
#
#    ...  movement_acceleration  movement_sprint_speed  movement_agility  \
# 0  ...                     96                     90                94
# 1  ...                     91                     94                93
# 2  ...                     93                     93                93
# 3  ...                     74                     77                86
# 4  ...                     58                     61                43
# 5  ...                     88                     79                86
# 6  ...                     76                     75                83
# 7  ...                     93                     87                92
# 8  ...                     73                     74                80
# 9  ...                     58                     64                74
#
#    movement_reactions  movement_balance  power_shot_power  power_jumping  \
# 0                  94                95                80             73
# 1                  90                63                94             94
# 2                  89                91                86             61
# 3                  85                41                93             72
# 4                  89                35                42             78
# 5                  91                60                84             69
# 6                  90                86                65             54
# 7                  85                90                79             59
# 8                  88                59                90             59
# 9                  90                75                86             82
#
#    power_stamina  power_strength  power_long_shots  mentality_aggression  \
# 0             77              60                88                    48
# 1             89              79                93                    63
# 2             78              65                90                    47
# 3             78              93                88                    84
# 4             44              83                25                    29
# 5             86              76                82                    78
# 6             78              59                75                    58
# 7             74              63                82                    54
# 8             72              72                86                    55
# 9             86              77                86                    80
#
#    mentality_interceptions  mentality_positioning  mentality_vision  \
# 0                       22                     92                90
# 1                       24                     91                81
# 2                       39                     89                84
# 3                       20                     86                83
# 4                       30                     25                20
# 5                       41                     88                84
# 6                       68                     87                93
# 7                       41                     84                86
# 8                       34                     90                82
# 9                       86                     82                86
#
#    mentality_penalties  mentality_composure  defending_marking  \
# 0                   76                  NaN                 25
# 1                   85                  NaN                 22
# 2                   80                  NaN                 29
# 3                   91                  NaN                 25
# 4                   37                  NaN                 25
# 5                   85                  NaN                 30
# 6                   71                  NaN                 57
# 7                   86                  NaN                 25
# 8                   86                  NaN                 23
# 9                   81                  NaN                 69
#
#    defending_standing_tackle  defending_sliding_tackle  goalkeeping_diving  \
# 0                         21                        20                   6
# 1                         31                        23                   7
# 2                         26                        26                  10
# 3                         41                        27                  13
# 4                         25                        25                  87
# 5                         45                        38                  27
# 6                         57                        56                   6
# 7                         27                        22                  11
# 8                         32                        21                   9
# 9                         80                        77                  14
#
#    goalkeeping_handling  goalkeeping_kicking  goalkeeping_positioning  \
# 0                    11                   15                       14
# 1                    11                   15                       14
# 2                     8                   11                        5
# 3                    15                   10                        9
# 4                    85                   92                       90
# 5                    25                   31                       33
# 6                    13                    6                       13
# 7                    12                    6                        8
# 8                    10                    5                        7
# 9                    14                   13                       13
#
#    goalkeeping_reflexes    ls    st    rs    lw    lf    cf    rf    rw   lam  \
# 0                     8  89+3  89+3  89+3  92+3  90+3  90+3  90+3  92+3  92+3
# 1                    11  91+1  91+1  91+1  89+3  91+1  91+1  91+1  89+3  89+3
# 2                    15  84+3  84+3  84+3  88+2  87+3  87+3  87+3  88+2  88+2
# 3                    12  87+3  87+3  87+3  84+3  86+3  86+3  86+3  84+3  86+3
# 4                    86  38+3  38+3  38+3  36+3  37+3  37+3  37+3  36+3  36+3
# 5                    37  86+3  86+3  86+3  85+3  86+3  86+3  86+3  85+3  87+3
# 6                     7  77+3  77+3  77+3  87+2  82+3  82+3  82+3  87+2  88+1
# 7                     8  81+2  81+2  81+2  86+2  84+2  84+2  84+2  86+2  87+2
# 8                     8  85+3  85+3  85+3  84+3  86+2  86+2  86+2  84+3  85+3
# 9                    11  80+2  80+2  80+2  80+2  82+2  82+2  82+2  80+2  84+2
#
#     cam   ram    lm   lcm    cm   rcm    rm   lwb   ldm   cdm   rdm   rwb  \
# 0  92+3  92+3  90+3  79+3  79+3  79+3  90+3  62+3  62+3  62+3  62+3  62+3
# 1  89+3  89+3  87+3  77+3  77+3  77+3  87+3  63+3  63+3  63+3  63+3  63+3
# 2  88+2  88+2  87+3  78+3  78+3  78+3  87+3  64+3  64+3  64+3  64+3  64+3
# 3  86+3  86+3  83+3  76+3  76+3  76+3  83+3  61+3  65+3  65+3  65+3  61+3
# 4  36+3  36+3  38+3  36+3  36+3  36+3  38+3  36+3  40+3  40+3  40+3  36+3
# 5  87+3  87+3  84+3  77+3  77+3  77+3  84+3  67+3  67+3  67+3  67+3  67+3
# 6  88+1  88+1  88+1  86+3  86+3  86+3  88+1  76+3  77+3  77+3  77+3  76+3
# 7  87+2  87+2  86+2  78+2  78+2  78+2  86+2  62+2  64+2  64+2  64+2  62+2
# 8  85+3  85+3  82+3  76+3  76+3  76+3  82+3  60+3  63+3  63+3  63+3  60+3
# 9  84+2  84+2  82+2  86+2  86+2  86+2  82+2  81+2  84+2  84+2  84+2  81+2
#
#      lb   lcb    cb   rcb    rb
# 0  54+3  45+3  45+3  45+3  54+3
# 1  57+3  52+3  52+3  52+3  57+3
# 2  55+3  46+3  46+3  46+3  55+3
# 3  56+3  55+3  55+3  55+3  56+3
# 4  36+3  38+3  38+3  38+3  36+3
# 5  62+3  57+3  57+3  57+3  62+3
# 6  70+3  63+3  63+3  63+3  70+3
# 7  54+2  46+2  46+2  46+2  54+2
# 8  54+3  48+3  48+3  48+3  54+3
# 9  81+2  79+2  79+2  79+2  81+2
#
# [10 rows x 106 columns]

# %%
data.columns
# Out:
# Index(['sofifa_id', 'player_url', 'short_name', 'long_name', 'age', 'dob',
#        'height_cm', 'weight_kg', 'nationality', 'club_name',
#        ...
#        'lwb', 'ldm', 'cdm', 'rdm', 'rwb', 'lb', 'lcb', 'cb', 'rcb', 'rb'],
#       dtype='object', length=106)

# %%
#data = data.drop(columns=['Unnamed: 0', 'weak_foot', 'real_face'])
data.dropna(how='all')
# Out:
#        sofifa_id                                         player_url  \
# 0         158023  https://sofifa.com/player/158023/lionel-messi/...
# 1          20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2           9014  https://sofifa.com/player/9014/arjen-robben/15...
# 3          41236  https://sofifa.com/player/41236/zlatan-ibrahim...
# 4         167495  https://sofifa.com/player/167495/manuel-neuer/...
# ...          ...                                                ...
# 16150     220806  https://sofifa.com/player/220806/ellis-redman/...
# 16151     225509  https://sofifa.com/player/225509/aaron-collins...
# 16152     217591  https://sofifa.com/player/217591/piotr-zemlo/1...
# 16153     222947  https://sofifa.com/player/222947/tom-davies/15...
# 16154     201197  https://sofifa.com/player/201197/paul-tisdale/...
#
#               short_name                            long_name  age        dob  \
# 0               L. Messi       Lionel Andrés Messi Cuccittini   27 1987-06-24
# 1      Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   29 1985-02-05
# 2              A. Robben                         Arjen Robben   30 1984-01-23
# 3         Z. Ibrahimović                   Zlatan Ibrahimović   32 1981-10-03
# 4               M. Neuer                         Manuel Neuer   28 1986-03-27
# ...                  ...                                  ...  ...        ...
# 16150          E. Redman                         Ellis Redman   17 1996-09-26
# 16151         A. Collins                        Aaron Collins   17 1997-06-01
# 16152           P. Żemło                          Piotr Żemło   18 1995-07-10
# 16153          T. Davies                           Tom Davies   22 1992-04-18
# 16154         P. Tisdale                         Paul Tisdale   41 1973-01-14
#
#        height_cm  weight_kg  nationality            club_name  \
# 0            169         67    Argentina         FC Barcelona
# 1            185         80     Portugal          Real Madrid
# 2            180         80  Netherlands    FC Bayern München
# 3            195         95       Sweden  Paris Saint-Germain
# 4            193         92      Germany    FC Bayern München
# ...          ...        ...          ...                  ...
# 16150        187         81        Wales       Newport County
# 16151        178         57        Wales       Newport County
# 16152        190         76       Poland         Wisła Kraków
# 16153        180         70      England       Fleetwood Town
# 16154        175         72        Malta          Exeter City
#
#                        league_name  league_rank  overall  potential  \
# 0           Spain Primera Division          1.0       93         95
# 1           Spain Primera Division          1.0       92         92
# 2             German 1. Bundesliga          1.0       90         90
# 3                   French Ligue 1          1.0       90         90
# 4             German 1. Bundesliga          1.0       90         90
# ...                            ...          ...      ...        ...
# 16150           English League Two          4.0       41         61
# 16151           English League Two          4.0       41         50
# 16152  Polish T-Mobile Ekstraklasa          1.0       40         50
# 16153           English League One          3.0       40         49
# 16154           English League Two          4.0       40         40
#
#        value_eur  wage_eur player_positions preferred_foot  \
# 0      100500000    550000               CF           Left
# 1       79000000    375000           LW, LM          Right
# 2       54500000    275000       RM, LM, RW           Left
# 3       52500000    275000               ST          Right
# 4       63500000    300000               GK          Right
# ...          ...       ...              ...            ...
# 16150      20000      2000               CB          Right
# 16151      30000      2000               ST          Right
# 16152      15000      2000           LM, LB           Left
# 16153      15000      2000               CB          Right
# 16154          0      2000          CM, CAM          Right
#
#        international_reputation  weak_foot  skill_moves      work_rate  \
# 0                             5          3            4     Medium/Low
# 1                             5          4            5       High/Low
# 2                             5          2            4       High/Low
# 3                             5          4            4     Medium/Low
# 4                             5          4            1  Medium/Medium
# ...                         ...        ...          ...            ...
# 16150                         1          2            2  Medium/Medium
# 16151                         1          3            3  Medium/Medium
# 16152                         1          3            2  Medium/Medium
# 16153                         1          2            2  Medium/Medium
# 16154                         1          3            2  Medium/Medium
#
#       body_type real_face  release_clause_eur  \
# 0        Normal       Yes                 NaN
# 1        Normal       Yes                 NaN
# 2        Normal       Yes                 NaN
# 3        Normal       Yes                 NaN
# 4        Normal       Yes                 NaN
# ...         ...       ...                 ...
# 16150    Normal        No                 NaN
# 16151      Lean        No                 NaN
# 16152    Normal        No                 NaN
# 16153    Normal        No                 NaN
# 16154      Lean        No                 NaN
#
#                                              player_tags team_position  \
# 0      #Speedster, #Dribbler, #FK Specialist, #Acroba...            CF
# 1      #Speedster, #Dribbler, #Distance Shooter, #Acr...            LW
# 2      #Speedster, #Dribbler, #Distance Shooter, #Acr...           SUB
# 3      #Poacher, #Aerial Threat, #Distance Shooter, #...            ST
# 4                                                    NaN            GK
# ...                                                  ...           ...
# 16150                                                NaN           RES
# 16151                                                NaN           RES
# 16152                                                NaN           RES
# 16153                                                NaN           RES
# 16154                                                NaN           RES
#
#        team_jersey_number loaned_from     joined  contract_valid_until  \
# 0                    10.0         NaN 2004-07-01                2018.0
# 1                     7.0         NaN 2009-07-01                2018.0
# 2                    10.0         NaN 2009-08-28                2017.0
# 3                    10.0         NaN 2012-07-01                2016.0
# 4                     1.0         NaN 2011-07-01                2019.0
# ...                   ...         ...        ...                   ...
# 16150                35.0         NaN 2013-10-22                2015.0
# 16151                39.0         NaN 2014-08-14                2015.0
# 16152                43.0         NaN 2012-07-01                2015.0
# 16153                26.0         NaN 2014-03-11                2021.0
# 16154                17.0         NaN 2006-06-26                2015.0
#
#       nation_position  nation_jersey_number  pace  shooting  passing  \
# 0                  CF                  10.0  93.0      89.0     86.0
# 1                  LW                   7.0  93.0      93.0     81.0
# 2                  RS                  11.0  93.0      86.0     83.0
# 3                  ST                  10.0  76.0      91.0     81.0
# 4                  GK                   1.0   NaN       NaN      NaN
# ...               ...                   ...   ...       ...      ...
# 16150             NaN                   NaN  66.0      25.0     29.0
# 16151             NaN                   NaN  64.0      41.0     27.0
# 16152             NaN                   NaN  58.0      27.0     35.0
# 16153             NaN                   NaN  72.0      27.0     27.0
# 16154             NaN                   NaN  38.0      36.0     42.0
#
#        dribbling  defending  physic  gk_diving  gk_handling  gk_kicking  \
# 0           96.0       27.0    63.0        NaN          NaN         NaN
# 1           91.0       32.0    79.0        NaN          NaN         NaN
# 2           92.0       32.0    64.0        NaN          NaN         NaN
# 3           86.0       34.0    86.0        NaN          NaN         NaN
# 4            NaN        NaN     NaN       87.0         85.0        92.0
# ...          ...        ...     ...        ...          ...         ...
# 16150       30.0       39.0    53.0        NaN          NaN         NaN
# 16151       35.0       27.0    41.0        NaN          NaN         NaN
# 16152       31.0       52.0    68.0        NaN          NaN         NaN
# 16153       30.0       35.0    61.0        NaN          NaN         NaN
# 16154       45.0       31.0    33.0        NaN          NaN         NaN
#
#        gk_reflexes  gk_speed  gk_positioning  \
# 0              NaN       NaN             NaN
# 1              NaN       NaN             NaN
# 2              NaN       NaN             NaN
# 3              NaN       NaN             NaN
# 4             86.0      60.0            90.0
# ...            ...       ...             ...
# 16150          NaN       NaN             NaN
# 16151          NaN       NaN             NaN
# 16152          NaN       NaN             NaN
# 16153          NaN       NaN             NaN
# 16154          NaN       NaN             NaN
#
#                                            player_traits  attacking_crossing  \
# 0      Finesse Shot, Speed Dribbler (AI), One Club Pl...                  84
# 1      Power Free-Kick, Flair, Long Shot Taker (AI), ...                  83
# 2      Diver, Injury Prone, Avoids Using Weaker Foot,...                  80
# 3      Power Free-Kick, Leadership, Flair, Long Shot ...                  76
# 4          GK Up for Corners, GK Long Throw, 1-on-1 Rush                  25
# ...                                                  ...                 ...
# 16150                                                NaN                  25
# 16151                                                NaN                  22
# 16152                                                NaN                  49
# 16153                                                NaN                  23
# 16154                       Injury Prone, Playmaker (AI)                  39
#
#        attacking_finishing  attacking_heading_accuracy  \
# 0                       94                          71
# 1                       95                          86
# 2                       85                          50
# 3                       91                          76
# 4                       25                          25
# ...                    ...                         ...
# 16150                   25                          41
# 16151                   47                          43
# 16152                   24                          57
# 16153                   25                          38
# 16154                   36                          29
#
#        attacking_short_passing  ...  movement_acceleration  \
# 0                           89  ...                     96
# 1                           82  ...                     91
# 2                           86  ...                     93
# 3                           84  ...                     74
# 4                           42  ...                     58
# ...                        ...  ...                    ...
# 16150                       36  ...                     65
# 16151                       25  ...                     60
# 16152                       40  ...                     57
# 16153                       32  ...                     71
# 16154                       43  ...                     35
#
#        movement_sprint_speed  movement_agility  movement_reactions  \
# 0                         90                94                  94
# 1                         94                93                  90
# 2                         93                93                  89
# 3                         77                86                  85
# 4                         61                43                  89
# ...                      ...               ...                 ...
# 16150                     66                52                  36
# 16151                     68                66                  39
# 16152                     58                36                  50
# 16153                     73                33                  32
# 16154                     41                37                  41
#
#        movement_balance  power_shot_power  power_jumping  power_stamina  \
# 0                    95                80             73             77
# 1                    63                94             94             89
# 2                    91                86             61             78
# 3                    41                93             72             78
# 4                    35                42             78             44
# ...                 ...               ...            ...            ...
# 16150                55                22             62             56
# 16151                68                36             51             47
# 16152                44                31             61             74
# 16153                61                39             64             70
# 16154                51                32             39             25
#
#        power_strength  power_long_shots  mentality_aggression  \
# 0                  60                88                    48
# 1                  79                93                    63
# 2                  65                90                    47
# 3                  93                88                    84
# 4                  83                25                    29
# ...               ...               ...                   ...
# 16150              52                25                    50
# 16151              42                36                    30
# 16152              75                25                    44
# 16153              63                22                    44
# 16154              37                38                    32
#
#        mentality_interceptions  mentality_positioning  mentality_vision  \
# 0                           22                     92                90
# 1                           24                     91                81
# 2                           39                     89                84
# 3                           20                     86                83
# 4                           30                     25                20
# ...                        ...                    ...               ...
# 16150                       41                     25                22
# 16151                       25                     41                39
# 16152                       47                     38                21
# 16153                       34                     27                25
# 16154                       35                     43                41
#
#        mentality_penalties  mentality_composure  defending_marking  \
# 0                       76                  NaN                 25
# 1                       85                  NaN                 22
# 2                       80                  NaN                 29
# 3                       91                  NaN                 25
# 4                       37                  NaN                 25
# ...                    ...                  ...                ...
# 16150                   31                  NaN                 38
# 16151                   47                  NaN                 25
# 16152                   31                  NaN                 54
# 16153                   21                  NaN                 36
# 16154                   55                  NaN                 27
#
#        defending_standing_tackle  defending_sliding_tackle  \
# 0                             21                        20
# 1                             31                        23
# 2                             26                        26
# 3                             41                        27
# 4                             25                        25
# ...                          ...                       ...
# 16150                         40                        35
# 16151                         25                        25
# 16152                         52                        51
# 16153                         34                        35
# 16154                         34                        29
#
#        goalkeeping_diving  goalkeeping_handling  goalkeeping_kicking  \
# 0                       6                    11                   15
# 1                       7                    11                   15
# 2                      10                     8                   11
# 3                      13                    15                   10
# 4                      87                    85                   92
# ...                   ...                   ...                  ...
# 16150                  12                     6                   15
# 16151                  13                    11                   12
# 16152                   8                    14                    7
# 16153                  15                    13                    6
# 16154                   5                     6                   14
#
#        goalkeeping_positioning  goalkeeping_reflexes    ls    st    rs    lw  \
# 0                           14                     8  89+3  89+3  89+3  92+3
# 1                           14                    11  91+1  91+1  91+1  89+3
# 2                            5                    15  84+3  84+3  84+3  88+2
# 3                            9                    12  87+3  87+3  87+3  84+3
# 4                           90                    86  38+3  38+3  38+3  36+3
# ...                        ...                   ...   ...   ...   ...   ...
# 16150                        8                     6  32+0  32+0  32+0  33+0
# 16151                       15                    11  41+0  41+0  41+0  37+0
# 16152                       10                     9  38+0  38+0  38+0  38+0
# 16153                       11                     9  35+0  35+0  35+0  33+0
# 16154                        8                    13  38+0  38+0  38+0   41+
#
#          lf    cf    rf    rw   lam   cam   ram    lm   lcm    cm   rcm    rm  \
# 0      90+3  90+3  90+3  92+3  92+3  92+3  92+3  90+3  79+3  79+3  79+3  90+3
# 1      91+1  91+1  91+1  89+3  89+3  89+3  89+3  87+3  77+3  77+3  77+3  87+3
# 2      87+3  87+3  87+3  88+2  88+2  88+2  88+2  87+3  78+3  78+3  78+3  87+3
# 3      86+3  86+3  86+3  84+3  86+3  86+3  86+3  83+3  76+3  76+3  76+3  83+3
# 4      37+3  37+3  37+3  36+3  36+3  36+3  36+3  38+3  36+3  36+3  36+3  38+3
# ...     ...   ...   ...   ...   ...   ...   ...   ...   ...   ...   ...   ...
# 16150  30+0  30+0  30+0  33+0  30+0  30+0  30+0  34+0  32+0  32+0  32+0  34+0
# 16151  39+0  39+0  39+0  37+0  37+0  37+0  37+0  35+0  32+0  32+0  32+0  35+0
# 16152  35+0  35+0  35+0  38+0  33+0  33+0  33+0  40+0  38+0  38+0  38+0  40+0
# 16153  33+0  33+0  33+0  33+0  31+0  31+0  31+0  34+0  31+0  31+0  31+0  34+0
# 16154  40+0  40+0  40+0   41+   41+   41+   41+   41+  40+0  40+0  40+0   41+
#
#         lwb   ldm   cdm   rdm   rwb    lb   lcb    cb   rcb    rb
# 0      62+3  62+3  62+3  62+3  62+3  54+3  45+3  45+3  45+3  54+3
# 1      63+3  63+3  63+3  63+3  63+3  57+3  52+3  52+3  52+3  57+3
# 2      64+3  64+3  64+3  64+3  64+3  55+3  46+3  46+3  46+3  55+3
# 3      61+3  65+3  65+3  65+3  61+3  56+3  55+3  55+3  55+3  56+3
# 4      36+3  40+3  40+3  40+3  36+3  36+3  38+3  38+3  38+3  36+3
# ...     ...   ...   ...   ...   ...   ...   ...   ...   ...   ...
# 16150  37+0  38+0  38+0  38+0  37+0  40+0  41+0  41+0  41+0  40+0
# 16151  31+0  30+0  30+0  30+0  31+0  32+0  31+0  31+0  31+0  32+0
# 16152  48+0  46+0  46+0  46+0  48+0   51+   53+   53+   53+   51+
# 16153  37+0  36+0  36+0  36+0  37+0  39+0  40+0  40+0  40+0  39+0
# 16154  36+0  37+0  37+0  37+0  36+0  34+0  33+0  33+0  33+0  34+0
#
# [16155 rows x 106 columns]

# %%
data.shape
# Out:
# (16155, 106)

# %%
len(data)
# Out:
# 16155

# %% [markdown]
#  data.query()
# You can filter or query using a boolean expression. I will use ‘shooting’ and ‘passing’ columns for this example. Here I am checking for which rows ‘shooting’ is bigger than ‘passing’

# %%
data.query("shooting > passing")
# Out:
#        sofifa_id                                         player_url  \
# 0         158023  https://sofifa.com/player/158023/lionel-messi/...
# 1          20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2           9014  https://sofifa.com/player/9014/arjen-robben/15...
# 3          41236  https://sofifa.com/player/41236/zlatan-ibrahim...
# 5         176580  https://sofifa.com/player/176580/luis-suarez/1...
# ...          ...                                                ...
# 16113     224502  https://sofifa.com/player/224502/billy-whiteho...
# 16116     223905   https://sofifa.com/player/223905/perry-ng/150002
# 16123     209403  https://sofifa.com/player/209403/jamie-allen/1...
# 16143     220549  https://sofifa.com/player/220549/liam-davies/1...
# 16151     225509  https://sofifa.com/player/225509/aaron-collins...
#
#               short_name                            long_name  age        dob  \
# 0               L. Messi       Lionel Andrés Messi Cuccittini   27 1987-06-24
# 1      Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   29 1985-02-05
# 2              A. Robben                         Arjen Robben   30 1984-01-23
# 3         Z. Ibrahimović                   Zlatan Ibrahimović   32 1981-10-03
# 5              L. Suárez             Luis Alberto Suárez Díaz   27 1987-01-24
# ...                  ...                                  ...  ...        ...
# 16113      B. Whitehouse             Billy Haywood Whitehouse   18 1996-06-13
# 16116              P. Ng                             Perry Ng   18 1996-04-27
# 16123           J. Allen                          Jamie Allen   19 1995-05-25
# 16143          L. Davies                          Liam Davies   17 1996-07-02
# 16151         A. Collins                        Aaron Collins   17 1997-06-01
#
#        height_cm  weight_kg  nationality            club_name  \
# 0            169         67    Argentina         FC Barcelona
# 1            185         80     Portugal          Real Madrid
# 2            180         80  Netherlands    FC Bayern München
# 3            195         95       Sweden  Paris Saint-Germain
# 5            181         81      Uruguay         FC Barcelona
# ...          ...        ...          ...                  ...
# 16113        180         72      England     Doncaster Rovers
# 16116        180         77      England      Crewe Alexandra
# 16123        170         69      England       Fleetwood Town
# 16143        183         70      England      Tranmere Rovers
# 16151        178         57        Wales       Newport County
#
#                   league_name  league_rank  overall  potential  value_eur  \
# 0      Spain Primera Division          1.0       93         95  100500000
# 1      Spain Primera Division          1.0       92         92   79000000
# 2        German 1. Bundesliga          1.0       90         90   54500000
# 3              French Ligue 1          1.0       90         90   52500000
# 5      Spain Primera Division          1.0       89         91   49500000
# ...                       ...          ...      ...        ...        ...
# 16113      English League One          3.0       46         53      25000
# 16116      English League One          3.0       46         52      20000
# 16123      English League One          3.0       45         63      30000
# 16143      English League Two          4.0       43         56      25000
# 16151      English League Two          4.0       41         50      30000
#
#        wage_eur player_positions preferred_foot  international_reputation  \
# 0        550000               CF           Left                         5
# 1        375000           LW, LM          Right                         5
# 2        275000       RM, LM, RW           Left                         5
# 3        275000               ST          Right                         5
# 5        300000           ST, CF          Right                         5
# ...         ...              ...            ...                       ...
# 16113      2000               RM          Right                         1
# 16116      2000       CB, LB, RB          Right                         1
# 16123      2000           ST, RW          Right                         1
# 16143      2000           LM, ST           Left                         1
# 16151      2000               ST          Right                         1
#
#        weak_foot  skill_moves      work_rate body_type real_face  \
# 0              3            4     Medium/Low    Normal       Yes
# 1              4            5       High/Low    Normal       Yes
# 2              2            4       High/Low    Normal       Yes
# 3              4            4     Medium/Low    Normal       Yes
# 5              4            4    High/Medium    Normal       Yes
# ...          ...          ...            ...       ...       ...
# 16113          2            2  Medium/Medium      Lean        No
# 16116          3            2  Medium/Medium    Normal        No
# 16123          3            2  Medium/Medium      Lean        No
# 16143          3            2  Medium/Medium    Normal        No
# 16151          3            3  Medium/Medium      Lean        No
#
#        release_clause_eur                                        player_tags  \
# 0                     NaN  #Speedster, #Dribbler, #FK Specialist, #Acroba...
# 1                     NaN  #Speedster, #Dribbler, #Distance Shooter, #Acr...
# 2                     NaN  #Speedster, #Dribbler, #Distance Shooter, #Acr...
# 3                     NaN  #Poacher, #Aerial Threat, #Distance Shooter, #...
# 5                     NaN                       #Acrobat, #Clinical Finisher
# ...                   ...                                                ...
# 16113                 NaN                                                NaN
# 16116                 NaN                                                NaN
# 16123                 NaN                                                NaN
# 16143                 NaN                                                NaN
# 16151                 NaN                                                NaN
#
#       team_position  team_jersey_number loaned_from     joined  \
# 0                CF                10.0         NaN 2004-07-01
# 1                LW                 7.0         NaN 2009-07-01
# 2               SUB                10.0         NaN 2009-08-28
# 3                ST                10.0         NaN 2012-07-01
# 5               RES                 9.0         NaN 2014-07-11
# ...             ...                 ...         ...        ...
# 16113           SUB                32.0         NaN 2014-07-01
# 16116           RES                23.0         NaN 2014-07-01
# 16123           RES                21.0         NaN 2012-05-01
# 16143           SUB                21.0         NaN 2013-09-21
# 16151           RES                39.0         NaN 2014-08-14
#
#        contract_valid_until nation_position  nation_jersey_number  pace  \
# 0                    2018.0              CF                  10.0  93.0
# 1                    2018.0              LW                   7.0  93.0
# 2                    2017.0              RS                  11.0  93.0
# 3                    2016.0              ST                  10.0  76.0
# 5                    2019.0             NaN                   NaN  83.0
# ...                     ...             ...                   ...   ...
# 16113                2015.0             NaN                   NaN  60.0
# 16116                2015.0             NaN                   NaN  60.0
# 16123                2015.0             NaN                   NaN  68.0
# 16143                2015.0             NaN                   NaN  59.0
# 16151                2015.0             NaN                   NaN  64.0
#
#        shooting  passing  dribbling  defending  physic  gk_diving  \
# 0          89.0     86.0       96.0       27.0    63.0        NaN
# 1          93.0     81.0       91.0       32.0    79.0        NaN
# 2          86.0     83.0       92.0       32.0    64.0        NaN
# 3          91.0     81.0       86.0       34.0    86.0        NaN
# 5          87.0     79.0       88.0       42.0    79.0        NaN
# ...         ...      ...        ...        ...     ...        ...
# 16113      44.0     43.0       50.0       23.0    46.0        NaN
# 16116      27.0     26.0       29.0       45.0    55.0        NaN
# 16123      44.0     38.0       47.0       24.0    36.0        NaN
# 16143      48.0     35.0       46.0       28.0    48.0        NaN
# 16151      41.0     27.0       35.0       27.0    41.0        NaN
#
#        gk_handling  gk_kicking  gk_reflexes  gk_speed  gk_positioning  \
# 0              NaN         NaN          NaN       NaN             NaN
# 1              NaN         NaN          NaN       NaN             NaN
# 2              NaN         NaN          NaN       NaN             NaN
# 3              NaN         NaN          NaN       NaN             NaN
# 5              NaN         NaN          NaN       NaN             NaN
# ...            ...         ...          ...       ...             ...
# 16113          NaN         NaN          NaN       NaN             NaN
# 16116          NaN         NaN          NaN       NaN             NaN
# 16123          NaN         NaN          NaN       NaN             NaN
# 16143          NaN         NaN          NaN       NaN             NaN
# 16151          NaN         NaN          NaN       NaN             NaN
#
#                                            player_traits  attacking_crossing  \
# 0      Finesse Shot, Speed Dribbler (AI), One Club Pl...                  84
# 1      Power Free-Kick, Flair, Long Shot Taker (AI), ...                  83
# 2      Diver, Injury Prone, Avoids Using Weaker Foot,...                  80
# 3      Power Free-Kick, Leadership, Flair, Long Shot ...                  76
# 5      Diver, Beat Offside Trap, Selfish, Flair, Tech...                  77
# ...                                                  ...                 ...
# 16113                                                NaN                  46
# 16116                                                NaN                  20
# 16123                                                NaN                  48
# 16143                                                NaN                  34
# 16151                                                NaN                  22
#
#        attacking_finishing  attacking_heading_accuracy  \
# 0                       94                          71
# 1                       95                          86
# 2                       85                          50
# 3                       91                          76
# 5                       91                          75
# ...                    ...                         ...
# 16113                   44                          30
# 16116                   25                          47
# 16123                   45                          35
# 16143                   50                          50
# 16151                   47                          43
#
#        attacking_short_passing  ...  movement_acceleration  \
# 0                           89  ...                     96
# 1                           82  ...                     91
# 2                           86  ...                     93
# 3                           84  ...                     74
# 5                           82  ...                     88
# ...                        ...  ...                    ...
# 16113                       41  ...                     50
# 16116                       30  ...                     60
# 16123                       35  ...                     65
# 16143                       37  ...                     57
# 16151                       25  ...                     60
#
#        movement_sprint_speed  movement_agility  movement_reactions  \
# 0                         90                94                  94
# 1                         94                93                  90
# 2                         93                93                  89
# 3                         77                86                  85
# 5                         79                86                  91
# ...                      ...               ...                 ...
# 16113                     68                56                  32
# 16116                     60                40                  47
# 16123                     71                85                  40
# 16143                     60                58                  45
# 16151                     68                66                  39
#
#        movement_balance  power_shot_power  power_jumping  power_stamina  \
# 0                    95                80             73             77
# 1                    63                94             94             89
# 2                    91                86             61             78
# 3                    41                93             72             78
# 5                    60                84             69             86
# ...                 ...               ...            ...            ...
# 16113                69                52             49             50
# 16116                57                35             65             57
# 16123                82                59             61             34
# 16143                64                42             63             59
# 16151                68                36             51             47
#
#        power_strength  power_long_shots  mentality_aggression  \
# 0                  60                88                    48
# 1                  79                93                    63
# 2                  65                90                    47
# 3                  93                88                    84
# 5                  76                82                    78
# ...               ...               ...                   ...
# 16113              50                33                    29
# 16116              57                25                    45
# 16123              39                30                    25
# 16143              49                48                    29
# 16151              42                36                    30
#
#        mentality_interceptions  mentality_positioning  mentality_vision  \
# 0                           22                     92                90
# 1                           24                     91                81
# 2                           39                     89                84
# 3                           20                     86                83
# 5                           41                     88                84
# ...                        ...                    ...               ...
# 16113                       22                     46                43
# 16116                       47                     23                26
# 16123                       25                     50                41
# 16143                       25                     50                40
# 16151                       25                     41                39
#
#        mentality_penalties  mentality_composure  defending_marking  \
# 0                       76                  NaN                 25
# 1                       85                  NaN                 22
# 2                       80                  NaN                 29
# 3                       91                  NaN                 25
# 5                       85                  NaN                 30
# ...                    ...                  ...                ...
# 16113                   52                  NaN                 20
# 16116                   33                  NaN                 40
# 16123                   41                  NaN                 20
# 16143                   59                  NaN                 25
# 16151                   47                  NaN                 25
#
#        defending_standing_tackle  defending_sliding_tackle  \
# 0                             21                        20
# 1                             31                        23
# 2                             26                        26
# 3                             41                        27
# 5                             45                        38
# ...                          ...                       ...
# 16113                         23                        29
# 16116                         48                        49
# 16123                         23                        24
# 16143                         25                        25
# 16151                         25                        25
#
#        goalkeeping_diving  goalkeeping_handling  goalkeeping_kicking  \
# 0                       6                    11                   15
# 1                       7                    11                   15
# 2                      10                     8                   11
# 3                      13                    15                   10
# 5                      27                    25                   31
# ...                   ...                   ...                  ...
# 16113                   9                    11                   10
# 16116                   9                     5                    7
# 16123                  10                    14                    5
# 16143                   7                    14                   11
# 16151                  13                    11                   12
#
#        goalkeeping_positioning  goalkeeping_reflexes    ls    st    rs    lw  \
# 0                           14                     8  89+3  89+3  89+3  92+3
# 1                           14                    11  91+1  91+1  91+1  89+3
# 2                            5                    15  84+3  84+3  84+3  88+2
# 3                            9                    12  87+3  87+3  87+3  84+3
# 5                           33                    37  86+3  86+3  86+3  85+3
# ...                        ...                   ...   ...   ...   ...   ...
# 16113                        7                     5  44+0  44+0  44+0  47+0
# 16116                       15                     6  34+0  34+0  34+0  31+0
# 16123                       11                     8  45+0  45+0  45+0  47+0
# 16143                       12                    13  48+0  48+0  48+0  45+0
# 16151                       15                    11  41+0  41+0  41+0  37+0
#
#          lf    cf    rf    rw   lam   cam   ram    lm   lcm    cm   rcm    rm  \
# 0      90+3  90+3  90+3  92+3  92+3  92+3  92+3  90+3  79+3  79+3  79+3  90+3
# 1      91+1  91+1  91+1  89+3  89+3  89+3  89+3  87+3  77+3  77+3  77+3  87+3
# 2      87+3  87+3  87+3  88+2  88+2  88+2  88+2  87+3  78+3  78+3  78+3  87+3
# 3      86+3  86+3  86+3  84+3  86+3  86+3  86+3  83+3  76+3  76+3  76+3  83+3
# 5      86+3  86+3  86+3  85+3  87+3  87+3  87+3  84+3  77+3  77+3  77+3  84+3
# ...     ...   ...   ...   ...   ...   ...   ...   ...   ...   ...   ...   ...
# 16113  44+0  44+0  44+0  47+0  44+0  44+0  44+0  46+0  40+0  40+0  40+0  46+0
# 16116  32+0  32+0  32+0  31+0  30+0  30+0  30+0  32+0  33+0  33+0  33+0  32+0
# 16123  45+0  45+0  45+0  47+0  44+0  44+0  44+0  45+0  36+0  36+0  36+0  45+0
# 16143  47+0  47+0  47+0  45+0  45+0  45+0  45+0  43+0  40+0  40+0  40+0  43+0
# 16151  39+0  39+0  39+0  37+0  37+0  37+0  37+0  35+0  32+0  32+0  32+0  35+0
#
#         lwb   ldm   cdm   rdm   rwb    lb   lcb    cb   rcb    rb
# 0      62+3  62+3  62+3  62+3  62+3  54+3  45+3  45+3  45+3  54+3
# 1      63+3  63+3  63+3  63+3  63+3  57+3  52+3  52+3  52+3  57+3
# 2      64+3  64+3  64+3  64+3  64+3  55+3  46+3  46+3  46+3  55+3
# 3      61+3  65+3  65+3  65+3  61+3  56+3  55+3  55+3  55+3  56+3
# 5      67+3  67+3  67+3  67+3  67+3  62+3  57+3  57+3  57+3  62+3
# ...     ...   ...   ...   ...   ...   ...   ...   ...   ...   ...
# 16113  37+0  35+0  35+0  35+0  37+0  34+0  31+0  31+0  31+0  34+0
# 16116  40+0  40+0  40+0  40+0  40+0  44+0  46+0  46+0  46+0  44+0
# 16123  36+0  31+0  31+0  31+0  36+0  32+0  30+0  30+0  30+0  32+0
# 16143  37+0  36+0  36+0  36+0  37+0  36+0  34+0  34+0  34+0  36+0
# 16151  31+0  30+0  30+0  30+0  31+0  32+0  31+0  31+0  31+0  32+0
#
# [4196 rows x 106 columns]

# %% [markdown]
# df.iloc()
# This function takes as a parameter the rows and column indices and gives you the subset of the DataFrame accordingly.
# Here I am taking the first 10 rows of data and index 5th to index 10th columns:

# %%
data.iloc[:10, 5:10]
# Out:
#          dob  height_cm  weight_kg  nationality            club_name
# 0 1987-06-24        169         67    Argentina         FC Barcelona
# 1 1985-02-05        185         80     Portugal          Real Madrid
# 2 1984-01-23        180         80  Netherlands    FC Bayern München
# 3 1981-10-03        195         95       Sweden  Paris Saint-Germain
# 4 1986-03-27        193         92      Germany    FC Bayern München
# 5 1987-01-24        181         81      Uruguay         FC Barcelona
# 6 1984-05-11        170         65        Spain         FC Barcelona
# 7 1991-01-07        173         74      Belgium              Chelsea
# 8 1983-08-06        187         71  Netherlands    Manchester United
# 9 1984-08-01        183         79      Germany    FC Bayern München

# %% [markdown]
# df.loc()
# This function does almost the similar operation as .iloc() function. But here we can specify exactly which row index we want and also the name of the columns we want in our subset. Here is an example:

# %%
data.loc[[3, 10, 14, 23], ['nationality', 'weight_kg', "height_cm"]]
# Out:
#    nationality  weight_kg  height_cm
# 3       Sweden         95        195
# 10      France         72        170
# 14     Germany         66        170
# 23   Argentina         70        180

# %% [markdown]
# Look at the row indices. We only have the 3rd, 10th, 14th, and 23rd rows. On the other hand, for columns, we only have the specified columns.

# %% [markdown]
# data[‘’].dtypes
# Another very basic and widely used functions. Because it is necessary to know the data types of the variables before we dive into the analysis, visualization, or predictive modeling. I am getting the data type of the ‘height_cm’ column using .dtypes function here:*italicized text*

# %%
data.height_cm.dtypes
# Out:
# dtype('int64')

# %%
data.dtypes
# Out:
# sofifa_id      int64
# player_url    object
# short_name    object
# long_name     object
# age            int64
#                ...
# lb            object
# lcb           object
# cb            object
# rcb           object
# rb            object
# Length: 106, dtype: object

# %% [markdown]
# data.select_dtypes()
# You can select the variables or columns of a certain data type using this function. For example, I want to select the columns with data types ‘int64’ only. Here is how to do that:

# %%
data.select_dtypes(include='int64')
# Out:
#        sofifa_id  age  height_cm  weight_kg  overall  potential  value_eur  \
# 0         158023   27        169         67       93         95  100500000
# 1          20801   29        185         80       92         92   79000000
# 2           9014   30        180         80       90         90   54500000
# 3          41236   32        195         95       90         90   52500000
# 4         167495   28        193         92       90         90   63500000
# ...          ...  ...        ...        ...      ...        ...        ...
# 16150     220806   17        187         81       41         61      20000
# 16151     225509   17        178         57       41         50      30000
# 16152     217591   18        190         76       40         50      15000
# 16153     222947   22        180         70       40         49      15000
# 16154     201197   41        175         72       40         40          0
#
#        wage_eur  international_reputation  weak_foot  skill_moves  \
# 0        550000                         5          3            4
# 1        375000                         5          4            5
# 2        275000                         5          2            4
# 3        275000                         5          4            4
# 4        300000                         5          4            1
# ...         ...                       ...        ...          ...
# 16150      2000                         1          2            2
# 16151      2000                         1          3            3
# 16152      2000                         1          3            2
# 16153      2000                         1          2            2
# 16154      2000                         1          3            2
#
#        attacking_crossing  attacking_finishing  attacking_heading_accuracy  \
# 0                      84                   94                          71
# 1                      83                   95                          86
# 2                      80                   85                          50
# 3                      76                   91                          76
# 4                      25                   25                          25
# ...                   ...                  ...                         ...
# 16150                  25                   25                          41
# 16151                  22                   47                          43
# 16152                  49                   24                          57
# 16153                  23                   25                          38
# 16154                  39                   36                          29
#
#        attacking_short_passing  attacking_volleys  skill_dribbling  \
# 0                           89                 85               96
# 1                           82                 87               93
# 2                           86                 86               93
# 3                           84                 92               88
# 4                           42                 25               25
# ...                        ...                ...              ...
# 16150                       36                 25               25
# 16151                       25                 27               29
# 16152                       40                 25               27
# 16153                       32                 29               24
# 16154                       43                 27               46
#
#        skill_curve  skill_fk_accuracy  skill_long_passing  skill_ball_control  \
# 0               89                 90                  76                  96
# 1               88                 79                  72                  92
# 2               85                 83                  76                  90
# 3               80                 80                  76                  90
# 4               25                 25                  41                  31
# ...            ...                ...                 ...                 ...
# 16150           21                 25                  33                  26
# 16151           20                 22                  24                  30
# 16152           24                 21                  34                  32
# 16153           24                 27                  21                  35
# 16154           41                 53                  41                  44
#
#        movement_acceleration  movement_sprint_speed  movement_agility  \
# 0                         96                     90                94
# 1                         91                     94                93
# 2                         93                     93                93
# 3                         74                     77                86
# 4                         58                     61                43
# ...                      ...                    ...               ...
# 16150                     65                     66                52
# 16151                     60                     68                66
# 16152                     57                     58                36
# 16153                     71                     73                33
# 16154                     35                     41                37
#
#        movement_reactions  movement_balance  power_shot_power  power_jumping  \
# 0                      94                95                80             73
# 1                      90                63                94             94
# 2                      89                91                86             61
# 3                      85                41                93             72
# 4                      89                35                42             78
# ...                   ...               ...               ...            ...
# 16150                  36                55                22             62
# 16151                  39                68                36             51
# 16152                  50                44                31             61
# 16153                  32                61                39             64
# 16154                  41                51                32             39
#
#        power_stamina  power_strength  power_long_shots  mentality_aggression  \
# 0                 77              60                88                    48
# 1                 89              79                93                    63
# 2                 78              65                90                    47
# 3                 78              93                88                    84
# 4                 44              83                25                    29
# ...              ...             ...               ...                   ...
# 16150             56              52                25                    50
# 16151             47              42                36                    30
# 16152             74              75                25                    44
# 16153             70              63                22                    44
# 16154             25              37                38                    32
#
#        mentality_interceptions  mentality_positioning  mentality_vision  \
# 0                           22                     92                90
# 1                           24                     91                81
# 2                           39                     89                84
# 3                           20                     86                83
# 4                           30                     25                20
# ...                        ...                    ...               ...
# 16150                       41                     25                22
# 16151                       25                     41                39
# 16152                       47                     38                21
# 16153                       34                     27                25
# 16154                       35                     43                41
#
#        mentality_penalties  defending_marking  defending_standing_tackle  \
# 0                       76                 25                         21
# 1                       85                 22                         31
# 2                       80                 29                         26
# 3                       91                 25                         41
# 4                       37                 25                         25
# ...                    ...                ...                        ...
# 16150                   31                 38                         40
# 16151                   47                 25                         25
# 16152                   31                 54                         52
# 16153                   21                 36                         34
# 16154                   55                 27                         34
#
#        defending_sliding_tackle  goalkeeping_diving  goalkeeping_handling  \
# 0                            20                   6                    11
# 1                            23                   7                    11
# 2                            26                  10                     8
# 3                            27                  13                    15
# 4                            25                  87                    85
# ...                         ...                 ...                   ...
# 16150                        35                  12                     6
# 16151                        25                  13                    11
# 16152                        51                   8                    14
# 16153                        35                  15                    13
# 16154                        29                   5                     6
#
#        goalkeeping_kicking  goalkeeping_positioning  goalkeeping_reflexes
# 0                       15                       14                     8
# 1                       15                       14                    11
# 2                       11                        5                    15
# 3                       10                        9                    12
# 4                       92                       90                    86
# ...                    ...                      ...                   ...
# 16150                   15                        8                     6
# 16151                   12                       15                    11
# 16152                    7                       10                     9
# 16153                    6                       11                     9
# 16154                   14                        8                    13
#
# [16155 rows x 44 columns]

# %% [markdown]
# We got all the columns that have the data type ‘int64’. If we use ‘exclude’ instead of ‘include’ in the ‘select_dtypes’ function, we will get the columns that do not have the data type ‘int64’:

# %%
data.select_dtypes(exclude='int64')
# Out:
#                                               player_url         short_name  \
# 0      https://sofifa.com/player/158023/lionel-messi/...           L. Messi
# 1      https://sofifa.com/player/20801/c-ronaldo-dos-...  Cristiano Ronaldo
# 2      https://sofifa.com/player/9014/arjen-robben/15...          A. Robben
# 3      https://sofifa.com/player/41236/zlatan-ibrahim...     Z. Ibrahimović
# 4      https://sofifa.com/player/167495/manuel-neuer/...           M. Neuer
# ...                                                  ...                ...
# 16150  https://sofifa.com/player/220806/ellis-redman/...          E. Redman
# 16151  https://sofifa.com/player/225509/aaron-collins...         A. Collins
# 16152  https://sofifa.com/player/217591/piotr-zemlo/1...           P. Żemło
# 16153  https://sofifa.com/player/222947/tom-davies/15...          T. Davies
# 16154  https://sofifa.com/player/201197/paul-tisdale/...         P. Tisdale
#
#                                  long_name        dob  nationality  \
# 0           Lionel Andrés Messi Cuccittini 1987-06-24    Argentina
# 1      Cristiano Ronaldo dos Santos Aveiro 1985-02-05     Portugal
# 2                             Arjen Robben 1984-01-23  Netherlands
# 3                       Zlatan Ibrahimović 1981-10-03       Sweden
# 4                             Manuel Neuer 1986-03-27      Germany
# ...                                    ...        ...          ...
# 16150                         Ellis Redman 1996-09-26        Wales
# 16151                        Aaron Collins 1997-06-01        Wales
# 16152                          Piotr Żemło 1995-07-10       Poland
# 16153                           Tom Davies 1992-04-18      England
# 16154                         Paul Tisdale 1973-01-14        Malta
#
#                  club_name                  league_name  league_rank  \
# 0             FC Barcelona       Spain Primera Division          1.0
# 1              Real Madrid       Spain Primera Division          1.0
# 2        FC Bayern München         German 1. Bundesliga          1.0
# 3      Paris Saint-Germain               French Ligue 1          1.0
# 4        FC Bayern München         German 1. Bundesliga          1.0
# ...                    ...                          ...          ...
# 16150       Newport County           English League Two          4.0
# 16151       Newport County           English League Two          4.0
# 16152         Wisła Kraków  Polish T-Mobile Ekstraklasa          1.0
# 16153       Fleetwood Town           English League One          3.0
# 16154          Exeter City           English League Two          4.0
#
#       player_positions preferred_foot      work_rate body_type real_face  \
# 0                   CF           Left     Medium/Low    Normal       Yes
# 1               LW, LM          Right       High/Low    Normal       Yes
# 2           RM, LM, RW           Left       High/Low    Normal       Yes
# 3                   ST          Right     Medium/Low    Normal       Yes
# 4                   GK          Right  Medium/Medium    Normal       Yes
# ...                ...            ...            ...       ...       ...
# 16150               CB          Right  Medium/Medium    Normal        No
# 16151               ST          Right  Medium/Medium      Lean        No
# 16152           LM, LB           Left  Medium/Medium    Normal        No
# 16153               CB          Right  Medium/Medium    Normal        No
# 16154          CM, CAM          Right  Medium/Medium      Lean        No
#
#        release_clause_eur                                        player_tags  \
# 0                     NaN  #Speedster, #Dribbler, #FK Specialist, #Acroba...
# 1                     NaN  #Speedster, #Dribbler, #Distance Shooter, #Acr...
# 2                     NaN  #Speedster, #Dribbler, #Distance Shooter, #Acr...
# 3                     NaN  #Poacher, #Aerial Threat, #Distance Shooter, #...
# 4                     NaN                                                NaN
# ...                   ...                                                ...
# 16150                 NaN                                                NaN
# 16151                 NaN                                                NaN
# 16152                 NaN                                                NaN
# 16153                 NaN                                                NaN
# 16154                 NaN                                                NaN
#
#       team_position  team_jersey_number loaned_from     joined  \
# 0                CF                10.0         NaN 2004-07-01
# 1                LW                 7.0         NaN 2009-07-01
# 2               SUB                10.0         NaN 2009-08-28
# 3                ST                10.0         NaN 2012-07-01
# 4                GK                 1.0         NaN 2011-07-01
# ...             ...                 ...         ...        ...
# 16150           RES                35.0         NaN 2013-10-22
# 16151           RES                39.0         NaN 2014-08-14
# 16152           RES                43.0         NaN 2012-07-01
# 16153           RES                26.0         NaN 2014-03-11
# 16154           RES                17.0         NaN 2006-06-26
#
#        contract_valid_until nation_position  nation_jersey_number  pace  \
# 0                    2018.0              CF                  10.0  93.0
# 1                    2018.0              LW                   7.0  93.0
# 2                    2017.0              RS                  11.0  93.0
# 3                    2016.0              ST                  10.0  76.0
# 4                    2019.0              GK                   1.0   NaN
# ...                     ...             ...                   ...   ...
# 16150                2015.0             NaN                   NaN  66.0
# 16151                2015.0             NaN                   NaN  64.0
# 16152                2015.0             NaN                   NaN  58.0
# 16153                2021.0             NaN                   NaN  72.0
# 16154                2015.0             NaN                   NaN  38.0
#
#        shooting  passing  dribbling  defending  physic  gk_diving  \
# 0          89.0     86.0       96.0       27.0    63.0        NaN
# 1          93.0     81.0       91.0       32.0    79.0        NaN
# 2          86.0     83.0       92.0       32.0    64.0        NaN
# 3          91.0     81.0       86.0       34.0    86.0        NaN
# 4           NaN      NaN        NaN        NaN     NaN       87.0
# ...         ...      ...        ...        ...     ...        ...
# 16150      25.0     29.0       30.0       39.0    53.0        NaN
# 16151      41.0     27.0       35.0       27.0    41.0        NaN
# 16152      27.0     35.0       31.0       52.0    68.0        NaN
# 16153      27.0     27.0       30.0       35.0    61.0        NaN
# 16154      36.0     42.0       45.0       31.0    33.0        NaN
#
#        gk_handling  gk_kicking  gk_reflexes  gk_speed  gk_positioning  \
# 0              NaN         NaN          NaN       NaN             NaN
# 1              NaN         NaN          NaN       NaN             NaN
# 2              NaN         NaN          NaN       NaN             NaN
# 3              NaN         NaN          NaN       NaN             NaN
# 4             85.0        92.0         86.0      60.0            90.0
# ...            ...         ...          ...       ...             ...
# 16150          NaN         NaN          NaN       NaN             NaN
# 16151          NaN         NaN          NaN       NaN             NaN
# 16152          NaN         NaN          NaN       NaN             NaN
# 16153          NaN         NaN          NaN       NaN             NaN
# 16154          NaN         NaN          NaN       NaN             NaN
#
#                                            player_traits  mentality_composure  \
# 0      Finesse Shot, Speed Dribbler (AI), One Club Pl...                  NaN
# 1      Power Free-Kick, Flair, Long Shot Taker (AI), ...                  NaN
# 2      Diver, Injury Prone, Avoids Using Weaker Foot,...                  NaN
# 3      Power Free-Kick, Leadership, Flair, Long Shot ...                  NaN
# 4          GK Up for Corners, GK Long Throw, 1-on-1 Rush                  NaN
# ...                                                  ...                  ...
# 16150                                                NaN                  NaN
# 16151                                                NaN                  NaN
# 16152                                                NaN                  NaN
# 16153                                                NaN                  NaN
# 16154                       Injury Prone, Playmaker (AI)                  NaN
#
#          ls    st    rs    lw    lf    cf    rf    rw   lam   cam   ram    lm  \
# 0      89+3  89+3  89+3  92+3  90+3  90+3  90+3  92+3  92+3  92+3  92+3  90+3
# 1      91+1  91+1  91+1  89+3  91+1  91+1  91+1  89+3  89+3  89+3  89+3  87+3
# 2      84+3  84+3  84+3  88+2  87+3  87+3  87+3  88+2  88+2  88+2  88+2  87+3
# 3      87+3  87+3  87+3  84+3  86+3  86+3  86+3  84+3  86+3  86+3  86+3  83+3
# 4      38+3  38+3  38+3  36+3  37+3  37+3  37+3  36+3  36+3  36+3  36+3  38+3
# ...     ...   ...   ...   ...   ...   ...   ...   ...   ...   ...   ...   ...
# 16150  32+0  32+0  32+0  33+0  30+0  30+0  30+0  33+0  30+0  30+0  30+0  34+0
# 16151  41+0  41+0  41+0  37+0  39+0  39+0  39+0  37+0  37+0  37+0  37+0  35+0
# 16152  38+0  38+0  38+0  38+0  35+0  35+0  35+0  38+0  33+0  33+0  33+0  40+0
# 16153  35+0  35+0  35+0  33+0  33+0  33+0  33+0  33+0  31+0  31+0  31+0  34+0
# 16154  38+0  38+0  38+0   41+  40+0  40+0  40+0   41+   41+   41+   41+   41+
#
#         lcm    cm   rcm    rm   lwb   ldm   cdm   rdm   rwb    lb   lcb    cb  \
# 0      79+3  79+3  79+3  90+3  62+3  62+3  62+3  62+3  62+3  54+3  45+3  45+3
# 1      77+3  77+3  77+3  87+3  63+3  63+3  63+3  63+3  63+3  57+3  52+3  52+3
# 2      78+3  78+3  78+3  87+3  64+3  64+3  64+3  64+3  64+3  55+3  46+3  46+3
# 3      76+3  76+3  76+3  83+3  61+3  65+3  65+3  65+3  61+3  56+3  55+3  55+3
# 4      36+3  36+3  36+3  38+3  36+3  40+3  40+3  40+3  36+3  36+3  38+3  38+3
# ...     ...   ...   ...   ...   ...   ...   ...   ...   ...   ...   ...   ...
# 16150  32+0  32+0  32+0  34+0  37+0  38+0  38+0  38+0  37+0  40+0  41+0  41+0
# 16151  32+0  32+0  32+0  35+0  31+0  30+0  30+0  30+0  31+0  32+0  31+0  31+0
# 16152  38+0  38+0  38+0  40+0  48+0  46+0  46+0  46+0  48+0   51+   53+   53+
# 16153  31+0  31+0  31+0  34+0  37+0  36+0  36+0  36+0  37+0  39+0  40+0  40+0
# 16154  40+0  40+0  40+0   41+  36+0  37+0  37+0  37+0  36+0  34+0  33+0  33+0
#
#         rcb    rb
# 0      45+3  54+3
# 1      52+3  57+3
# 2      46+3  55+3
# 3      55+3  56+3
# 4      38+3  36+3
# ...     ...   ...
# 16150  41+0  40+0
# 16151  31+0  32+0
# 16152   53+   51+
# 16153  40+0  39+0
# 16154  33+0  34+0
#
# [16155 rows x 62 columns]

# %% [markdown]
# Here is part of the output. Look, the variables are not integers. You may think that the ‘random_col’ column is integers. But if you check its data type, you will see that it looks integers but its data type is different. Please feel free to check.

# %% [markdown]
# -------------------------------------

# %% [markdown]
# data.insert()
# As the name of the function suggests, it inserts a column in the specified position. To demonstrate that I will first create an array of random numbers that have the length of our DataFrame:

# %%
random_col = np.random.randint(100, size=len(data))
random_col
# Out:
# array([62,  1, 55, ..., 14, 44, 23])

# %% [markdown]
# I will insert this array as a column in the DataFrame df at column 3 position. Remember, the column index starts from zero

# %%
#data.insert(3, 'random_col', random_col)
random_col
# Out:
# array([62,  1, 55, ..., 14, 44, 23])

# %%
data.head(5)
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2       9014  https://sofifa.com/player/9014/arjen-robben/15...
# 3      41236  https://sofifa.com/player/41236/zlatan-ibrahim...
# 4     167495  https://sofifa.com/player/167495/manuel-neuer/...
#
#           short_name  random_col                            long_name  age  \
# 0           L. Messi          62       Lionel Andrés Messi Cuccittini   27
# 1  Cristiano Ronaldo           1  Cristiano Ronaldo dos Santos Aveiro   29
# 2          A. Robben          55                         Arjen Robben   30
# 3     Z. Ibrahimović          72                   Zlatan Ibrahimović   32
# 4           M. Neuer          96                         Manuel Neuer   28
#
#          dob  height_cm  weight_kg  nationality            club_name  \
# 0 1987-06-24        169         67    Argentina         FC Barcelona
# 1 1985-02-05        185         80     Portugal          Real Madrid
# 2 1984-01-23        180         80  Netherlands    FC Bayern München
# 3 1981-10-03        195         95       Sweden  Paris Saint-Germain
# 4 1986-03-27        193         92      Germany    FC Bayern München
#
#               league_name  league_rank  overall  potential  value_eur  \
# 0  Spain Primera Division          1.0       93         95  100500000
# 1  Spain Primera Division          1.0       92         92   79000000
# 2    German 1. Bundesliga          1.0       90         90   54500000
# 3          French Ligue 1          1.0       90         90   52500000
# 4    German 1. Bundesliga          1.0       90         90   63500000
#
#    wage_eur player_positions preferred_foot  international_reputation  \
# 0    550000               CF           Left                         5
# 1    375000           LW, LM          Right                         5
# 2    275000       RM, LM, RW           Left                         5
# 3    275000               ST          Right                         5
# 4    300000               GK          Right                         5
#
#    weak_foot  skill_moves      work_rate body_type real_face  \
# 0          3            4     Medium/Low    Normal       Yes
# 1          4            5       High/Low    Normal       Yes
# 2          2            4       High/Low    Normal       Yes
# 3          4            4     Medium/Low    Normal       Yes
# 4          4            1  Medium/Medium    Normal       Yes
#
#    release_clause_eur                                        player_tags  \
# 0                 NaN  #Speedster, #Dribbler, #FK Specialist, #Acroba...
# 1                 NaN  #Speedster, #Dribbler, #Distance Shooter, #Acr...
# 2                 NaN  #Speedster, #Dribbler, #Distance Shooter, #Acr...
# 3                 NaN  #Poacher, #Aerial Threat, #Distance Shooter, #...
# 4                 NaN                                                NaN
#
#   team_position  team_jersey_number loaned_from     joined  \
# 0            CF                10.0         NaN 2004-07-01
# 1            LW                 7.0         NaN 2009-07-01
# 2           SUB                10.0         NaN 2009-08-28
# 3            ST                10.0         NaN 2012-07-01
# 4            GK                 1.0         NaN 2011-07-01
#
#    contract_valid_until nation_position  nation_jersey_number  pace  shooting  \
# 0                2018.0              CF                  10.0  93.0      89.0
# 1                2018.0              LW                   7.0  93.0      93.0
# 2                2017.0              RS                  11.0  93.0      86.0
# 3                2016.0              ST                  10.0  76.0      91.0
# 4                2019.0              GK                   1.0   NaN       NaN
#
#    passing  dribbling  defending  physic  gk_diving  gk_handling  gk_kicking  \
# 0     86.0       96.0       27.0    63.0        NaN          NaN         NaN
# 1     81.0       91.0       32.0    79.0        NaN          NaN         NaN
# 2     83.0       92.0       32.0    64.0        NaN          NaN         NaN
# 3     81.0       86.0       34.0    86.0        NaN          NaN         NaN
# 4      NaN        NaN        NaN     NaN       87.0         85.0        92.0
#
#    gk_reflexes  gk_speed  gk_positioning  \
# 0          NaN       NaN             NaN
# 1          NaN       NaN             NaN
# 2          NaN       NaN             NaN
# 3          NaN       NaN             NaN
# 4         86.0      60.0            90.0
#
#                                        player_traits  attacking_crossing  \
# 0  Finesse Shot, Speed Dribbler (AI), One Club Pl...                  84
# 1  Power Free-Kick, Flair, Long Shot Taker (AI), ...                  83
# 2  Diver, Injury Prone, Avoids Using Weaker Foot,...                  80
# 3  Power Free-Kick, Leadership, Flair, Long Shot ...                  76
# 4      GK Up for Corners, GK Long Throw, 1-on-1 Rush                  25
#
#    attacking_finishing  attacking_heading_accuracy  ...  \
# 0                   94                          71  ...
# 1                   95                          86  ...
# 2                   85                          50  ...
# 3                   91                          76  ...
# 4                   25                          25  ...
#
#    movement_acceleration  movement_sprint_speed  movement_agility  \
# 0                     96                     90                94
# 1                     91                     94                93
# 2                     93                     93                93
# 3                     74                     77                86
# 4                     58                     61                43
#
#    movement_reactions  movement_balance  power_shot_power  power_jumping  \
# 0                  94                95                80             73
# 1                  90                63                94             94
# 2                  89                91                86             61
# 3                  85                41                93             72
# 4                  89                35                42             78
#
#    power_stamina  power_strength  power_long_shots  mentality_aggression  \
# 0             77              60                88                    48
# 1             89              79                93                    63
# 2             78              65                90                    47
# 3             78              93                88                    84
# 4             44              83                25                    29
#
#    mentality_interceptions  mentality_positioning  mentality_vision  \
# 0                       22                     92                90
# 1                       24                     91                81
# 2                       39                     89                84
# 3                       20                     86                83
# 4                       30                     25                20
#
#    mentality_penalties  mentality_composure  defending_marking  \
# 0                   76                  NaN                 25
# 1                   85                  NaN                 22
# 2                   80                  NaN                 29
# 3                   91                  NaN                 25
# 4                   37                  NaN                 25
#
#    defending_standing_tackle  defending_sliding_tackle  goalkeeping_diving  \
# 0                         21                        20                   6
# 1                         31                        23                   7
# 2                         26                        26                  10
# 3                         41                        27                  13
# 4                         25                        25                  87
#
#    goalkeeping_handling  goalkeeping_kicking  goalkeeping_positioning  \
# 0                    11                   15                       14
# 1                    11                   15                       14
# 2                     8                   11                        5
# 3                    15                   10                        9
# 4                    85                   92                       90
#
#    goalkeeping_reflexes    ls    st    rs    lw    lf    cf    rf    rw   lam  \
# 0                     8  89+3  89+3  89+3  92+3  90+3  90+3  90+3  92+3  92+3
# 1                    11  91+1  91+1  91+1  89+3  91+1  91+1  91+1  89+3  89+3
# 2                    15  84+3  84+3  84+3  88+2  87+3  87+3  87+3  88+2  88+2
# 3                    12  87+3  87+3  87+3  84+3  86+3  86+3  86+3  84+3  86+3
# 4                    86  38+3  38+3  38+3  36+3  37+3  37+3  37+3  36+3  36+3
#
#     cam   ram    lm   lcm    cm   rcm    rm   lwb   ldm   cdm   rdm   rwb  \
# 0  92+3  92+3  90+3  79+3  79+3  79+3  90+3  62+3  62+3  62+3  62+3  62+3
# 1  89+3  89+3  87+3  77+3  77+3  77+3  87+3  63+3  63+3  63+3  63+3  63+3
# 2  88+2  88+2  87+3  78+3  78+3  78+3  87+3  64+3  64+3  64+3  64+3  64+3
# 3  86+3  86+3  83+3  76+3  76+3  76+3  83+3  61+3  65+3  65+3  65+3  61+3
# 4  36+3  36+3  38+3  36+3  36+3  36+3  38+3  36+3  40+3  40+3  40+3  36+3
#
#      lb   lcb    cb   rcb    rb
# 0  54+3  45+3  45+3  45+3  54+3
# 1  57+3  52+3  52+3  52+3  57+3
# 2  55+3  46+3  46+3  46+3  55+3
# 3  56+3  55+3  55+3  55+3  56+3
# 4  36+3  38+3  38+3  38+3  36+3
#
# [5 rows x 107 columns]

# %% [markdown]
# data[‘’].cumsum()
# It provides you with the cumulative sum. Let me explain with an example. I am going to use the ‘value_eur’ and ‘wage_eur’columns for this example. Here is the code:

# %%
data[['value_eur', 'wage_eur']].cumsum()
# Out:
#          value_eur   wage_eur
# 0        100500000     550000
# 1        179500000     925000
# 2        234000000    1200000
# 3        286500000    1475000
# 4        350000000    1775000
# ...            ...        ...
# 16150  17138496000  210919000
# 16151  17138526000  210921000
# 16152  17138541000  210923000
# 16153  17138556000  210925000
# 16154  17138556000  210927000
#
# [16155 rows x 2 columns]

# %% [markdown]
# As you can see in every row it provides you with the cumulative sum of all the values of the previous rows.

# %% [markdown]
# data.sample()
# When the size of the dataset is too big, you can take a representative sample from it to perform the analysis and predictive modeling. That may save you some time. Also, too much data may ruin the visualization sometimes. we can use this function to get a certain number of data points or a certain fraction or data point. Here I am taking a sample of 200 data points from the FIFA dataset. It takes a random sample.

# %% [markdown]
# df.sample(n = 200)

# %%
data.sample(n = 200)
# Out:
#        sofifa_id                                         player_url  \
# 6244      176254  https://sofifa.com/player/176254/marcin-komoro...
# 3177      116368  https://sofifa.com/player/116368/youssouf-hadj...
# 15712     222328  https://sofifa.com/player/222328/jonas-bager/1...
# 15893     225510  https://sofifa.com/player/225510/devlin-mackay...
# 142       159065  https://sofifa.com/player/159065/ezequiel-lave...
# ...          ...                                                ...
# 15711     222319  https://sofifa.com/player/222319/jeison-angulo...
# 13344     219714  https://sofifa.com/player/219714/alessandro-de...
# 7066      155267  https://sofifa.com/player/155267/rob-friend/15...
# 15485     208556  https://sofifa.com/player/208556/josh-lelan/15...
# 7622      199638  https://sofifa.com/player/199638/daniel-proven...
#
#           short_name  random_col                      long_name  age  \
# 6244   M. Komorowski          41              Marcin Komorowski   30
# 3177        Y. Hadji          66                 Youssouf Hadji   34
# 15712       J. Bager          51                    Jonas Bager   17
# 15893      D. Mackay           6                  Devlin Mackay   17
# 142       E. Lavezzi          23          Ezequiel Iván Lavezzi   29
# ...              ...         ...                            ...  ...
# 15711      J. Ángulo          35  Jeison Andrés Angulo Trujillo   18
# 13344    A. De Leidi          84            Alessandro De Leidi   23
# 7066       R. Friend          39                     Rob Friend   33
# 15485       J. Lelan          56                     Josh Lelan   19
# 7622       Provencio          54        Daniel Provencio Azcune   26
#
#              dob  height_cm  weight_kg nationality            club_name  \
# 6244  1984-04-17        186         76      Poland         Terek Grozny
# 3177  1980-02-25        183         78     Morocco    AS Nancy Lorraine
# 15712 1996-07-18        181         78     Denmark           Randers FC
# 15893 1997-01-23        180         75    Scotland           Kilmarnock
# 142   1985-05-03        173         75   Argentina  Paris Saint-Germain
# ...          ...        ...        ...         ...                  ...
# 15711 1996-06-27        185         74    Colombia       Deportivo Cali
# 13344 1991-04-23        177         72       Italy           Cittadella
# 7066  1981-01-23        195         94      Canada            LA Galaxy
# 15485 1994-12-21        185         70     England         Swindon Town
# 7622  1987-10-07        181         78       Spain          CD Mirandés
#
#                     league_name  league_rank  overall  potential  value_eur  \
# 6244     Russian Premier League          1.0       66         66     500000
# 3177             French Ligue 2          2.0       70         70     850000
# 15712          Danish Superliga          1.0       50         62      20000
# 15893      Scottish Premiership          1.0       49         58      20000
# 142              French Ligue 1          1.0       82         82   14500000
# ...                         ...          ...      ...        ...        ...
# 15711   Colombian Liga Postobón          1.0       50         62      20000
# 13344           Italian Serie B          2.0       57         65     120000
# 7066    USA Major League Soccer          1.0       65         65     350000
# 15485        English League One          3.0       51         64      35000
# 7622   Spanish Segunda División          2.0       64         69     575000
#
#        wage_eur player_positions preferred_foot  international_reputation  \
# 6244       6000           CB, LB           Left                         1
# 3177      15000               ST          Right                         2
# 15712      2000      RB, RWB, CB          Right                         1
# 15893      2000               GK          Right                         1
# 142      140000           LW, ST          Right                         3
# ...         ...              ...            ...                       ...
# 15711      2000               LB           Left                         1
# 13344      3000               CB          Right                         1
# 7066       7000               ST          Right                         1
# 15485      2000               CB          Right                         1
# 7622       2000     CM, CAM, CDM          Right                         1
#
#        weak_foot  skill_moves      work_rate body_type real_face  \
# 6244           3            2  Medium/Medium    Normal        No
# 3177           3            3  Medium/Medium      Lean        No
# 15712          3            2  Medium/Medium    Normal        No
# 15893          2            1  Medium/Medium    Normal        No
# 142            4            4    High/Medium    Stocky       Yes
# ...          ...          ...            ...       ...       ...
# 15711          3            2  Medium/Medium      Lean        No
# 13344          2            2  Medium/Medium    Normal        No
# 7066           3            2  Medium/Medium    Stocky        No
# 15485          3            2  Medium/Medium    Normal        No
# 7622           3            2  Medium/Medium    Normal        No
#
#        release_clause_eur                player_tags team_position  \
# 6244                  NaN                        NaN           LCB
# 3177                  NaN                        NaN            LS
# 15712                 NaN                        NaN           RES
# 15893                 NaN                        NaN           RES
# 142                   NaN                   #Acrobat            LW
# ...                   ...                        ...           ...
# 15711                 NaN                        NaN           RES
# 13344                 NaN                        NaN           SUB
# 7066                  NaN  #Aerial Threat, #Strength           SUB
# 15485                 NaN                        NaN           SUB
# 7622                  NaN                        NaN           SUB
#
#        team_jersey_number   loaned_from     joined  contract_valid_until  \
# 6244                 24.0           NaN 2012-02-24                2021.0
# 3177                 15.0           NaN 2014-06-10                2015.0
# 15712                24.0           NaN 2014-01-01                2015.0
# 15893                31.0           NaN 2013-01-01                2021.0
# 142                  22.0           NaN 2012-07-01                2016.0
# ...                   ...           ...        ...                   ...
# 15711                26.0           NaN 2014-03-10                2021.0
# 13344                 4.0           NaN 2013-08-10                2021.0
# 7066                 16.0           NaN 2014-01-13                2020.0
# 15485                15.0  Derby County        NaT                2014.0
# 7622                 15.0           NaN 2014-08-28                2015.0
#
#       nation_position  nation_jersey_number  pace  shooting  passing  \
# 6244              NaN                   NaN  74.0      56.0     54.0
# 3177              NaN                   NaN  69.0      71.0     70.0
# 15712             NaN                   NaN  62.0      28.0     37.0
# 15893             NaN                   NaN   NaN       NaN      NaN
# 142               SUB                  22.0  87.0      76.0     75.0
# ...               ...                   ...   ...       ...      ...
# 15711             NaN                   NaN  70.0      24.0     33.0
# 13344             NaN                   NaN  58.0      41.0     49.0
# 7066              NaN                   NaN  49.0      63.0     52.0
# 15485             NaN                   NaN  66.0      26.0     30.0
# 7622              NaN                   NaN  62.0      57.0     61.0
#
#        dribbling  defending  physic  gk_diving  gk_handling  gk_kicking  \
# 6244        54.0       66.0    73.0        NaN          NaN         NaN
# 3177        70.0       35.0    75.0        NaN          NaN         NaN
# 15712       41.0       51.0    55.0        NaN          NaN         NaN
# 15893        NaN        NaN     NaN       55.0         48.0        47.0
# 142         85.0       32.0    73.0        NaN          NaN         NaN
# ...          ...        ...     ...        ...          ...         ...
# 15711       53.0       49.0    62.0        NaN          NaN         NaN
# 13344       37.0       59.0    57.0        NaN          NaN         NaN
# 7066        56.0       34.0    75.0        NaN          NaN         NaN
# 15485       32.0       53.0    49.0        NaN          NaN         NaN
# 7622        61.0       50.0    67.0        NaN          NaN         NaN
#
#        gk_reflexes  gk_speed  gk_positioning               player_traits  \
# 6244           NaN       NaN             NaN                         NaN
# 3177           NaN       NaN             NaN  Diver, Speed Dribbler (AI)
# 15712          NaN       NaN             NaN                         NaN
# 15893         54.0      41.0            45.0                         NaN
# 142            NaN       NaN             NaN  Diver, Speed Dribbler (AI)
# ...            ...       ...             ...                         ...
# 15711          NaN       NaN             NaN                         NaN
# 13344          NaN       NaN             NaN                         NaN
# 7066           NaN       NaN             NaN                Power Header
# 15485          NaN       NaN             NaN                         NaN
# 7622           NaN       NaN             NaN              Playmaker (AI)
#
#        attacking_crossing  attacking_finishing  attacking_heading_accuracy  \
# 6244                   57                   48                          72
# 3177                   71                   72                          76
# 15712                  44                   26                          48
# 15893                  25                   25                          25
# 142                    78                   76                          47
# ...                   ...                  ...                         ...
# 15711                  46                   21                          52
# 13344                  51                   28                          61
# 7066                   44                   60                          86
# 15485                  29                   25                          44
# 7622                   38                   55                          59
#
#        ...  movement_acceleration  movement_sprint_speed  movement_agility  \
# 6244   ...                     72                     76                60
# 3177   ...                     68                     69                75
# 15712  ...                     63                     61                44
# 15893  ...                     42                     41                37
# 142    ...                     86                     88                94
# ...    ...                    ...                    ...               ...
# 15711  ...                     73                     67                68
# 13344  ...                     60                     56                45
# 7066   ...                     48                     49                60
# 15485  ...                     62                     70                43
# 7622   ...                     65                     60                63
#
#        movement_reactions  movement_balance  power_shot_power  power_jumping  \
# 6244                   54                62                72             71
# 3177                   68                63                74             90
# 15712                  43                61                33             71
# 15893                  34                52                25             48
# 142                    80                92                81             72
# ...                   ...               ...               ...            ...
# 15711                  48                63                24             62
# 13344                  45                64                59             74
# 7066                   64                40                72             53
# 15485                  49                55                30             70
# 7622                   61                60                62             67
#
#        power_stamina  power_strength  power_long_shots  mentality_aggression  \
# 6244              77              71                65                    75
# 3177              76              78                70                    61
# 15712             59              57                23                    41
# 15893             33              50                25                    25
# 142               75              72                70                    75
# ...              ...             ...               ...                   ...
# 15711             60              67                22                    53
# 13344             60              58                57                    44
# 7066              54              90                58                    68
# 15485             59              43                21                    44
# 7622              80              59                59                    72
#
#        mentality_interceptions  mentality_positioning  mentality_vision  \
# 6244                        63                     50                46
# 3177                        32                     64                70
# 15712                       51                     29                35
# 15893                       22                     25                25
# 142                         30                     77                78
# ...                        ...                    ...               ...
# 15711                       54                     45                35
# 13344                       46                     21                33
# 7066                        32                     65                54
# 15485                       52                     21                26
# 7622                        50                     71                65
#
#        mentality_penalties  mentality_composure  defending_marking  \
# 6244                    42                  NaN                 63
# 3177                    75                  NaN                 23
# 15712                   35                  NaN                 48
# 15893                   23                  NaN                 25
# 142                     68                  NaN                 20
# ...                    ...                  ...                ...
# 15711                   38                  NaN                 43
# 13344                   33                  NaN                 61
# 7066                    64                  NaN                 25
# 15485                   32                  NaN                 50
# 7622                    41                  NaN                 39
#
#        defending_standing_tackle  defending_sliding_tackle  \
# 6244                          68                        65
# 3177                          38                        25
# 15712                         55                        54
# 15893                         25                        25
# 142                           39                        36
# ...                          ...                       ...
# 15711                         50                        50
# 13344                         64                        62
# 7066                          30                        23
# 15485                         59                        59
# 7622                          60                        48
#
#        goalkeeping_diving  goalkeeping_handling  goalkeeping_kicking  \
# 6244                   14                     6                   11
# 3177                   11                     9                   12
# 15712                  10                    12                   14
# 15893                  55                    48                   47
# 142                     5                    14                   10
# ...                   ...                   ...                  ...
# 15711                   7                    13                   13
# 13344                  12                     8                   14
# 7066                   10                    11                    6
# 15485                   8                    10                   15
# 7622                    8                    11                    8
#
#        goalkeeping_positioning  goalkeeping_reflexes    ls    st    rs    lw  \
# 6244                        15                     9  59+0  59+0  59+0  57+0
# 3177                        15                     7  70+0  70+0  70+0  70+0
# 15712                        9                     6  37+0  37+0  37+0  41+0
# 15893                       45                    54  28+0  28+0  28+0  28+0
# 142                          8                    11  76+1  76+1  76+1  81+1
# ...                        ...                   ...   ...   ...   ...   ...
# 15711                        7                    10  41+0  41+0  41+0  47+0
# 13344                       10                    13  42+0  42+0  42+0  43+0
# 7066                        11                     8  65+0  65+0  65+0  55+0
# 15485                       12                    10  34+0  34+0  34+0  35+0
# 7622                         9                     6  61+0  61+0  61+0  60+0
#
#          lf    cf    rf    rw   lam   cam   ram    lm   lcm    cm   rcm    rm  \
# 6244   58+0  58+0  58+0  57+0  55+0  55+0  55+0  57+0  57+0  57+0  57+0  57+0
# 3177   70+0  70+0  70+0  70+0  70+0  70+0  70+0  70+0  65+0  65+0  65+0  70+0
# 15712  37+0  37+0  37+0  41+0  37+0  37+0  37+0  42+0  39+0  39+0  39+0  42+0
# 15893  27+0  27+0  27+0  28+0  27+0  27+0  27+0  28+0  26+0  26+0  26+0  28+0
# 142    78+1  78+1  78+1  81+1  80+1  80+1  80+1  79+1  70+1  70+1  70+1  79+1
# ...     ...   ...   ...   ...   ...   ...   ...   ...   ...   ...   ...   ...
# 15711  40+0  40+0  40+0  47+0  41+0  41+0  41+0  47+0  41+0  41+0  41+0  47+0
# 13344  42+0  42+0  42+0  43+0  41+0  41+0  41+0  45+0  45+0  45+0  45+0  45+0
# 7066   61+0  61+0  61+0  55+0  60+0  60+0  60+0  54+0  53+0  53+0  53+0  54+0
# 15485  33+0  33+0  33+0  35+0  32+0  32+0  32+0  36+0  35+0  35+0  35+0  36+0
# 7622   63+0  63+0  63+0  60+0  65+0  65+0  65+0  62+0  64+0  64+0  64+0  62+0
#
#         lwb   ldm   cdm   rdm   rwb    lb   lcb    cb   rcb    rb
# 6244   62+0  62+0  62+0  62+0  62+0  65+0  66+0  66+0  66+0  65+0
# 3177   55+0  58+0  58+0  58+0  55+0  52+0  50+0  50+0  50+0  52+0
# 15712  48+0  45+0  45+0  45+0  48+0  50+0  50+0  50+0  50+0  50+0
# 15893  27+0  27+0  27+0  27+0  27+0  27+0  29+0  29+0  29+0  27+0
# 142    61+1  60+1  60+1  60+1  61+1  55+1  49+1  49+1  49+1  55+1
# ...     ...   ...   ...   ...   ...   ...   ...   ...   ...   ...
# 15711  50+0  45+0  45+0  45+0  50+0  50+0  51+0  51+0  51+0  50+0
# 13344  52+0  51+0  51+0  51+0  52+0  55+0  57+0  57+0  57+0  55+0
# 7066   45+0  50+0  50+0  50+0  45+0  45+0  49+0  49+0  49+0  45+0
# 15485  47+0  43+0  43+0  43+0  47+0  50+0  51+0  51+0  51+0  50+0
# 7622   57+0  61+0  61+0  61+0  57+0  57+0  56+0  56+0  56+0  57+0
#
# [200 rows x 107 columns]

# %% [markdown]
# I am taking 25% of the FIFA dataset here:

# %%
data.sample(frac = 0.25)
# Out:
#        sofifa_id                                         player_url  \
# 4829      193011  https://sofifa.com/player/193011/steve-cook/15...
# 5530      223154  https://sofifa.com/player/223154/ozan-tufan/15...
# 12396     155811  https://sofifa.com/player/155811/johannes-ertl...
# 6766      218857  https://sofifa.com/player/218857/marco-ciani/1...
# 3642      189682    https://sofifa.com/player/189682/ben-mee/150002
# ...          ...                                                ...
# 12419     169191  https://sofifa.com/player/169191/gavin-peers/1...
# 10126     214108  https://sofifa.com/player/214108/jorge-nunez/1...
# 2903      193580  https://sofifa.com/player/193580/musa-nizam/15...
# 8283      204406  https://sofifa.com/player/204406/gabriel-achil...
# 11236     210600  https://sofifa.com/player/210600/fahad-al-dosa...
#
#          short_name  random_col                        long_name  age  \
# 4829        S. Cook          21                       Steve Cook   23
# 5530       O. Tufan          57                       Ozan Tufan   19
# 12396       J. Ertl           4                    Johannes Ertl   31
# 6766       M. Ciani          66       Marco Tulio Ciani Barillas   27
# 3642         B. Mee          72                          Ben Mee   24
# ...             ...         ...                              ...  ...
# 12419      G. Peers          89                      Gavin Peers   28
# 10126      J. Núñez          67      Jorge Daniel Núñez Espínola   29
# 2903       M. Nizam          62                       Musa Nizam   23
# 8283    G. Achilier          69  Gabriel Eduardo Achilier Zurita   29
# 11236  F. Al Dosari          59                  Fahad Al Dosari   24
#
#              dob  height_cm  weight_kg          nationality  \
# 4829  1991-04-19        185         83              England
# 5530  1995-03-23        179         70               Turkey
# 12396 1982-11-13        188         80              Austria
# 6766  1987-03-07        172         73            Guatemala
# 3642  1989-09-23        180         74              England
# ...          ...        ...        ...                  ...
# 12419 1985-11-10        181         79  Republic of Ireland
# 10126 1984-09-22        175         76             Paraguay
# 2903  1990-09-29        182         74               Turkey
# 8283  1985-03-25        180         83              Ecuador
# 11236 1990-05-01        175         69         Saudi Arabia
#
#                            club_name                     league_name  \
# 4829                     Bournemouth     English League Championship
# 5530                       Bursaspor               Turkish Süper Lig
# 12396                     Portsmouth              English League Two
# 6766   Deportivo San Marcos de Arica     Chilian Campeonato Nacional
# 3642                         Burnley          English Premier League
# ...                              ...                             ...
# 12419                   Sligo Rovers  Rep. Ireland Airtricity League
# 10126                     La Equidad         Colombian Liga Postobón
# 2903                     Trabzonspor               Turkish Süper Lig
# 8283                             NaN                             NaN
# 11236                      Al Shabab    Saudi Abdul L. Jameel League
#
#        league_rank  overall  potential  value_eur  wage_eur player_positions  \
# 4829           2.0       67         74     575000      9000               CB
# 5530           1.0       66         82     425000      4000      CDM, RM, RB
# 12396          4.0       59         59      80000      2000      CDM, CM, CB
# 6766           1.0       65         69     600000      7000              CAM
# 3642           1.0       69         71     900000      9000           LB, CB
# ...            ...      ...        ...        ...       ...              ...
# 12419          1.0       59         59     120000      3000               CB
# 10126          1.0       62         62     300000      4000           RM, CM
# 2903           1.0       70         76    1300000     25000  CB, LB, CDM, CM
# 8283           NaN       64         64          0         0               RB
# 11236          1.0       60         67     250000      4000           ST, LM
#
#       preferred_foot  international_reputation  weak_foot  skill_moves  \
# 4829           Right                         1          3            2
# 5530           Right                         1          3            2
# 12396          Right                         1          3            2
# 6766           Right                         1          3            3
# 3642            Left                         1          3            2
# ...              ...                       ...        ...          ...
# 12419          Right                         1          3            2
# 10126          Right                         1          3            3
# 2903            Left                         1          2            3
# 8283           Right                         1          2            2
# 11236           Left                         1          3            3
#
#            work_rate body_type real_face  release_clause_eur player_tags  \
# 4829   Medium/Medium      Lean        No                 NaN         NaN
# 5530     High/Medium    Normal        No                 NaN         NaN
# 12396  Medium/Medium    Normal        No                 NaN         NaN
# 6766   Medium/Medium    Normal        No                 NaN         NaN
# 3642   Medium/Medium    Normal        No                 NaN         NaN
# ...              ...       ...       ...                 ...         ...
# 12419    Medium/High    Normal        No                 NaN         NaN
# 10126    High/Medium    Normal        No                 NaN         NaN
# 2903     Medium/High    Normal        No                 NaN         NaN
# 8283   Medium/Medium    Normal        No                 NaN         NaN
# 11236     Medium/Low    Normal        No                 NaN         NaN
#
#       team_position  team_jersey_number loaned_from     joined  \
# 4829            LCB                 3.0         NaN 2012-01-01
# 5530             RM                 7.0         NaN 2012-06-15
# 12396           SUB                13.0         NaN 2012-08-31
# 6766            SUB                10.0         NaN 2014-06-19
# 3642             LB                 6.0         NaN 2012-01-17
# ...             ...                 ...         ...        ...
# 12419           LCB                 4.0         NaN 2006-02-01
# 10126           SUB                16.0         NaN 2014-02-10
# 2903             LB                77.0         NaN 2014-08-06
# 8283            NaN                 NaN         NaN        NaT
# 11236           SUB                17.0         NaN 2012-01-01
#
#        contract_valid_until nation_position  nation_jersey_number  pace  \
# 4829                 2017.0             NaN                   NaN  66.0
# 5530                 2018.0             NaN                   NaN  70.0
# 12396                2016.0             NaN                   NaN  57.0
# 6766                 2015.0             NaN                   NaN  74.0
# 3642                 2017.0             NaN                   NaN  69.0
# ...                     ...             ...                   ...   ...
# 12419                2021.0             NaN                   NaN  52.0
# 10126                2020.0             NaN                   NaN  68.0
# 2903                 2018.0             NaN                   NaN  75.0
# 8283                    NaN             SUB                  21.0  60.0
# 11236                2020.0             NaN                   NaN  72.0
#
#        shooting  passing  dribbling  defending  physic  gk_diving  \
# 4829       29.0     48.0       56.0       68.0    71.0        NaN
# 5530       62.0     68.0       68.0       63.0    64.0        NaN
# 12396      33.0     46.0       46.0       62.0    74.0        NaN
# 6766       62.0     62.0       69.0       38.0    65.0        NaN
# 3642       36.0     58.0       64.0       69.0    77.0        NaN
# ...         ...      ...        ...        ...     ...        ...
# 12419      39.0     43.0       44.0       58.0    69.0        NaN
# 10126      46.0     59.0       65.0       37.0    63.0        NaN
# 2903       36.0     52.0       58.0       72.0    68.0        NaN
# 8283       25.0     41.0       46.0       70.0    75.0        NaN
# 11236      58.0     58.0       60.0       26.0    66.0        NaN
#
#        gk_handling  gk_kicking  gk_reflexes  gk_speed  gk_positioning  \
# 4829           NaN         NaN          NaN       NaN             NaN
# 5530           NaN         NaN          NaN       NaN             NaN
# 12396          NaN         NaN          NaN       NaN             NaN
# 6766           NaN         NaN          NaN       NaN             NaN
# 3642           NaN         NaN          NaN       NaN             NaN
# ...            ...         ...          ...       ...             ...
# 12419          NaN         NaN          NaN       NaN             NaN
# 10126          NaN         NaN          NaN       NaN             NaN
# 2903           NaN         NaN          NaN       NaN             NaN
# 8283           NaN         NaN          NaN       NaN             NaN
# 11236          NaN         NaN          NaN       NaN             NaN
#
#                                            player_traits  attacking_crossing  \
# 4829             Long Throw-in, Avoids Using Weaker Foot                  39
# 5530                                                 NaN                  67
# 12396                            Leadership, Team Player                  41
# 6766                      Flair, Technical Dribbler (AI)                  56
# 3642   Long Throw-in, Injury Prone, Dives Into Tackle...                  66
# ...                                                  ...                 ...
# 12419                                       Power Header                  38
# 10126                                                NaN                  60
# 2903                                                 NaN                  53
# 8283                                                 NaN                  48
# 11236                                                NaN                  52
#
#        attacking_finishing  attacking_heading_accuracy  ...  \
# 4829                    25                          66  ...
# 5530                    59                          58  ...
# 12396                   23                          68  ...
# 6766                    63                          45  ...
# 3642                    26                          71  ...
# ...                    ...                         ...  ...
# 12419                   33                          57  ...
# 10126                   46                          36  ...
# 2903                    30                          71  ...
# 8283                    25                          68  ...
# 11236                   53                          54  ...
#
#        movement_acceleration  movement_sprint_speed  movement_agility  \
# 4829                      65                     66                56
# 5530                      73                     68                69
# 12396                     61                     53                38
# 6766                      71                     76                74
# 3642                      69                     69                66
# ...                      ...                    ...               ...
# 12419                     53                     52                53
# 10126                     69                     67                69
# 2903                      76                     75                66
# 8283                      60                     60                43
# 11236                     71                     73                57
#
#        movement_reactions  movement_balance  power_shot_power  power_jumping  \
# 4829                   63                70                46             66
# 5530                   65                70                71             71
# 12396                  61                27                54             63
# 6766                   46                60                65             56
# 3642                   66                69                59             90
# ...                   ...               ...               ...            ...
# 12419                  49                54                57             64
# 10126                  51                74                58             64
# 2903                   66                71                46             71
# 8283                   64                41                25             76
# 11236                  60                71                65             62
#
#        power_stamina  power_strength  power_long_shots  mentality_aggression  \
# 4829              68              75                25                    66
# 5530              65              65                65                    59
# 12396             64              82                31                    70
# 6766              68              69                62                    52
# 3642              79              78                38                    67
# ...              ...             ...               ...                   ...
# 12419             52              81                40                    62
# 10126             69              70                31                    39
# 2903              74              58                40                    85
# 8283              68              81                25                    67
# 11236             75              63                62                    61
#
#        mentality_interceptions  mentality_positioning  mentality_vision  \
# 4829                        66                     25                34
# 5530                        63                     64                64
# 12396                       62                     51                39
# 6766                        41                     61                64
# 3642                        69                     29                49
# ...                        ...                    ...               ...
# 12419                       57                     22                40
# 10126                       42                     53                52
# 2903                        69                     31                38
# 8283                        71                     27                31
# 11236                       25                     62                58
#
#        mentality_penalties  mentality_composure  defending_marking  \
# 4829                    25                  NaN                 68
# 5530                    39                  NaN                 62
# 12396                   40                  NaN                 62
# 6766                    55                  NaN                 34
# 3642                    35                  NaN                 68
# ...                    ...                  ...                ...
# 12419                   38                  NaN                 59
# 10126                   51                  NaN                 33
# 2903                    37                  NaN                 74
# 8283                    34                  NaN                 69
# 11236                   50                  NaN                 21
#
#        defending_standing_tackle  defending_sliding_tackle  \
# 4829                          70                        66
# 5530                          66                        60
# 12396                         62                        60
# 6766                          37                        35
# 3642                          68                        69
# ...                          ...                       ...
# 12419                         59                        56
# 10126                         40                        31
# 2903                          75                        67
# 8283                          71                        66
# 11236                         25                        22
#
#        goalkeeping_diving  goalkeeping_handling  goalkeeping_kicking  \
# 4829                   13                    11                    6
# 5530                    5                    13                    7
# 12396                   8                    13                   14
# 6766                    8                    14                    5
# 3642                   14                     6                   11
# ...                   ...                   ...                  ...
# 12419                   9                     9                   15
# 10126                   9                     8                   11
# 2903                   12                    13                   10
# 8283                   14                     7                   12
# 11236                   7                     7                   13
#
#        goalkeeping_positioning  goalkeeping_reflexes    ls    st    rs    lw  \
# 4829                        13                    11  45+0  45+0  45+0  49+0
# 5530                         6                    14  64+0  64+0  64+0  68+0
# 12396                       15                    13  47+0  47+0  47+0  47+0
# 6766                         6                     6  61+0  61+0  61+0  65+0
# 3642                         9                    13  50+0  50+0  50+0  58+0
# ...                        ...                   ...   ...   ...   ...   ...
# 12419                       13                     6  43+0  43+0  43+0  42+0
# 10126                        9                    13  52+0  52+0  52+0  60+0
# 2903                         8                    10  49+0  49+0  49+0  55+0
# 8283                        14                     8  42+0  42+0  42+0  45+0
# 11236                       10                     6  60+0  60+0  60+0  60+0
#
#          lf    cf    rf    rw   lam   cam   ram    lm   lcm    cm   rcm    rm  \
# 4829   46+0  46+0  46+0  49+0  47+0  47+0  47+0  52+0  53+0  53+0  53+0  52+0
# 5530   66+0  66+0  66+0  68+0  67+0  67+0  67+0  68+0  67+0  67+0  67+0  68+0
# 12396  47+0  47+0  47+0  47+0  47+0  47+0  47+0  50+0  52+0  52+0  52+0  50+0
# 6766   63+0  63+0  63+0  65+0  65+0  65+0  65+0  65+0  61+0  61+0  61+0  65+0
# 3642   52+0  52+0  52+0  58+0  54+0  54+0  54+0  62+0  59+0  59+0  59+0  62+0
# ...     ...   ...   ...   ...   ...   ...   ...   ...   ...   ...   ...   ...
# 12419  42+0  42+0  42+0  42+0  42+0  42+0  42+0  43+0  45+0  45+0  45+0  43+0
# 10126  54+0  54+0  54+0  60+0  57+0  57+0  57+0  62+0  56+0  56+0  56+0  62+0
# 2903   50+0  50+0  50+0  55+0  51+0  51+0  51+0  57+0  56+0  56+0  56+0  57+0
# 8283   41+0  41+0  41+0  45+0  41+0  41+0  41+0  47+0  47+0  47+0  47+0  47+0
# 11236  61+0  61+0  61+0  60+0  61+0  61+0  61+0  61+0  57+0  57+0  57+0  61+0
#
#         lwb   ldm   cdm   rdm   rwb    lb   lcb    cb   rcb    rb
# 4829   62+0  62+0  62+0  62+0  62+0  64+0  67+0  67+0  67+0  64+0
# 5530   66+0  66+0  66+0  66+0  66+0  64+0  63+0  63+0  63+0  64+0
# 12396  56+0  59+0  59+0  59+0  56+0   60+   64+   64+   64+   60+
# 6766   53+0  55+0  55+0  55+0  53+0  49+0  46+0  46+0  46+0  49+0
# 3642   67+0  66+0  66+0  66+0  67+0  69+0  70+0  70+0  70+0  69+0
# ...     ...   ...   ...   ...   ...   ...   ...   ...   ...   ...
# 12419  51+0  53+0  53+0  53+0  51+0  53+0  59+0  59+0  59+0  53+0
# 10126  52+0  53+0  53+0  53+0  52+0  47+0  44+0  44+0  44+0  47+0
# 2903   66+0  64+0  64+0  64+0  66+0  69+0  70+0  70+0  70+0  69+0
# 8283   60+0  59+0  59+0  59+0  60+0  64+0   68+   68+   68+  64+0
# 11236  46+0  50+0  50+0  50+0  46+0  44+0  40+0  40+0  40+0  44+0
#
# [4039 rows x 107 columns]

# %%
data.shape
# Out:
# (16155, 107)

# %% [markdown]
# df[‘’].where()
# This function helps you query a dataset based on a boolean condition. For an example, the random_col we made before has the values ranging from 0 to 100. Here is how we make a series to see which of them are bigger than 50.

# %%
data['random_col'].where(data['random_col'] > 50)
# Out:
# 0        62.0
# 1         NaN
# 2        55.0
# 3        72.0
# 4        96.0
#          ...
# 16150     NaN
# 16151     NaN
# 16152     NaN
# 16153     NaN
# 16154     NaN
# Name: random_col, Length: 16155, dtype: float64

# %%
data['random_col'].where(data['random_col'] > 50, 0)
# Out:
# 0        62
# 1         0
# 2        55
# 3        72
# 4        96
#          ..
# 16150     0
# 16151     0
# 16152     0
# 16153     0
# 16154     0
# Name: random_col, Length: 16155, dtype: int64

# %% [markdown]
# df[‘’].unique()
# This is very useful where we have categorical variables. It is used to find out the unique values of a categorical column. Let’s see what are the unique values of the ‘skill_moves’ column in our FIFA dataset:

# %%
data.skill_moves.unique()
# Out:
# array([4, 5, 1, 3, 2])

# %% [markdown]
# df[‘’].nunique()
# Another popular function. This function lets you know how many unique values do you have in a column. As an example, if you want to see how many different nationalities are there in this dataset, you can use this simple line of code

# %%
data.nationality.nunique()
# Out:
# 149

# %%
data.nunique()
# Out:
# sofifa_id     16155
# player_url    16155
# short_name    15195
# random_col      100
# long_name     16104
#               ...
# lb              159
# lcb             174
# cb              174
# rcb             174
# rb              159
# Length: 107, dtype: int64

# %% [markdown]
# df[‘’].rank()
# This function provides you with the rank based on a certain column. In the FIFA dataset, if we want to rank the players based on the ‘value_eur’ column, here is the syntax for that:

# %%
data['rank_calc'] = data["value_eur"].rank()

# %% [markdown]
# isin()
# I am going to make a subset of the dataset that will contain only a few nationalities of players using .isin() function.

# %%
nationality = ["Argentina", "Portugal", "Sweden", "England"]
data[data.nationality.isin(nationality)]
# Out:
#        sofifa_id                                         player_url  \
# 0         158023  https://sofifa.com/player/158023/lionel-messi/...
# 1          20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 3          41236  https://sofifa.com/player/41236/zlatan-ibrahim...
# 23        183898  https://sofifa.com/player/183898/angel-di-mari...
# 26        153079  https://sofifa.com/player/153079/sergio-aguero...
# ...          ...                                                ...
# 16143     220549  https://sofifa.com/player/220549/liam-davies/1...
# 16145      11728  https://sofifa.com/player/11728/barry-richards...
# 16146     211228  https://sofifa.com/player/211228/matthew-palme...
# 16149     214725  https://sofifa.com/player/214725/sam-ramsbotto...
# 16153     222947  https://sofifa.com/player/222947/tom-davies/15...
#
#               short_name  random_col                            long_name  \
# 0               L. Messi          62       Lionel Andrés Messi Cuccittini
# 1      Cristiano Ronaldo           1  Cristiano Ronaldo dos Santos Aveiro
# 3         Z. Ibrahimović          72                   Zlatan Ibrahimović
# 23           A. Di María          38      Ángel Fabián Di María Hernández
# 26             S. Agüero           4    Sergio Leonel Agüero del Castillo
# ...                  ...         ...                                  ...
# 16143          L. Davies           2                          Liam Davies
# 16145      B. Richardson          41                     Barry Richardson
# 16146          M. Palmer          80                       Matthew Palmer
# 16149      S. Ramsbottom          14                       Sam Ramsbottom
# 16153          T. Davies          44                           Tom Davies
#
#        age        dob  height_cm  weight_kg nationality            club_name  \
# 0       27 1987-06-24        169         67   Argentina         FC Barcelona
# 1       29 1985-02-05        185         80    Portugal          Real Madrid
# 3       32 1981-10-03        195         95      Sweden  Paris Saint-Germain
# 23      26 1988-02-14        180         70   Argentina    Manchester United
# 26      26 1988-06-02        172         74   Argentina      Manchester City
# ...    ...        ...        ...        ...         ...                  ...
# 16143   17 1996-07-02        183         70     England      Tranmere Rovers
# 16145   44 1969-08-05        185         77     England    Wycombe Wanderers
# 16146   18 1995-08-01        179         79     England        Burton Albion
# 16149   18 1996-04-03        196         80     England      Tranmere Rovers
# 16153   22 1992-04-18        180         70     England       Fleetwood Town
#
#                   league_name  league_rank  overall  potential  value_eur  \
# 0      Spain Primera Division          1.0       93         95  100500000
# 1      Spain Primera Division          1.0       92         92   79000000
# 3              French Ligue 1          1.0       90         90   52500000
# 23     English Premier League          1.0       86         88   45500000
# 26     English Premier League          1.0       86         87   45500000
# ...                       ...          ...      ...        ...        ...
# 16143      English League Two          4.0       43         56      25000
# 16145      English League Two          4.0       43         43       6000
# 16146      English League Two          4.0       42         56      25000
# 16149      English League Two          4.0       42         52      20000
# 16153      English League One          3.0       40         49      15000
#
#        wage_eur player_positions preferred_foot  international_reputation  \
# 0        550000               CF           Left                         5
# 1        375000           LW, LM          Right                         5
# 3        275000               ST          Right                         5
# 23       230000      CAM, CM, RM           Left                         4
# 26       230000               ST          Right                         4
# ...         ...              ...            ...                       ...
# 16143      2000           LM, ST           Left                         1
# 16145      2000               GK          Right                         1
# 16146      2000      CM, CDM, RM          Right                         1
# 16149      2000               GK          Right                         1
# 16153      2000               CB          Right                         1
#
#        weak_foot  skill_moves      work_rate body_type real_face  \
# 0              3            4     Medium/Low    Normal       Yes
# 1              4            5       High/Low    Normal       Yes
# 3              4            4     Medium/Low    Normal       Yes
# 23             2            4      High/High      Lean       Yes
# 26             4            4       High/Low    Normal       Yes
# ...          ...          ...            ...       ...       ...
# 16143          3            2  Medium/Medium    Normal        No
# 16145          2            1  Medium/Medium    Normal        No
# 16146          2            2  Medium/Medium      Lean        No
# 16149          2            1  Medium/Medium    Normal        No
# 16153          2            2  Medium/Medium    Normal        No
#
#        release_clause_eur                                        player_tags  \
# 0                     NaN  #Speedster, #Dribbler, #FK Specialist, #Acroba...
# 1                     NaN  #Speedster, #Dribbler, #Distance Shooter, #Acr...
# 3                     NaN  #Poacher, #Aerial Threat, #Distance Shooter, #...
# 23                    NaN          #Speedster, #Dribbler, #Crosser, #Acrobat
# 26                    NaN                                #Dribbler, #Acrobat
# ...                   ...                                                ...
# 16143                 NaN                                                NaN
# 16145                 NaN                                                NaN
# 16146                 NaN                                                NaN
# 16149                 NaN                                                NaN
# 16153                 NaN                                                NaN
#
#       team_position  team_jersey_number loaned_from     joined  \
# 0                CF                10.0         NaN 2004-07-01
# 1                LW                 7.0         NaN 2009-07-01
# 3                ST                10.0         NaN 2012-07-01
# 23              LCM                 7.0         NaN 2014-08-27
# 26               ST                16.0         NaN 2011-07-28
# ...             ...                 ...         ...        ...
# 16143           SUB                21.0         NaN 2013-09-21
# 16145           SUB                13.0         NaN 2014-01-30
# 16146           SUB                23.0         NaN 2012-08-01
# 16149           RES                20.0         NaN 2013-04-01
# 16153           RES                26.0         NaN 2014-03-11
#
#        contract_valid_until nation_position  nation_jersey_number  pace  \
# 0                    2018.0              CF                  10.0  93.0
# 1                    2018.0              LW                   7.0  93.0
# 3                    2016.0              ST                  10.0  76.0
# 23                   2019.0              LM                   7.0  90.0
# 26                   2019.0             SUB                  20.0  88.0
# ...                     ...             ...                   ...   ...
# 16143                2015.0             NaN                   NaN  59.0
# 16145                2015.0             NaN                   NaN   NaN
# 16146                2015.0             NaN                   NaN  61.0
# 16149                2016.0             NaN                   NaN   NaN
# 16153                2021.0             NaN                   NaN  72.0
#
#        shooting  passing  dribbling  defending  physic  gk_diving  \
# 0          89.0     86.0       96.0       27.0    63.0        NaN
# 1          93.0     81.0       91.0       32.0    79.0        NaN
# 3          91.0     81.0       86.0       34.0    86.0        NaN
# 23         79.0     83.0       87.0       57.0    71.0        NaN
# 26         86.0     77.0       88.0       28.0    66.0        NaN
# ...         ...      ...        ...        ...     ...        ...
# 16143      48.0     35.0       46.0       28.0    48.0        NaN
# 16145       NaN      NaN        NaN        NaN     NaN       35.0
# 16146      27.0     34.0       38.0       51.0    60.0        NaN
# 16149       NaN      NaN        NaN        NaN     NaN       50.0
# 16153      27.0     27.0       30.0       35.0    61.0        NaN
#
#        gk_handling  gk_kicking  gk_reflexes  gk_speed  gk_positioning  \
# 0              NaN         NaN          NaN       NaN             NaN
# 1              NaN         NaN          NaN       NaN             NaN
# 3              NaN         NaN          NaN       NaN             NaN
# 23             NaN         NaN          NaN       NaN             NaN
# 26             NaN         NaN          NaN       NaN             NaN
# ...            ...         ...          ...       ...             ...
# 16143          NaN         NaN          NaN       NaN             NaN
# 16145         53.0        21.0         31.0      25.0            57.0
# 16146          NaN         NaN          NaN       NaN             NaN
# 16149         36.0        44.0         44.0      42.0            41.0
# 16153          NaN         NaN          NaN       NaN             NaN
#
#                                            player_traits  attacking_crossing  \
# 0      Finesse Shot, Speed Dribbler (AI), One Club Pl...                  84
# 1      Power Free-Kick, Flair, Long Shot Taker (AI), ...                  83
# 3      Power Free-Kick, Leadership, Flair, Long Shot ...                  76
# 23     Diver, Avoids Using Weaker Foot, Dives Into Ta...                  91
# 26     Injury Prone, Beat Offside Trap, Flair, Techni...                  70
# ...                                                  ...                 ...
# 16143                                                NaN                  34
# 16145                                                NaN                  25
# 16146                                                NaN                  22
# 16149                                                NaN                  25
# 16153                                                NaN                  23
#
#        attacking_finishing  attacking_heading_accuracy  ...  \
# 0                       94                          71  ...
# 1                       95                          86  ...
# 3                       91                          76  ...
# 23                      75                          53  ...
# 26                      89                          68  ...
# ...                    ...                         ...  ...
# 16143                   50                          50  ...
# 16145                   25                          25  ...
# 16146                   24                          47  ...
# 16149                   25                          25  ...
# 16153                   25                          38  ...
#
#        movement_sprint_speed  movement_agility  movement_reactions  \
# 0                         90                94                  94
# 1                         94                93                  90
# 3                         77                86                  85
# 23                        90                90                  80
# 26                        84                86                  86
# ...                      ...               ...                 ...
# 16143                     60                58                  45
# 16145                     25                38                  38
# 16146                     60                63                  47
# 16149                     40                38                  34
# 16153                     73                33                  32
#
#        movement_balance  power_shot_power  power_jumping  power_stamina  \
# 0                    95                80             73             77
# 1                    63                94             94             89
# 3                    41                93             72             78
# 23                   79                88             72             79
# 26                   90                85             76             66
# ...                 ...               ...            ...            ...
# 16143                64                42             63             59
# 16145                44                25             51             32
# 16146                64                35             65             72
# 16149                30                20             60             38
# 16153                61                39             64             70
#
#        power_strength  power_long_shots  mentality_aggression  \
# 0                  60                88                    48
# 1                  79                93                    63
# 3                  93                88                    84
# 23                 64                79                    76
# 26                 68                78                    57
# ...               ...               ...                   ...
# 16143              49                48                    29
# 16145              47                25                    43
# 16146              61                22                    41
# 16149              40                25                    21
# 16153              63                22                    44
#
#        mentality_interceptions  mentality_positioning  mentality_vision  \
# 0                           22                     92                90
# 1                           24                     91                81
# 3                           20                     86                83
# 23                          72                     84                83
# 26                          24                     87                83
# ...                        ...                    ...               ...
# 16143                       25                     50                40
# 16145                       25                     25                25
# 16146                       54                     25                25
# 16149                       25                     25                25
# 16153                       34                     27                25
#
#        mentality_penalties  mentality_composure  defending_marking  \
# 0                       76                  NaN                 25
# 1                       85                  NaN                 22
# 3                       91                  NaN                 25
# 23                      73                  NaN                 42
# 26                      86                  NaN                 25
# ...                    ...                  ...                ...
# 16143                   59                  NaN                 25
# 16145                   39                  NaN                 25
# 16146                   35                  NaN                 41
# 16149                   20                  NaN                 25
# 16153                   21                  NaN                 36
#
#        defending_standing_tackle  defending_sliding_tackle  \
# 0                             21                        20
# 1                             31                        23
# 3                             41                        27
# 23                            63                        61
# 26                            20                        25
# ...                          ...                       ...
# 16143                         25                        25
# 16145                         25                        25
# 16146                         58                        53
# 16149                         25                        25
# 16153                         34                        35
#
#        goalkeeping_diving  goalkeeping_handling  goalkeeping_kicking  \
# 0                       6                    11                   15
# 1                       7                    11                   15
# 3                      13                    15                   10
# 23                     10                     7                   11
# 26                     13                    15                    6
# ...                   ...                   ...                  ...
# 16143                   7                    14                   11
# 16145                  35                    53                   21
# 16146                   8                     9                    6
# 16149                  50                    36                   44
# 16153                  15                    13                    6
#
#        goalkeeping_positioning  goalkeeping_reflexes    ls    st    rs    lw  \
# 0                           14                     8  89+3  89+3  89+3  92+3
# 1                           14                    11  91+1  91+1  91+1  89+3
# 3                            9                    12  87+3  87+3  87+3  84+3
# 23                          12                    11  79+2  79+2  79+2  86+2
# 26                          11                    14  84+2  84+2  84+2  84+2
# ...                        ...                   ...   ...   ...   ...   ...
# 16143                       12                    13  48+0  48+0  48+0  45+0
# 16145                       57                    31  27+0  27+0  27+0  26+0
# 16146                       12                    10  36+0  36+0  36+0  37+0
# 16149                       41                    44  27+0  27+0  27+0  28+0
# 16153                       11                     9  35+0  35+0  35+0  33+0
#
#          lf    cf    rf    rw   lam   cam   ram    lm   lcm    cm   rcm    rm  \
# 0      90+3  90+3  90+3  92+3  92+3  92+3  92+3  90+3  79+3  79+3  79+3  90+3
# 1      91+1  91+1  91+1  89+3  89+3  89+3  89+3  87+3  77+3  77+3  77+3  87+3
# 3      86+3  86+3  86+3  84+3  86+3  86+3  86+3  83+3  76+3  76+3  76+3  83+3
# 23     82+2  82+2  82+2  86+2  84+2  84+2  84+2  85+2  81+2  81+2  81+2  85+2
# 26     85+2  85+2  85+2  84+2  86+1  86+1  86+1  81+2  72+2  72+2  72+2  81+2
# ...     ...   ...   ...   ...   ...   ...   ...   ...   ...   ...   ...   ...
# 16143  47+0  47+0  47+0  45+0  45+0  45+0  45+0  43+0  40+0  40+0  40+0  43+0
# 16145  26+0  26+0  26+0  26+0  26+0  26+0  26+0  26+0  26+0  26+0  26+0  26+0
# 16146  35+0  35+0  35+0  37+0  36+0  36+0  36+0  40+0  42+0  42+0  42+0  40+0
# 16149  27+0  27+0  27+0  28+0  27+0  27+0  27+0  28+0  27+0  27+0  27+0  28+0
# 16153  33+0  33+0  33+0  33+0  31+0  31+0  31+0  34+0  31+0  31+0  31+0  34+0
#
#         lwb   ldm   cdm   rdm   rwb    lb   lcb    cb   rcb    rb rank_calc
# 0      62+3  62+3  62+3  62+3  62+3  54+3  45+3  45+3  45+3  54+3   16155.0
# 1      63+3  63+3  63+3  63+3  63+3  57+3  52+3  52+3  52+3  57+3   16154.0
# 3      61+3  65+3  65+3  65+3  61+3  56+3  55+3  55+3  55+3  56+3   16151.0
# 23     75+2  73+2  73+2  73+2  75+2  70+2  64+2  64+2  64+2  70+2   16147.5
# 26     58+2  59+2  59+2  59+2  58+2  51+2  47+2  47+2  47+2  51+2   16147.5
# ...     ...   ...   ...   ...   ...   ...   ...   ...   ...   ...       ...
# 16143  37+0  36+0  36+0  36+0  37+0  36+0  34+0  34+0  34+0  36+0     584.0
# 16145  27+0  28+0  28+0  28+0  27+0  27+0  30+0  30+0  30+0  27+0     328.0
# 16146  48+0  49+0  49+0  49+0  48+0  50+0  51+0  51+0  51+0  50+0     584.0
# 16149  28+0  27+0  27+0  27+0  28+0  27+0  28+0  28+0  28+0  27+0     418.0
# 16153  37+0  36+0  36+0  36+0  37+0  39+0  40+0  40+0  40+0  39+0     337.5
#
# [3229 rows x 108 columns]

# %% [markdown]
# data.replace()
# It does exactly what it sounds like. It replaces the values of a column. When we need to replace only one unique value of a column we simply need to pass the old value and the new value. Imagine, we just found out that the ‘league_rank’ 1.0 needs to be replaced by 1.1 now. Here is how to do that:

# %%
data.replace(1.0, 1.1)
# Out:
#        sofifa_id                                         player_url  \
# 0         158023  https://sofifa.com/player/158023/lionel-messi/...
# 1          20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2           9014  https://sofifa.com/player/9014/arjen-robben/15...
# 3          41236  https://sofifa.com/player/41236/zlatan-ibrahim...
# 4         167495  https://sofifa.com/player/167495/manuel-neuer/...
# ...          ...                                                ...
# 16150     220806  https://sofifa.com/player/220806/ellis-redman/...
# 16151     225509  https://sofifa.com/player/225509/aaron-collins...
# 16152     217591  https://sofifa.com/player/217591/piotr-zemlo/1...
# 16153     222947  https://sofifa.com/player/222947/tom-davies/15...
# 16154     201197  https://sofifa.com/player/201197/paul-tisdale/...
#
#               short_name  random_col                            long_name  \
# 0               L. Messi        62.0       Lionel Andrés Messi Cuccittini
# 1      Cristiano Ronaldo         1.1  Cristiano Ronaldo dos Santos Aveiro
# 2              A. Robben        55.0                         Arjen Robben
# 3         Z. Ibrahimović        72.0                   Zlatan Ibrahimović
# 4               M. Neuer        96.0                         Manuel Neuer
# ...                  ...         ...                                  ...
# 16150          E. Redman        22.0                         Ellis Redman
# 16151         A. Collins        45.0                        Aaron Collins
# 16152           P. Żemło        14.0                          Piotr Żemło
# 16153          T. Davies        44.0                           Tom Davies
# 16154         P. Tisdale        23.0                         Paul Tisdale
#
#        age        dob  height_cm  weight_kg  nationality            club_name  \
# 0       27 1987-06-24        169         67    Argentina         FC Barcelona
# 1       29 1985-02-05        185         80     Portugal          Real Madrid
# 2       30 1984-01-23        180         80  Netherlands    FC Bayern München
# 3       32 1981-10-03        195         95       Sweden  Paris Saint-Germain
# 4       28 1986-03-27        193         92      Germany    FC Bayern München
# ...    ...        ...        ...        ...          ...                  ...
# 16150   17 1996-09-26        187         81        Wales       Newport County
# 16151   17 1997-06-01        178         57        Wales       Newport County
# 16152   18 1995-07-10        190         76       Poland         Wisła Kraków
# 16153   22 1992-04-18        180         70      England       Fleetwood Town
# 16154   41 1973-01-14        175         72        Malta          Exeter City
#
#                        league_name  league_rank  overall  potential  \
# 0           Spain Primera Division          1.1       93         95
# 1           Spain Primera Division          1.1       92         92
# 2             German 1. Bundesliga          1.1       90         90
# 3                   French Ligue 1          1.1       90         90
# 4             German 1. Bundesliga          1.1       90         90
# ...                            ...          ...      ...        ...
# 16150           English League Two          4.0       41         61
# 16151           English League Two          4.0       41         50
# 16152  Polish T-Mobile Ekstraklasa          1.1       40         50
# 16153           English League One          3.0       40         49
# 16154           English League Two          4.0       40         40
#
#        value_eur  wage_eur player_positions preferred_foot  \
# 0      100500000    550000               CF           Left
# 1       79000000    375000           LW, LM          Right
# 2       54500000    275000       RM, LM, RW           Left
# 3       52500000    275000               ST          Right
# 4       63500000    300000               GK          Right
# ...          ...       ...              ...            ...
# 16150      20000      2000               CB          Right
# 16151      30000      2000               ST          Right
# 16152      15000      2000           LM, LB           Left
# 16153      15000      2000               CB          Right
# 16154          0      2000          CM, CAM          Right
#
#        international_reputation  weak_foot  skill_moves      work_rate  \
# 0                           5.0        3.0          4.0     Medium/Low
# 1                           5.0        4.0          5.0       High/Low
# 2                           5.0        2.0          4.0       High/Low
# 3                           5.0        4.0          4.0     Medium/Low
# 4                           5.0        4.0          1.1  Medium/Medium
# ...                         ...        ...          ...            ...
# 16150                       1.1        2.0          2.0  Medium/Medium
# 16151                       1.1        3.0          3.0  Medium/Medium
# 16152                       1.1        3.0          2.0  Medium/Medium
# 16153                       1.1        2.0          2.0  Medium/Medium
# 16154                       1.1        3.0          2.0  Medium/Medium
#
#       body_type real_face  release_clause_eur  \
# 0        Normal       Yes                 NaN
# 1        Normal       Yes                 NaN
# 2        Normal       Yes                 NaN
# 3        Normal       Yes                 NaN
# 4        Normal       Yes                 NaN
# ...         ...       ...                 ...
# 16150    Normal        No                 NaN
# 16151      Lean        No                 NaN
# 16152    Normal        No                 NaN
# 16153    Normal        No                 NaN
# 16154      Lean        No                 NaN
#
#                                              player_tags team_position  \
# 0      #Speedster, #Dribbler, #FK Specialist, #Acroba...            CF
# 1      #Speedster, #Dribbler, #Distance Shooter, #Acr...            LW
# 2      #Speedster, #Dribbler, #Distance Shooter, #Acr...           SUB
# 3      #Poacher, #Aerial Threat, #Distance Shooter, #...            ST
# 4                                                    NaN            GK
# ...                                                  ...           ...
# 16150                                                NaN           RES
# 16151                                                NaN           RES
# 16152                                                NaN           RES
# 16153                                                NaN           RES
# 16154                                                NaN           RES
#
#        team_jersey_number loaned_from     joined  contract_valid_until  \
# 0                    10.0         NaN 2004-07-01                2018.0
# 1                     7.0         NaN 2009-07-01                2018.0
# 2                    10.0         NaN 2009-08-28                2017.0
# 3                    10.0         NaN 2012-07-01                2016.0
# 4                     1.1         NaN 2011-07-01                2019.0
# ...                   ...         ...        ...                   ...
# 16150                35.0         NaN 2013-10-22                2015.0
# 16151                39.0         NaN 2014-08-14                2015.0
# 16152                43.0         NaN 2012-07-01                2015.0
# 16153                26.0         NaN 2014-03-11                2021.0
# 16154                17.0         NaN 2006-06-26                2015.0
#
#       nation_position  nation_jersey_number  pace  shooting  passing  \
# 0                  CF                  10.0  93.0      89.0     86.0
# 1                  LW                   7.0  93.0      93.0     81.0
# 2                  RS                  11.0  93.0      86.0     83.0
# 3                  ST                  10.0  76.0      91.0     81.0
# 4                  GK                   1.1   NaN       NaN      NaN
# ...               ...                   ...   ...       ...      ...
# 16150             NaN                   NaN  66.0      25.0     29.0
# 16151             NaN                   NaN  64.0      41.0     27.0
# 16152             NaN                   NaN  58.0      27.0     35.0
# 16153             NaN                   NaN  72.0      27.0     27.0
# 16154             NaN                   NaN  38.0      36.0     42.0
#
#        dribbling  defending  physic  gk_diving  gk_handling  gk_kicking  \
# 0           96.0       27.0    63.0        NaN          NaN         NaN
# 1           91.0       32.0    79.0        NaN          NaN         NaN
# 2           92.0       32.0    64.0        NaN          NaN         NaN
# 3           86.0       34.0    86.0        NaN          NaN         NaN
# 4            NaN        NaN     NaN       87.0         85.0        92.0
# ...          ...        ...     ...        ...          ...         ...
# 16150       30.0       39.0    53.0        NaN          NaN         NaN
# 16151       35.0       27.0    41.0        NaN          NaN         NaN
# 16152       31.0       52.0    68.0        NaN          NaN         NaN
# 16153       30.0       35.0    61.0        NaN          NaN         NaN
# 16154       45.0       31.0    33.0        NaN          NaN         NaN
#
#        gk_reflexes  gk_speed  gk_positioning  \
# 0              NaN       NaN             NaN
# 1              NaN       NaN             NaN
# 2              NaN       NaN             NaN
# 3              NaN       NaN             NaN
# 4             86.0      60.0            90.0
# ...            ...       ...             ...
# 16150          NaN       NaN             NaN
# 16151          NaN       NaN             NaN
# 16152          NaN       NaN             NaN
# 16153          NaN       NaN             NaN
# 16154          NaN       NaN             NaN
#
#                                            player_traits  attacking_crossing  \
# 0      Finesse Shot, Speed Dribbler (AI), One Club Pl...                  84
# 1      Power Free-Kick, Flair, Long Shot Taker (AI), ...                  83
# 2      Diver, Injury Prone, Avoids Using Weaker Foot,...                  80
# 3      Power Free-Kick, Leadership, Flair, Long Shot ...                  76
# 4          GK Up for Corners, GK Long Throw, 1-on-1 Rush                  25
# ...                                                  ...                 ...
# 16150                                                NaN                  25
# 16151                                                NaN                  22
# 16152                                                NaN                  49
# 16153                                                NaN                  23
# 16154                       Injury Prone, Playmaker (AI)                  39
#
#        attacking_finishing  attacking_heading_accuracy  ...  \
# 0                       94                          71  ...
# 1                       95                          86  ...
# 2                       85                          50  ...
# 3                       91                          76  ...
# 4                       25                          25  ...
# ...                    ...                         ...  ...
# 16150                   25                          41  ...
# 16151                   47                          43  ...
# 16152                   24                          57  ...
# 16153                   25                          38  ...
# 16154                   36                          29  ...
#
#        movement_sprint_speed  movement_agility  movement_reactions  \
# 0                         90                94                  94
# 1                         94                93                  90
# 2                         93                93                  89
# 3                         77                86                  85
# 4                         61                43                  89
# ...                      ...               ...                 ...
# 16150                     66                52                  36
# 16151                     68                66                  39
# 16152                     58                36                  50
# 16153                     73                33                  32
# 16154                     41                37                  41
#
#        movement_balance  power_shot_power  power_jumping  power_stamina  \
# 0                    95                80             73             77
# 1                    63                94             94             89
# 2                    91                86             61             78
# 3                    41                93             72             78
# 4                    35                42             78             44
# ...                 ...               ...            ...            ...
# 16150                55                22             62             56
# 16151                68                36             51             47
# 16152                44                31             61             74
# 16153                61                39             64             70
# 16154                51                32             39             25
#
#        power_strength  power_long_shots  mentality_aggression  \
# 0                  60                88                    48
# 1                  79                93                    63
# 2                  65                90                    47
# 3                  93                88                    84
# 4                  83                25                    29
# ...               ...               ...                   ...
# 16150              52                25                    50
# 16151              42                36                    30
# 16152              75                25                    44
# 16153              63                22                    44
# 16154              37                38                    32
#
#        mentality_interceptions  mentality_positioning  mentality_vision  \
# 0                           22                     92                90
# 1                           24                     91                81
# 2                           39                     89                84
# 3                           20                     86                83
# 4                           30                     25                20
# ...                        ...                    ...               ...
# 16150                       41                     25                22
# 16151                       25                     41                39
# 16152                       47                     38                21
# 16153                       34                     27                25
# 16154                       35                     43                41
#
#        mentality_penalties  mentality_composure  defending_marking  \
# 0                       76                  NaN                 25
# 1                       85                  NaN                 22
# 2                       80                  NaN                 29
# 3                       91                  NaN                 25
# 4                       37                  NaN                 25
# ...                    ...                  ...                ...
# 16150                   31                  NaN                 38
# 16151                   47                  NaN                 25
# 16152                   31                  NaN                 54
# 16153                   21                  NaN                 36
# 16154                   55                  NaN                 27
#
#        defending_standing_tackle  defending_sliding_tackle  \
# 0                             21                        20
# 1                             31                        23
# 2                             26                        26
# 3                             41                        27
# 4                             25                        25
# ...                          ...                       ...
# 16150                         40                        35
# 16151                         25                        25
# 16152                         52                        51
# 16153                         34                        35
# 16154                         34                        29
#
#        goalkeeping_diving  goalkeeping_handling  goalkeeping_kicking  \
# 0                     6.0                  11.0                 15.0
# 1                     7.0                  11.0                 15.0
# 2                    10.0                   8.0                 11.0
# 3                    13.0                  15.0                 10.0
# 4                    87.0                  85.0                 92.0
# ...                   ...                   ...                  ...
# 16150                12.0                   6.0                 15.0
# 16151                13.0                  11.0                 12.0
# 16152                 8.0                  14.0                  7.0
# 16153                15.0                  13.0                  6.0
# 16154                 5.0                   6.0                 14.0
#
#        goalkeeping_positioning  goalkeeping_reflexes    ls    st    rs    lw  \
# 0                         14.0                   8.0  89+3  89+3  89+3  92+3
# 1                         14.0                  11.0  91+1  91+1  91+1  89+3
# 2                          5.0                  15.0  84+3  84+3  84+3  88+2
# 3                          9.0                  12.0  87+3  87+3  87+3  84+3
# 4                         90.0                  86.0  38+3  38+3  38+3  36+3
# ...                        ...                   ...   ...   ...   ...   ...
# 16150                      8.0                   6.0  32+0  32+0  32+0  33+0
# 16151                     15.0                  11.0  41+0  41+0  41+0  37+0
# 16152                     10.0                   9.0  38+0  38+0  38+0  38+0
# 16153                     11.0                   9.0  35+0  35+0  35+0  33+0
# 16154                      8.0                  13.0  38+0  38+0  38+0   41+
#
#          lf    cf    rf    rw   lam   cam   ram    lm   lcm    cm   rcm    rm  \
# 0      90+3  90+3  90+3  92+3  92+3  92+3  92+3  90+3  79+3  79+3  79+3  90+3
# 1      91+1  91+1  91+1  89+3  89+3  89+3  89+3  87+3  77+3  77+3  77+3  87+3
# 2      87+3  87+3  87+3  88+2  88+2  88+2  88+2  87+3  78+3  78+3  78+3  87+3
# 3      86+3  86+3  86+3  84+3  86+3  86+3  86+3  83+3  76+3  76+3  76+3  83+3
# 4      37+3  37+3  37+3  36+3  36+3  36+3  36+3  38+3  36+3  36+3  36+3  38+3
# ...     ...   ...   ...   ...   ...   ...   ...   ...   ...   ...   ...   ...
# 16150  30+0  30+0  30+0  33+0  30+0  30+0  30+0  34+0  32+0  32+0  32+0  34+0
# 16151  39+0  39+0  39+0  37+0  37+0  37+0  37+0  35+0  32+0  32+0  32+0  35+0
# 16152  35+0  35+0  35+0  38+0  33+0  33+0  33+0  40+0  38+0  38+0  38+0  40+0
# 16153  33+0  33+0  33+0  33+0  31+0  31+0  31+0  34+0  31+0  31+0  31+0  34+0
# 16154  40+0  40+0  40+0   41+   41+   41+   41+   41+  40+0  40+0  40+0   41+
#
#         lwb   ldm   cdm   rdm   rwb    lb   lcb    cb   rcb    rb rank_calc
# 0      62+3  62+3  62+3  62+3  62+3  54+3  45+3  45+3  45+3  54+3   16155.0
# 1      63+3  63+3  63+3  63+3  63+3  57+3  52+3  52+3  52+3  57+3   16154.0
# 2      64+3  64+3  64+3  64+3  64+3  55+3  46+3  46+3  46+3  55+3   16152.0
# 3      61+3  65+3  65+3  65+3  61+3  56+3  55+3  55+3  55+3  56+3   16151.0
# 4      36+3  40+3  40+3  40+3  36+3  36+3  38+3  38+3  38+3  36+3   16153.0
# ...     ...   ...   ...   ...   ...   ...   ...   ...   ...   ...       ...
# 16150  37+0  38+0  38+0  38+0  37+0  40+0  41+0  41+0  41+0  40+0     418.0
# 16151  31+0  30+0  30+0  30+0  31+0  32+0  31+0  31+0  31+0  32+0     749.5
# 16152  48+0  46+0  46+0  46+0  48+0   51+   53+   53+   53+   51+     337.5
# 16153  37+0  36+0  36+0  36+0  37+0  39+0  40+0  40+0  40+0  39+0     337.5
# 16154  36+0  37+0  37+0  37+0  36+0  34+0  33+0  33+0  33+0  34+0     156.0
#
# [16155 rows x 108 columns]

# %%
data.replace({1.0: 1.1,  4.0: 4.1, 3.0: 3.1})
# Out:
#        sofifa_id                                         player_url  \
# 0       158023.0  https://sofifa.com/player/158023/lionel-messi/...
# 1        20801.0  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2         9014.0  https://sofifa.com/player/9014/arjen-robben/15...
# 3        41236.0  https://sofifa.com/player/41236/zlatan-ibrahim...
# 4       167495.0  https://sofifa.com/player/167495/manuel-neuer/...
# ...          ...                                                ...
# 16150   220806.0  https://sofifa.com/player/220806/ellis-redman/...
# 16151   225509.0  https://sofifa.com/player/225509/aaron-collins...
# 16152   217591.0  https://sofifa.com/player/217591/piotr-zemlo/1...
# 16153   222947.0  https://sofifa.com/player/222947/tom-davies/15...
# 16154   201197.0  https://sofifa.com/player/201197/paul-tisdale/...
#
#               short_name  random_col                            long_name  \
# 0               L. Messi        62.0       Lionel Andrés Messi Cuccittini
# 1      Cristiano Ronaldo         1.1  Cristiano Ronaldo dos Santos Aveiro
# 2              A. Robben        55.0                         Arjen Robben
# 3         Z. Ibrahimović        72.0                   Zlatan Ibrahimović
# 4               M. Neuer        96.0                         Manuel Neuer
# ...                  ...         ...                                  ...
# 16150          E. Redman        22.0                         Ellis Redman
# 16151         A. Collins        45.0                        Aaron Collins
# 16152           P. Żemło        14.0                          Piotr Żemło
# 16153          T. Davies        44.0                           Tom Davies
# 16154         P. Tisdale        23.0                         Paul Tisdale
#
#         age        dob  height_cm  weight_kg  nationality  \
# 0      27.0 1987-06-24      169.0       67.0    Argentina
# 1      29.0 1985-02-05      185.0       80.0     Portugal
# 2      30.0 1984-01-23      180.0       80.0  Netherlands
# 3      32.0 1981-10-03      195.0       95.0       Sweden
# 4      28.0 1986-03-27      193.0       92.0      Germany
# ...     ...        ...        ...        ...          ...
# 16150  17.0 1996-09-26      187.0       81.0        Wales
# 16151  17.0 1997-06-01      178.0       57.0        Wales
# 16152  18.0 1995-07-10      190.0       76.0       Poland
# 16153  22.0 1992-04-18      180.0       70.0      England
# 16154  41.0 1973-01-14      175.0       72.0        Malta
#
#                  club_name                  league_name  league_rank  overall  \
# 0             FC Barcelona       Spain Primera Division          1.1     93.0
# 1              Real Madrid       Spain Primera Division          1.1     92.0
# 2        FC Bayern München         German 1. Bundesliga          1.1     90.0
# 3      Paris Saint-Germain               French Ligue 1          1.1     90.0
# 4        FC Bayern München         German 1. Bundesliga          1.1     90.0
# ...                    ...                          ...          ...      ...
# 16150       Newport County           English League Two          4.1     41.0
# 16151       Newport County           English League Two          4.1     41.0
# 16152         Wisła Kraków  Polish T-Mobile Ekstraklasa          1.1     40.0
# 16153       Fleetwood Town           English League One          3.1     40.0
# 16154          Exeter City           English League Two          4.1     40.0
#
#        potential    value_eur  wage_eur player_positions preferred_foot  \
# 0           95.0  100500000.0  550000.0               CF           Left
# 1           92.0   79000000.0  375000.0           LW, LM          Right
# 2           90.0   54500000.0  275000.0       RM, LM, RW           Left
# 3           90.0   52500000.0  275000.0               ST          Right
# 4           90.0   63500000.0  300000.0               GK          Right
# ...          ...          ...       ...              ...            ...
# 16150       61.0      20000.0    2000.0               CB          Right
# 16151       50.0      30000.0    2000.0               ST          Right
# 16152       50.0      15000.0    2000.0           LM, LB           Left
# 16153       49.0      15000.0    2000.0               CB          Right
# 16154       40.0          0.0    2000.0          CM, CAM          Right
#
#        international_reputation  weak_foot  skill_moves      work_rate  \
# 0                           5.0        3.1          4.1     Medium/Low
# 1                           5.0        4.1          5.0       High/Low
# 2                           5.0        2.0          4.1       High/Low
# 3                           5.0        4.1          4.1     Medium/Low
# 4                           5.0        4.1          1.1  Medium/Medium
# ...                         ...        ...          ...            ...
# 16150                       1.1        2.0          2.0  Medium/Medium
# 16151                       1.1        3.1          3.1  Medium/Medium
# 16152                       1.1        3.1          2.0  Medium/Medium
# 16153                       1.1        2.0          2.0  Medium/Medium
# 16154                       1.1        3.1          2.0  Medium/Medium
#
#       body_type real_face  release_clause_eur  \
# 0        Normal       Yes                 NaN
# 1        Normal       Yes                 NaN
# 2        Normal       Yes                 NaN
# 3        Normal       Yes                 NaN
# 4        Normal       Yes                 NaN
# ...         ...       ...                 ...
# 16150    Normal        No                 NaN
# 16151      Lean        No                 NaN
# 16152    Normal        No                 NaN
# 16153    Normal        No                 NaN
# 16154      Lean        No                 NaN
#
#                                              player_tags team_position  \
# 0      #Speedster, #Dribbler, #FK Specialist, #Acroba...            CF
# 1      #Speedster, #Dribbler, #Distance Shooter, #Acr...            LW
# 2      #Speedster, #Dribbler, #Distance Shooter, #Acr...           SUB
# 3      #Poacher, #Aerial Threat, #Distance Shooter, #...            ST
# 4                                                    NaN            GK
# ...                                                  ...           ...
# 16150                                                NaN           RES
# 16151                                                NaN           RES
# 16152                                                NaN           RES
# 16153                                                NaN           RES
# 16154                                                NaN           RES
#
#        team_jersey_number loaned_from     joined  contract_valid_until  \
# 0                    10.0         NaN 2004-07-01                2018.0
# 1                     7.0         NaN 2009-07-01                2018.0
# 2                    10.0         NaN 2009-08-28                2017.0
# 3                    10.0         NaN 2012-07-01                2016.0
# 4                     1.1         NaN 2011-07-01                2019.0
# ...                   ...         ...        ...                   ...
# 16150                35.0         NaN 2013-10-22                2015.0
# 16151                39.0         NaN 2014-08-14                2015.0
# 16152                43.0         NaN 2012-07-01                2015.0
# 16153                26.0         NaN 2014-03-11                2021.0
# 16154                17.0         NaN 2006-06-26                2015.0
#
#       nation_position  nation_jersey_number  pace  shooting  passing  \
# 0                  CF                  10.0  93.0      89.0     86.0
# 1                  LW                   7.0  93.0      93.0     81.0
# 2                  RS                  11.0  93.0      86.0     83.0
# 3                  ST                  10.0  76.0      91.0     81.0
# 4                  GK                   1.1   NaN       NaN      NaN
# ...               ...                   ...   ...       ...      ...
# 16150             NaN                   NaN  66.0      25.0     29.0
# 16151             NaN                   NaN  64.0      41.0     27.0
# 16152             NaN                   NaN  58.0      27.0     35.0
# 16153             NaN                   NaN  72.0      27.0     27.0
# 16154             NaN                   NaN  38.0      36.0     42.0
#
#        dribbling  defending  physic  gk_diving  gk_handling  gk_kicking  \
# 0           96.0       27.0    63.0        NaN          NaN         NaN
# 1           91.0       32.0    79.0        NaN          NaN         NaN
# 2           92.0       32.0    64.0        NaN          NaN         NaN
# 3           86.0       34.0    86.0        NaN          NaN         NaN
# 4            NaN        NaN     NaN       87.0         85.0        92.0
# ...          ...        ...     ...        ...          ...         ...
# 16150       30.0       39.0    53.0        NaN          NaN         NaN
# 16151       35.0       27.0    41.0        NaN          NaN         NaN
# 16152       31.0       52.0    68.0        NaN          NaN         NaN
# 16153       30.0       35.0    61.0        NaN          NaN         NaN
# 16154       45.0       31.0    33.0        NaN          NaN         NaN
#
#        gk_reflexes  gk_speed  gk_positioning  \
# 0              NaN       NaN             NaN
# 1              NaN       NaN             NaN
# 2              NaN       NaN             NaN
# 3              NaN       NaN             NaN
# 4             86.0      60.0            90.0
# ...            ...       ...             ...
# 16150          NaN       NaN             NaN
# 16151          NaN       NaN             NaN
# 16152          NaN       NaN             NaN
# 16153          NaN       NaN             NaN
# 16154          NaN       NaN             NaN
#
#                                            player_traits  attacking_crossing  \
# 0      Finesse Shot, Speed Dribbler (AI), One Club Pl...                84.0
# 1      Power Free-Kick, Flair, Long Shot Taker (AI), ...                83.0
# 2      Diver, Injury Prone, Avoids Using Weaker Foot,...                80.0
# 3      Power Free-Kick, Leadership, Flair, Long Shot ...                76.0
# 4          GK Up for Corners, GK Long Throw, 1-on-1 Rush                25.0
# ...                                                  ...                 ...
# 16150                                                NaN                25.0
# 16151                                                NaN                22.0
# 16152                                                NaN                49.0
# 16153                                                NaN                23.0
# 16154                       Injury Prone, Playmaker (AI)                39.0
#
#        attacking_finishing  attacking_heading_accuracy  ...  \
# 0                     94.0                        71.0  ...
# 1                     95.0                        86.0  ...
# 2                     85.0                        50.0  ...
# 3                     91.0                        76.0  ...
# 4                     25.0                        25.0  ...
# ...                    ...                         ...  ...
# 16150                 25.0                        41.0  ...
# 16151                 47.0                        43.0  ...
# 16152                 24.0                        57.0  ...
# 16153                 25.0                        38.0  ...
# 16154                 36.0                        29.0  ...
#
#        movement_sprint_speed  movement_agility  movement_reactions  \
# 0                       90.0              94.0                94.0
# 1                       94.0              93.0                90.0
# 2                       93.0              93.0                89.0
# 3                       77.0              86.0                85.0
# 4                       61.0              43.0                89.0
# ...                      ...               ...                 ...
# 16150                   66.0              52.0                36.0
# 16151                   68.0              66.0                39.0
# 16152                   58.0              36.0                50.0
# 16153                   73.0              33.0                32.0
# 16154                   41.0              37.0                41.0
#
#        movement_balance  power_shot_power  power_jumping  power_stamina  \
# 0                  95.0              80.0           73.0           77.0
# 1                  63.0              94.0           94.0           89.0
# 2                  91.0              86.0           61.0           78.0
# 3                  41.0              93.0           72.0           78.0
# 4                  35.0              42.0           78.0           44.0
# ...                 ...               ...            ...            ...
# 16150              55.0              22.0           62.0           56.0
# 16151              68.0              36.0           51.0           47.0
# 16152              44.0              31.0           61.0           74.0
# 16153              61.0              39.0           64.0           70.0
# 16154              51.0              32.0           39.0           25.0
#
#        power_strength  power_long_shots  mentality_aggression  \
# 0                60.0              88.0                  48.0
# 1                79.0              93.0                  63.0
# 2                65.0              90.0                  47.0
# 3                93.0              88.0                  84.0
# 4                83.0              25.0                  29.0
# ...               ...               ...                   ...
# 16150            52.0              25.0                  50.0
# 16151            42.0              36.0                  30.0
# 16152            75.0              25.0                  44.0
# 16153            63.0              22.0                  44.0
# 16154            37.0              38.0                  32.0
#
#        mentality_interceptions  mentality_positioning  mentality_vision  \
# 0                         22.0                   92.0              90.0
# 1                         24.0                   91.0              81.0
# 2                         39.0                   89.0              84.0
# 3                         20.0                   86.0              83.0
# 4                         30.0                   25.0              20.0
# ...                        ...                    ...               ...
# 16150                     41.0                   25.0              22.0
# 16151                     25.0                   41.0              39.0
# 16152                     47.0                   38.0              21.0
# 16153                     34.0                   27.0              25.0
# 16154                     35.0                   43.0              41.0
#
#        mentality_penalties  mentality_composure  defending_marking  \
# 0                     76.0                  NaN               25.0
# 1                     85.0                  NaN               22.0
# 2                     80.0                  NaN               29.0
# 3                     91.0                  NaN               25.0
# 4                     37.0                  NaN               25.0
# ...                    ...                  ...                ...
# 16150                 31.0                  NaN               38.0
# 16151                 47.0                  NaN               25.0
# 16152                 31.0                  NaN               54.0
# 16153                 21.0                  NaN               36.0
# 16154                 55.0                  NaN               27.0
#
#        defending_standing_tackle  defending_sliding_tackle  \
# 0                           21.0                      20.0
# 1                           31.0                      23.0
# 2                           26.0                      26.0
# 3                           41.0                      27.0
# 4                           25.0                      25.0
# ...                          ...                       ...
# 16150                       40.0                      35.0
# 16151                       25.0                      25.0
# 16152                       52.0                      51.0
# 16153                       34.0                      35.0
# 16154                       34.0                      29.0
#
#        goalkeeping_diving  goalkeeping_handling  goalkeeping_kicking  \
# 0                     6.0                  11.0                 15.0
# 1                     7.0                  11.0                 15.0
# 2                    10.0                   8.0                 11.0
# 3                    13.0                  15.0                 10.0
# 4                    87.0                  85.0                 92.0
# ...                   ...                   ...                  ...
# 16150                12.0                   6.0                 15.0
# 16151                13.0                  11.0                 12.0
# 16152                 8.0                  14.0                  7.0
# 16153                15.0                  13.0                  6.0
# 16154                 5.0                   6.0                 14.0
#
#        goalkeeping_positioning  goalkeeping_reflexes    ls    st    rs    lw  \
# 0                         14.0                   8.0  89+3  89+3  89+3  92+3
# 1                         14.0                  11.0  91+1  91+1  91+1  89+3
# 2                          5.0                  15.0  84+3  84+3  84+3  88+2
# 3                          9.0                  12.0  87+3  87+3  87+3  84+3
# 4                         90.0                  86.0  38+3  38+3  38+3  36+3
# ...                        ...                   ...   ...   ...   ...   ...
# 16150                      8.0                   6.0  32+0  32+0  32+0  33+0
# 16151                     15.0                  11.0  41+0  41+0  41+0  37+0
# 16152                     10.0                   9.0  38+0  38+0  38+0  38+0
# 16153                     11.0                   9.0  35+0  35+0  35+0  33+0
# 16154                      8.0                  13.0  38+0  38+0  38+0   41+
#
#          lf    cf    rf    rw   lam   cam   ram    lm   lcm    cm   rcm    rm  \
# 0      90+3  90+3  90+3  92+3  92+3  92+3  92+3  90+3  79+3  79+3  79+3  90+3
# 1      91+1  91+1  91+1  89+3  89+3  89+3  89+3  87+3  77+3  77+3  77+3  87+3
# 2      87+3  87+3  87+3  88+2  88+2  88+2  88+2  87+3  78+3  78+3  78+3  87+3
# 3      86+3  86+3  86+3  84+3  86+3  86+3  86+3  83+3  76+3  76+3  76+3  83+3
# 4      37+3  37+3  37+3  36+3  36+3  36+3  36+3  38+3  36+3  36+3  36+3  38+3
# ...     ...   ...   ...   ...   ...   ...   ...   ...   ...   ...   ...   ...
# 16150  30+0  30+0  30+0  33+0  30+0  30+0  30+0  34+0  32+0  32+0  32+0  34+0
# 16151  39+0  39+0  39+0  37+0  37+0  37+0  37+0  35+0  32+0  32+0  32+0  35+0
# 16152  35+0  35+0  35+0  38+0  33+0  33+0  33+0  40+0  38+0  38+0  38+0  40+0
# 16153  33+0  33+0  33+0  33+0  31+0  31+0  31+0  34+0  31+0  31+0  31+0  34+0
# 16154  40+0  40+0  40+0   41+   41+   41+   41+   41+  40+0  40+0  40+0   41+
#
#         lwb   ldm   cdm   rdm   rwb    lb   lcb    cb   rcb    rb rank_calc
# 0      62+3  62+3  62+3  62+3  62+3  54+3  45+3  45+3  45+3  54+3   16155.0
# 1      63+3  63+3  63+3  63+3  63+3  57+3  52+3  52+3  52+3  57+3   16154.0
# 2      64+3  64+3  64+3  64+3  64+3  55+3  46+3  46+3  46+3  55+3   16152.0
# 3      61+3  65+3  65+3  65+3  61+3  56+3  55+3  55+3  55+3  56+3   16151.0
# 4      36+3  40+3  40+3  40+3  36+3  36+3  38+3  38+3  38+3  36+3   16153.0
# ...     ...   ...   ...   ...   ...   ...   ...   ...   ...   ...       ...
# 16150  37+0  38+0  38+0  38+0  37+0  40+0  41+0  41+0  41+0  40+0     418.0
# 16151  31+0  30+0  30+0  30+0  31+0  32+0  31+0  31+0  31+0  32+0     749.5
# 16152  48+0  46+0  46+0  46+0  48+0   51+   53+   53+   53+   51+     337.5
# 16153  37+0  36+0  36+0  36+0  37+0  39+0  40+0  40+0  40+0  39+0     337.5
# 16154  36+0  37+0  37+0  37+0  36+0  34+0  33+0  33+0  33+0  34+0     156.0
#
# [16155 rows x 108 columns]

# %% [markdown]
# df.rename()
# It is used to rename the column/s. Here I am changing the ‘weight_kg’ and ‘height_cm’ columns to “Weight (kg)” and “Height (cm)”:

# %%
data.rename(columns = {"weight_kg": "Weight (kg)", "height_cm": "Height (cm)"})
# Out:
#        sofifa_id                                         player_url  \
# 0         158023  https://sofifa.com/player/158023/lionel-messi/...
# 1          20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2           9014  https://sofifa.com/player/9014/arjen-robben/15...
# 3          41236  https://sofifa.com/player/41236/zlatan-ibrahim...
# 4         167495  https://sofifa.com/player/167495/manuel-neuer/...
# ...          ...                                                ...
# 16150     220806  https://sofifa.com/player/220806/ellis-redman/...
# 16151     225509  https://sofifa.com/player/225509/aaron-collins...
# 16152     217591  https://sofifa.com/player/217591/piotr-zemlo/1...
# 16153     222947  https://sofifa.com/player/222947/tom-davies/15...
# 16154     201197  https://sofifa.com/player/201197/paul-tisdale/...
#
#               short_name  random_col                            long_name  \
# 0               L. Messi          62       Lionel Andrés Messi Cuccittini
# 1      Cristiano Ronaldo           1  Cristiano Ronaldo dos Santos Aveiro
# 2              A. Robben          55                         Arjen Robben
# 3         Z. Ibrahimović          72                   Zlatan Ibrahimović
# 4               M. Neuer          96                         Manuel Neuer
# ...                  ...         ...                                  ...
# 16150          E. Redman          22                         Ellis Redman
# 16151         A. Collins          45                        Aaron Collins
# 16152           P. Żemło          14                          Piotr Żemło
# 16153          T. Davies          44                           Tom Davies
# 16154         P. Tisdale          23                         Paul Tisdale
#
#        age        dob  Height (cm)  Weight (kg)  nationality  \
# 0       27 1987-06-24          169           67    Argentina
# 1       29 1985-02-05          185           80     Portugal
# 2       30 1984-01-23          180           80  Netherlands
# 3       32 1981-10-03          195           95       Sweden
# 4       28 1986-03-27          193           92      Germany
# ...    ...        ...          ...          ...          ...
# 16150   17 1996-09-26          187           81        Wales
# 16151   17 1997-06-01          178           57        Wales
# 16152   18 1995-07-10          190           76       Poland
# 16153   22 1992-04-18          180           70      England
# 16154   41 1973-01-14          175           72        Malta
#
#                  club_name                  league_name  league_rank  overall  \
# 0             FC Barcelona       Spain Primera Division          1.0       93
# 1              Real Madrid       Spain Primera Division          1.0       92
# 2        FC Bayern München         German 1. Bundesliga          1.0       90
# 3      Paris Saint-Germain               French Ligue 1          1.0       90
# 4        FC Bayern München         German 1. Bundesliga          1.0       90
# ...                    ...                          ...          ...      ...
# 16150       Newport County           English League Two          4.0       41
# 16151       Newport County           English League Two          4.0       41
# 16152         Wisła Kraków  Polish T-Mobile Ekstraklasa          1.0       40
# 16153       Fleetwood Town           English League One          3.0       40
# 16154          Exeter City           English League Two          4.0       40
#
#        potential  value_eur  wage_eur player_positions preferred_foot  \
# 0             95  100500000    550000               CF           Left
# 1             92   79000000    375000           LW, LM          Right
# 2             90   54500000    275000       RM, LM, RW           Left
# 3             90   52500000    275000               ST          Right
# 4             90   63500000    300000               GK          Right
# ...          ...        ...       ...              ...            ...
# 16150         61      20000      2000               CB          Right
# 16151         50      30000      2000               ST          Right
# 16152         50      15000      2000           LM, LB           Left
# 16153         49      15000      2000               CB          Right
# 16154         40          0      2000          CM, CAM          Right
#
#        international_reputation  weak_foot  skill_moves      work_rate  \
# 0                             5          3            4     Medium/Low
# 1                             5          4            5       High/Low
# 2                             5          2            4       High/Low
# 3                             5          4            4     Medium/Low
# 4                             5          4            1  Medium/Medium
# ...                         ...        ...          ...            ...
# 16150                         1          2            2  Medium/Medium
# 16151                         1          3            3  Medium/Medium
# 16152                         1          3            2  Medium/Medium
# 16153                         1          2            2  Medium/Medium
# 16154                         1          3            2  Medium/Medium
#
#       body_type real_face  release_clause_eur  \
# 0        Normal       Yes                 NaN
# 1        Normal       Yes                 NaN
# 2        Normal       Yes                 NaN
# 3        Normal       Yes                 NaN
# 4        Normal       Yes                 NaN
# ...         ...       ...                 ...
# 16150    Normal        No                 NaN
# 16151      Lean        No                 NaN
# 16152    Normal        No                 NaN
# 16153    Normal        No                 NaN
# 16154      Lean        No                 NaN
#
#                                              player_tags team_position  \
# 0      #Speedster, #Dribbler, #FK Specialist, #Acroba...            CF
# 1      #Speedster, #Dribbler, #Distance Shooter, #Acr...            LW
# 2      #Speedster, #Dribbler, #Distance Shooter, #Acr...           SUB
# 3      #Poacher, #Aerial Threat, #Distance Shooter, #...            ST
# 4                                                    NaN            GK
# ...                                                  ...           ...
# 16150                                                NaN           RES
# 16151                                                NaN           RES
# 16152                                                NaN           RES
# 16153                                                NaN           RES
# 16154                                                NaN           RES
#
#        team_jersey_number loaned_from     joined  contract_valid_until  \
# 0                    10.0         NaN 2004-07-01                2018.0
# 1                     7.0         NaN 2009-07-01                2018.0
# 2                    10.0         NaN 2009-08-28                2017.0
# 3                    10.0         NaN 2012-07-01                2016.0
# 4                     1.0         NaN 2011-07-01                2019.0
# ...                   ...         ...        ...                   ...
# 16150                35.0         NaN 2013-10-22                2015.0
# 16151                39.0         NaN 2014-08-14                2015.0
# 16152                43.0         NaN 2012-07-01                2015.0
# 16153                26.0         NaN 2014-03-11                2021.0
# 16154                17.0         NaN 2006-06-26                2015.0
#
#       nation_position  nation_jersey_number  pace  shooting  passing  \
# 0                  CF                  10.0  93.0      89.0     86.0
# 1                  LW                   7.0  93.0      93.0     81.0
# 2                  RS                  11.0  93.0      86.0     83.0
# 3                  ST                  10.0  76.0      91.0     81.0
# 4                  GK                   1.0   NaN       NaN      NaN
# ...               ...                   ...   ...       ...      ...
# 16150             NaN                   NaN  66.0      25.0     29.0
# 16151             NaN                   NaN  64.0      41.0     27.0
# 16152             NaN                   NaN  58.0      27.0     35.0
# 16153             NaN                   NaN  72.0      27.0     27.0
# 16154             NaN                   NaN  38.0      36.0     42.0
#
#        dribbling  defending  physic  gk_diving  gk_handling  gk_kicking  \
# 0           96.0       27.0    63.0        NaN          NaN         NaN
# 1           91.0       32.0    79.0        NaN          NaN         NaN
# 2           92.0       32.0    64.0        NaN          NaN         NaN
# 3           86.0       34.0    86.0        NaN          NaN         NaN
# 4            NaN        NaN     NaN       87.0         85.0        92.0
# ...          ...        ...     ...        ...          ...         ...
# 16150       30.0       39.0    53.0        NaN          NaN         NaN
# 16151       35.0       27.0    41.0        NaN          NaN         NaN
# 16152       31.0       52.0    68.0        NaN          NaN         NaN
# 16153       30.0       35.0    61.0        NaN          NaN         NaN
# 16154       45.0       31.0    33.0        NaN          NaN         NaN
#
#        gk_reflexes  gk_speed  gk_positioning  \
# 0              NaN       NaN             NaN
# 1              NaN       NaN             NaN
# 2              NaN       NaN             NaN
# 3              NaN       NaN             NaN
# 4             86.0      60.0            90.0
# ...            ...       ...             ...
# 16150          NaN       NaN             NaN
# 16151          NaN       NaN             NaN
# 16152          NaN       NaN             NaN
# 16153          NaN       NaN             NaN
# 16154          NaN       NaN             NaN
#
#                                            player_traits  attacking_crossing  \
# 0      Finesse Shot, Speed Dribbler (AI), One Club Pl...                  84
# 1      Power Free-Kick, Flair, Long Shot Taker (AI), ...                  83
# 2      Diver, Injury Prone, Avoids Using Weaker Foot,...                  80
# 3      Power Free-Kick, Leadership, Flair, Long Shot ...                  76
# 4          GK Up for Corners, GK Long Throw, 1-on-1 Rush                  25
# ...                                                  ...                 ...
# 16150                                                NaN                  25
# 16151                                                NaN                  22
# 16152                                                NaN                  49
# 16153                                                NaN                  23
# 16154                       Injury Prone, Playmaker (AI)                  39
#
#        attacking_finishing  attacking_heading_accuracy  ...  \
# 0                       94                          71  ...
# 1                       95                          86  ...
# 2                       85                          50  ...
# 3                       91                          76  ...
# 4                       25                          25  ...
# ...                    ...                         ...  ...
# 16150                   25                          41  ...
# 16151                   47                          43  ...
# 16152                   24                          57  ...
# 16153                   25                          38  ...
# 16154                   36                          29  ...
#
#        movement_sprint_speed  movement_agility  movement_reactions  \
# 0                         90                94                  94
# 1                         94                93                  90
# 2                         93                93                  89
# 3                         77                86                  85
# 4                         61                43                  89
# ...                      ...               ...                 ...
# 16150                     66                52                  36
# 16151                     68                66                  39
# 16152                     58                36                  50
# 16153                     73                33                  32
# 16154                     41                37                  41
#
#        movement_balance  power_shot_power  power_jumping  power_stamina  \
# 0                    95                80             73             77
# 1                    63                94             94             89
# 2                    91                86             61             78
# 3                    41                93             72             78
# 4                    35                42             78             44
# ...                 ...               ...            ...            ...
# 16150                55                22             62             56
# 16151                68                36             51             47
# 16152                44                31             61             74
# 16153                61                39             64             70
# 16154                51                32             39             25
#
#        power_strength  power_long_shots  mentality_aggression  \
# 0                  60                88                    48
# 1                  79                93                    63
# 2                  65                90                    47
# 3                  93                88                    84
# 4                  83                25                    29
# ...               ...               ...                   ...
# 16150              52                25                    50
# 16151              42                36                    30
# 16152              75                25                    44
# 16153              63                22                    44
# 16154              37                38                    32
#
#        mentality_interceptions  mentality_positioning  mentality_vision  \
# 0                           22                     92                90
# 1                           24                     91                81
# 2                           39                     89                84
# 3                           20                     86                83
# 4                           30                     25                20
# ...                        ...                    ...               ...
# 16150                       41                     25                22
# 16151                       25                     41                39
# 16152                       47                     38                21
# 16153                       34                     27                25
# 16154                       35                     43                41
#
#        mentality_penalties  mentality_composure  defending_marking  \
# 0                       76                  NaN                 25
# 1                       85                  NaN                 22
# 2                       80                  NaN                 29
# 3                       91                  NaN                 25
# 4                       37                  NaN                 25
# ...                    ...                  ...                ...
# 16150                   31                  NaN                 38
# 16151                   47                  NaN                 25
# 16152                   31                  NaN                 54
# 16153                   21                  NaN                 36
# 16154                   55                  NaN                 27
#
#        defending_standing_tackle  defending_sliding_tackle  \
# 0                             21                        20
# 1                             31                        23
# 2                             26                        26
# 3                             41                        27
# 4                             25                        25
# ...                          ...                       ...
# 16150                         40                        35
# 16151                         25                        25
# 16152                         52                        51
# 16153                         34                        35
# 16154                         34                        29
#
#        goalkeeping_diving  goalkeeping_handling  goalkeeping_kicking  \
# 0                       6                    11                   15
# 1                       7                    11                   15
# 2                      10                     8                   11
# 3                      13                    15                   10
# 4                      87                    85                   92
# ...                   ...                   ...                  ...
# 16150                  12                     6                   15
# 16151                  13                    11                   12
# 16152                   8                    14                    7
# 16153                  15                    13                    6
# 16154                   5                     6                   14
#
#        goalkeeping_positioning  goalkeeping_reflexes    ls    st    rs    lw  \
# 0                           14                     8  89+3  89+3  89+3  92+3
# 1                           14                    11  91+1  91+1  91+1  89+3
# 2                            5                    15  84+3  84+3  84+3  88+2
# 3                            9                    12  87+3  87+3  87+3  84+3
# 4                           90                    86  38+3  38+3  38+3  36+3
# ...                        ...                   ...   ...   ...   ...   ...
# 16150                        8                     6  32+0  32+0  32+0  33+0
# 16151                       15                    11  41+0  41+0  41+0  37+0
# 16152                       10                     9  38+0  38+0  38+0  38+0
# 16153                       11                     9  35+0  35+0  35+0  33+0
# 16154                        8                    13  38+0  38+0  38+0   41+
#
#          lf    cf    rf    rw   lam   cam   ram    lm   lcm    cm   rcm    rm  \
# 0      90+3  90+3  90+3  92+3  92+3  92+3  92+3  90+3  79+3  79+3  79+3  90+3
# 1      91+1  91+1  91+1  89+3  89+3  89+3  89+3  87+3  77+3  77+3  77+3  87+3
# 2      87+3  87+3  87+3  88+2  88+2  88+2  88+2  87+3  78+3  78+3  78+3  87+3
# 3      86+3  86+3  86+3  84+3  86+3  86+3  86+3  83+3  76+3  76+3  76+3  83+3
# 4      37+3  37+3  37+3  36+3  36+3  36+3  36+3  38+3  36+3  36+3  36+3  38+3
# ...     ...   ...   ...   ...   ...   ...   ...   ...   ...   ...   ...   ...
# 16150  30+0  30+0  30+0  33+0  30+0  30+0  30+0  34+0  32+0  32+0  32+0  34+0
# 16151  39+0  39+0  39+0  37+0  37+0  37+0  37+0  35+0  32+0  32+0  32+0  35+0
# 16152  35+0  35+0  35+0  38+0  33+0  33+0  33+0  40+0  38+0  38+0  38+0  40+0
# 16153  33+0  33+0  33+0  33+0  31+0  31+0  31+0  34+0  31+0  31+0  31+0  34+0
# 16154  40+0  40+0  40+0   41+   41+   41+   41+   41+  40+0  40+0  40+0   41+
#
#         lwb   ldm   cdm   rdm   rwb    lb   lcb    cb   rcb    rb rank_calc
# 0      62+3  62+3  62+3  62+3  62+3  54+3  45+3  45+3  45+3  54+3   16155.0
# 1      63+3  63+3  63+3  63+3  63+3  57+3  52+3  52+3  52+3  57+3   16154.0
# 2      64+3  64+3  64+3  64+3  64+3  55+3  46+3  46+3  46+3  55+3   16152.0
# 3      61+3  65+3  65+3  65+3  61+3  56+3  55+3  55+3  55+3  56+3   16151.0
# 4      36+3  40+3  40+3  40+3  36+3  36+3  38+3  38+3  38+3  36+3   16153.0
# ...     ...   ...   ...   ...   ...   ...   ...   ...   ...   ...       ...
# 16150  37+0  38+0  38+0  38+0  37+0  40+0  41+0  41+0  41+0  40+0     418.0
# 16151  31+0  30+0  30+0  30+0  31+0  32+0  31+0  31+0  31+0  32+0     749.5
# 16152  48+0  46+0  46+0  46+0  48+0   51+   53+   53+   53+   51+     337.5
# 16153  37+0  36+0  36+0  36+0  37+0  39+0  40+0  40+0  40+0  39+0     337.5
# 16154  36+0  37+0  37+0  37+0  36+0  34+0  33+0  33+0  33+0  34+0     156.0
#
# [16155 rows x 108 columns]

# %% [markdown]
# fillna()
# Whenever you will receive a big dataset in real life, there will be some null values in most cases. It is really hard to get a perfect dataset. So, filling up the null values is part of your daily task if you are a data analyst or a data scientist. This function .fillna() replaces the null values with some other value of your choice. Here are some of the columns towards the end of the FIFA dataset:

# %%
data['pace'].fillna(0, inplace=True)

# %%
data['pace'].fillna(data['pace'].mean(), inplace = True)
data.head(5)
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2       9014  https://sofifa.com/player/9014/arjen-robben/15...
# 3      41236  https://sofifa.com/player/41236/zlatan-ibrahim...
# 4     167495  https://sofifa.com/player/167495/manuel-neuer/...
#
#           short_name  random_col                            long_name  age  \
# 0           L. Messi          62       Lionel Andrés Messi Cuccittini   27
# 1  Cristiano Ronaldo           1  Cristiano Ronaldo dos Santos Aveiro   29
# 2          A. Robben          55                         Arjen Robben   30
# 3     Z. Ibrahimović          72                   Zlatan Ibrahimović   32
# 4           M. Neuer          96                         Manuel Neuer   28
#
#          dob  height_cm  weight_kg  nationality            club_name  \
# 0 1987-06-24        169         67    Argentina         FC Barcelona
# 1 1985-02-05        185         80     Portugal          Real Madrid
# 2 1984-01-23        180         80  Netherlands    FC Bayern München
# 3 1981-10-03        195         95       Sweden  Paris Saint-Germain
# 4 1986-03-27        193         92      Germany    FC Bayern München
#
#               league_name  league_rank  overall  potential  value_eur  \
# 0  Spain Primera Division          1.0       93         95  100500000
# 1  Spain Primera Division          1.0       92         92   79000000
# 2    German 1. Bundesliga          1.0       90         90   54500000
# 3          French Ligue 1          1.0       90         90   52500000
# 4    German 1. Bundesliga          1.0       90         90   63500000
#
#    wage_eur player_positions preferred_foot  international_reputation  \
# 0    550000               CF           Left                         5
# 1    375000           LW, LM          Right                         5
# 2    275000       RM, LM, RW           Left                         5
# 3    275000               ST          Right                         5
# 4    300000               GK          Right                         5
#
#    weak_foot  skill_moves      work_rate body_type real_face  \
# 0          3            4     Medium/Low    Normal       Yes
# 1          4            5       High/Low    Normal       Yes
# 2          2            4       High/Low    Normal       Yes
# 3          4            4     Medium/Low    Normal       Yes
# 4          4            1  Medium/Medium    Normal       Yes
#
#    release_clause_eur                                        player_tags  \
# 0                 NaN  #Speedster, #Dribbler, #FK Specialist, #Acroba...
# 1                 NaN  #Speedster, #Dribbler, #Distance Shooter, #Acr...
# 2                 NaN  #Speedster, #Dribbler, #Distance Shooter, #Acr...
# 3                 NaN  #Poacher, #Aerial Threat, #Distance Shooter, #...
# 4                 NaN                                                NaN
#
#   team_position  team_jersey_number loaned_from     joined  \
# 0            CF                10.0         NaN 2004-07-01
# 1            LW                 7.0         NaN 2009-07-01
# 2           SUB                10.0         NaN 2009-08-28
# 3            ST                10.0         NaN 2012-07-01
# 4            GK                 1.0         NaN 2011-07-01
#
#    contract_valid_until nation_position  nation_jersey_number  pace  shooting  \
# 0                2018.0              CF                  10.0  93.0      89.0
# 1                2018.0              LW                   7.0  93.0      93.0
# 2                2017.0              RS                  11.0  93.0      86.0
# 3                2016.0              ST                  10.0  76.0      91.0
# 4                2019.0              GK                   1.0   0.0       NaN
#
#    passing  dribbling  defending  physic  gk_diving  gk_handling  gk_kicking  \
# 0     86.0       96.0       27.0    63.0        NaN          NaN         NaN
# 1     81.0       91.0       32.0    79.0        NaN          NaN         NaN
# 2     83.0       92.0       32.0    64.0        NaN          NaN         NaN
# 3     81.0       86.0       34.0    86.0        NaN          NaN         NaN
# 4      NaN        NaN        NaN     NaN       87.0         85.0        92.0
#
#    gk_reflexes  gk_speed  gk_positioning  \
# 0          NaN       NaN             NaN
# 1          NaN       NaN             NaN
# 2          NaN       NaN             NaN
# 3          NaN       NaN             NaN
# 4         86.0      60.0            90.0
#
#                                        player_traits  attacking_crossing  \
# 0  Finesse Shot, Speed Dribbler (AI), One Club Pl...                  84
# 1  Power Free-Kick, Flair, Long Shot Taker (AI), ...                  83
# 2  Diver, Injury Prone, Avoids Using Weaker Foot,...                  80
# 3  Power Free-Kick, Leadership, Flair, Long Shot ...                  76
# 4      GK Up for Corners, GK Long Throw, 1-on-1 Rush                  25
#
#    attacking_finishing  attacking_heading_accuracy  ...  \
# 0                   94                          71  ...
# 1                   95                          86  ...
# 2                   85                          50  ...
# 3                   91                          76  ...
# 4                   25                          25  ...
#
#    movement_sprint_speed  movement_agility  movement_reactions  \
# 0                     90                94                  94
# 1                     94                93                  90
# 2                     93                93                  89
# 3                     77                86                  85
# 4                     61                43                  89
#
#    movement_balance  power_shot_power  power_jumping  power_stamina  \
# 0                95                80             73             77
# 1                63                94             94             89
# 2                91                86             61             78
# 3                41                93             72             78
# 4                35                42             78             44
#
#    power_strength  power_long_shots  mentality_aggression  \
# 0              60                88                    48
# 1              79                93                    63
# 2              65                90                    47
# 3              93                88                    84
# 4              83                25                    29
#
#    mentality_interceptions  mentality_positioning  mentality_vision  \
# 0                       22                     92                90
# 1                       24                     91                81
# 2                       39                     89                84
# 3                       20                     86                83
# 4                       30                     25                20
#
#    mentality_penalties  mentality_composure  defending_marking  \
# 0                   76                  NaN                 25
# 1                   85                  NaN                 22
# 2                   80                  NaN                 29
# 3                   91                  NaN                 25
# 4                   37                  NaN                 25
#
#    defending_standing_tackle  defending_sliding_tackle  goalkeeping_diving  \
# 0                         21                        20                   6
# 1                         31                        23                   7
# 2                         26                        26                  10
# 3                         41                        27                  13
# 4                         25                        25                  87
#
#    goalkeeping_handling  goalkeeping_kicking  goalkeeping_positioning  \
# 0                    11                   15                       14
# 1                    11                   15                       14
# 2                     8                   11                        5
# 3                    15                   10                        9
# 4                    85                   92                       90
#
#    goalkeeping_reflexes    ls    st    rs    lw    lf    cf    rf    rw   lam  \
# 0                     8  89+3  89+3  89+3  92+3  90+3  90+3  90+3  92+3  92+3
# 1                    11  91+1  91+1  91+1  89+3  91+1  91+1  91+1  89+3  89+3
# 2                    15  84+3  84+3  84+3  88+2  87+3  87+3  87+3  88+2  88+2
# 3                    12  87+3  87+3  87+3  84+3  86+3  86+3  86+3  84+3  86+3
# 4                    86  38+3  38+3  38+3  36+3  37+3  37+3  37+3  36+3  36+3
#
#     cam   ram    lm   lcm    cm   rcm    rm   lwb   ldm   cdm   rdm   rwb  \
# 0  92+3  92+3  90+3  79+3  79+3  79+3  90+3  62+3  62+3  62+3  62+3  62+3
# 1  89+3  89+3  87+3  77+3  77+3  77+3  87+3  63+3  63+3  63+3  63+3  63+3
# 2  88+2  88+2  87+3  78+3  78+3  78+3  87+3  64+3  64+3  64+3  64+3  64+3
# 3  86+3  86+3  83+3  76+3  76+3  76+3  83+3  61+3  65+3  65+3  65+3  61+3
# 4  36+3  36+3  38+3  36+3  36+3  36+3  38+3  36+3  40+3  40+3  40+3  36+3
#
#      lb   lcb    cb   rcb    rb rank_calc
# 0  54+3  45+3  45+3  45+3  54+3   16155.0
# 1  57+3  52+3  52+3  52+3  57+3   16154.0
# 2  55+3  46+3  46+3  46+3  55+3   16152.0
# 3  56+3  55+3  55+3  55+3  56+3   16151.0
# 4  36+3  38+3  38+3  38+3  36+3   16153.0
#
# [5 rows x 108 columns]

# %% [markdown]
# df.groupby()
# This is the most popular function for data summarizing. You can group the data as per a certain variable and find out useful information about those groups. For example, here I am grouping the data by nationality and calculating the total ‘value_eur’ for each nationality:

# %%
data.groupby("nationality")['value_eur'].sum()
# Out:
# nationality
# Albania                25860000
# Algeria                70560000
# Angola                  6070000
# Antigua & Barbuda       1450000
# Argentina            1281372000
#                         ...
# Uzbekistan              7495000
# Venezuela              41495000
# Wales                 113340000
# Zambia                  4375000
# Zimbabwe                6000000
# Name: value_eur, Length: 149, dtype: int64

# %% [markdown]
# The sum of ‘value_eur’ for all the players of Albania is 25860000.
# It is also possible to group by several variables and use several aggregate functions. We will see for each nationality and each league rank’s mean value_eur, median value_eur, mean wage_eur, and median wage_eur.

# %%
data.groupby(['nationality', 'league_rank'])['value_eur', 'wage_eur'].agg([np.mean, np.median])
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
#                             value_eur               wage_eur
#                                  mean   median          mean median
# nationality league_rank
# Albania     1.0          8.584615e+05   475000  13230.769231   7000
#             2.0          5.057143e+05   500000   5857.142857   7000
# Algeria     1.0          2.130536e+06  1300000  25107.142857  20000
#             2.0          8.388462e+05   450000  12307.692308   8000
# Angola      1.0          1.149000e+06   575000  15600.000000   9000
# ...                               ...      ...           ...    ...
# Zambia      1.0          9.583333e+05   925000  11000.000000   9000
#             2.0          1.500000e+06  1500000  20000.000000  20000
# Zimbabwe    1.0          6.183333e+05   500000   8777.777778   9000
#             3.0          2.025000e+05   202500   3500.000000   3500
#             4.0          3.000000e+04    30000   2000.000000   2000
#
# [318 rows x 4 columns]

# %% [markdown]
# pct_change()
# You can get the percent change from the previous value of a variable. For this demonstration, I will use the value_eur column and get the percent change from the previous for each row of data. The first row will be NaN because there is no value to compare before.

# %%
data.value_eur.pct_change()
# Out:
# 0             NaN
# 1       -0.213930
# 2       -0.310127
# 3       -0.036697
# 4        0.209524
#            ...
# 16150    0.000000
# 16151    0.500000
# 16152   -0.500000
# 16153    0.000000
# 16154   -1.000000
# Name: value_eur, Length: 16155, dtype: float64

# %%
data.count()
#It provides you the number of data in the DataFrame in the specified direction. When the direction is 0, it provides the number of data in the columns
# Out:
# sofifa_id     16155
# player_url    16155
# short_name    16155
# random_col    16155
# long_name     16155
#               ...
# lcb           16155
# cb            16155
# rcb           16155
# rb            16155
# rank_calc     16155
# Length: 108, dtype: int64

# %% [markdown]
# df[‘’].value_counts()
# We can get the value counts of each category using this function. Here I am getting how many values are there in each league_rank.

# %%
data['league_rank'].value_counts()
# Out:
# 1.0    11738
# 2.0     2936
# 3.0      639
# 4.0      603
# Name: league_rank, dtype: int64

# %%
data['league_rank'].value_counts(ascending=True)
# Out:
# 4.0      603
# 3.0      639
# 2.0     2936
# 1.0    11738
# Name: league_rank, dtype: int64

# %% [markdown]
# pd.crosstab()
# It gives you a frequency table that is a cross-tabulation of two variables. I am making a cross-tabulation of league_rank and international_reputation here:

# %%
pd.crosstab(data['league_rank'], data['international_reputation'])
# Out:
# international_reputation      1     2    3   4  5
# league_rank
# 1.0                       10305  1160  227  37  9
# 2.0                        2772   163    1   0  0
# 3.0                         637     2    0   0  0
# 4.0                         601     2    0   0  0

# %%
pd.crosstab(data['league_rank'], data['international_reputation'], 
            margins = True,
            margins_name="Total",
            normalize = True)
# Out:
# international_reputation         1         2         3         4         5  \
# league_rank
# 1.0                       0.647462  0.072883  0.014262  0.002325  0.000565
# 2.0                       0.174164  0.010241  0.000063  0.000000  0.000000
# 3.0                       0.040023  0.000126  0.000000  0.000000  0.000000
# 4.0                       0.037761  0.000126  0.000000  0.000000  0.000000
# Total                     0.899409  0.083375  0.014325  0.002325  0.000565
#
# international_reputation     Total
# league_rank
# 1.0                       0.737497
# 2.0                       0.184468
# 3.0                       0.040148
# 4.0                       0.037886
# Total                     1.000000

# %% [markdown]
# pd.qcut()
# This function bins the data or segments the data based on the distribution of the data. So, we get the range for each player. Here I am going to segment the value_eur in 5 portions and get which player falls in which portion:

# %%
pd.qcut(data['value_eur'], q = 5)
# Out:
# 0        (1100000.0, 100500000.0]
# 1        (1100000.0, 100500000.0]
# 2        (1100000.0, 100500000.0]
# 3        (1100000.0, 100500000.0]
# 4        (1100000.0, 100500000.0]
#                    ...
# 16150          (-0.001, 100000.0]
# 16151          (-0.001, 100000.0]
# 16152          (-0.001, 100000.0]
# 16153          (-0.001, 100000.0]
# 16154          (-0.001, 100000.0]
# Name: value_eur, Length: 16155, dtype: category
# Categories (5, interval[float64]): [(-0.001, 100000.0] < (100000.0, 230000.0] < (230000.0, 500000.0] <
#                                     (500000.0, 1100000.0] < (1100000.0, 100500000.0]]

# %% [markdown]
# You can use the value_counts on the above line of code to see how players fall in which range:

# %%
pd.qcut(data['value_eur'], q = 5).value_counts()
# Out:
# (-0.001, 100000.0]          3462
# (230000.0, 500000.0]        3305
# (100000.0, 230000.0]        3184
# (500000.0, 1100000.0]       3154
# (1100000.0, 100500000.0]    3050
# Name: value_eur, dtype: int64

# %% [markdown]
# pd.cut()
# Another method for binning. If we want to make 5 bins using cut, it will divide the entire value_eur range into equal five portions and the population in each bin will follow accordingly.

# %%
pd.cut(data['value_eur'], bins = 5).value_counts()
# Out:
# (-100500.0, 20100000.0]      16102
# (20100000.0, 40200000.0]        40
# (40200000.0, 60300000.0]        10
# (60300000.0, 80400000.0]         2
# (80400000.0, 100500000.0]        1
# Name: value_eur, dtype: int64

# %% [markdown]
# df[‘’].describe()
# This is a great function that provides some basic statistical measures. Here I am using the describe function on the wage_eur column:

# %%
data['wage_eur'].describe()
# Out:
# count     16155.000000
# mean      13056.453110
# std       23488.182571
# min           0.000000
# 25%        2000.000000
# 50%        5000.000000
# 75%       10000.000000
# max      550000.000000
# Name: wage_eur, dtype: float64

# %% [markdown]
# nlargest and nsmallest
# This gives you the dataset with n number of largest values or smallest values of a specified variable. As an example, I wanted to get the rows with the top 5 wage_eur:

# %%
data.nlargest(5, "wage_eur")
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 4     167495  https://sofifa.com/player/167495/manuel-neuer/...
# 5     176580  https://sofifa.com/player/176580/luis-suarez/1...
# 2       9014  https://sofifa.com/player/9014/arjen-robben/15...
#
#           short_name  random_col                            long_name  age  \
# 0           L. Messi          62       Lionel Andrés Messi Cuccittini   27
# 1  Cristiano Ronaldo           1  Cristiano Ronaldo dos Santos Aveiro   29
# 4           M. Neuer          96                         Manuel Neuer   28
# 5          L. Suárez          26             Luis Alberto Suárez Díaz   27
# 2          A. Robben          55                         Arjen Robben   30
#
#          dob  height_cm  weight_kg  nationality          club_name  \
# 0 1987-06-24        169         67    Argentina       FC Barcelona
# 1 1985-02-05        185         80     Portugal        Real Madrid
# 4 1986-03-27        193         92      Germany  FC Bayern München
# 5 1987-01-24        181         81      Uruguay       FC Barcelona
# 2 1984-01-23        180         80  Netherlands  FC Bayern München
#
#               league_name  league_rank  overall  potential  value_eur  \
# 0  Spain Primera Division          1.0       93         95  100500000
# 1  Spain Primera Division          1.0       92         92   79000000
# 4    German 1. Bundesliga          1.0       90         90   63500000
# 5  Spain Primera Division          1.0       89         91   49500000
# 2    German 1. Bundesliga          1.0       90         90   54500000
#
#    wage_eur player_positions preferred_foot  international_reputation  \
# 0    550000               CF           Left                         5
# 1    375000           LW, LM          Right                         5
# 4    300000               GK          Right                         5
# 5    300000           ST, CF          Right                         5
# 2    275000       RM, LM, RW           Left                         5
#
#    weak_foot  skill_moves      work_rate body_type real_face  \
# 0          3            4     Medium/Low    Normal       Yes
# 1          4            5       High/Low    Normal       Yes
# 4          4            1  Medium/Medium    Normal       Yes
# 5          4            4    High/Medium    Normal       Yes
# 2          2            4       High/Low    Normal       Yes
#
#    release_clause_eur                                        player_tags  \
# 0                 NaN  #Speedster, #Dribbler, #FK Specialist, #Acroba...
# 1                 NaN  #Speedster, #Dribbler, #Distance Shooter, #Acr...
# 4                 NaN                                                NaN
# 5                 NaN                       #Acrobat, #Clinical Finisher
# 2                 NaN  #Speedster, #Dribbler, #Distance Shooter, #Acr...
#
#   team_position  team_jersey_number loaned_from     joined  \
# 0            CF                10.0         NaN 2004-07-01
# 1            LW                 7.0         NaN 2009-07-01
# 4            GK                 1.0         NaN 2011-07-01
# 5           RES                 9.0         NaN 2014-07-11
# 2           SUB                10.0         NaN 2009-08-28
#
#    contract_valid_until nation_position  nation_jersey_number  pace  shooting  \
# 0                2018.0              CF                  10.0  93.0      89.0
# 1                2018.0              LW                   7.0  93.0      93.0
# 4                2019.0              GK                   1.0   0.0       NaN
# 5                2019.0             NaN                   NaN  83.0      87.0
# 2                2017.0              RS                  11.0  93.0      86.0
#
#    passing  dribbling  defending  physic  gk_diving  gk_handling  gk_kicking  \
# 0     86.0       96.0       27.0    63.0        NaN          NaN         NaN
# 1     81.0       91.0       32.0    79.0        NaN          NaN         NaN
# 4      NaN        NaN        NaN     NaN       87.0         85.0        92.0
# 5     79.0       88.0       42.0    79.0        NaN          NaN         NaN
# 2     83.0       92.0       32.0    64.0        NaN          NaN         NaN
#
#    gk_reflexes  gk_speed  gk_positioning  \
# 0          NaN       NaN             NaN
# 1          NaN       NaN             NaN
# 4         86.0      60.0            90.0
# 5          NaN       NaN             NaN
# 2          NaN       NaN             NaN
#
#                                        player_traits  attacking_crossing  \
# 0  Finesse Shot, Speed Dribbler (AI), One Club Pl...                  84
# 1  Power Free-Kick, Flair, Long Shot Taker (AI), ...                  83
# 4      GK Up for Corners, GK Long Throw, 1-on-1 Rush                  25
# 5  Diver, Beat Offside Trap, Selfish, Flair, Tech...                  77
# 2  Diver, Injury Prone, Avoids Using Weaker Foot,...                  80
#
#    attacking_finishing  attacking_heading_accuracy  ...  \
# 0                   94                          71  ...
# 1                   95                          86  ...
# 4                   25                          25  ...
# 5                   91                          75  ...
# 2                   85                          50  ...
#
#    movement_sprint_speed  movement_agility  movement_reactions  \
# 0                     90                94                  94
# 1                     94                93                  90
# 4                     61                43                  89
# 5                     79                86                  91
# 2                     93                93                  89
#
#    movement_balance  power_shot_power  power_jumping  power_stamina  \
# 0                95                80             73             77
# 1                63                94             94             89
# 4                35                42             78             44
# 5                60                84             69             86
# 2                91                86             61             78
#
#    power_strength  power_long_shots  mentality_aggression  \
# 0              60                88                    48
# 1              79                93                    63
# 4              83                25                    29
# 5              76                82                    78
# 2              65                90                    47
#
#    mentality_interceptions  mentality_positioning  mentality_vision  \
# 0                       22                     92                90
# 1                       24                     91                81
# 4                       30                     25                20
# 5                       41                     88                84
# 2                       39                     89                84
#
#    mentality_penalties  mentality_composure  defending_marking  \
# 0                   76                  NaN                 25
# 1                   85                  NaN                 22
# 4                   37                  NaN                 25
# 5                   85                  NaN                 30
# 2                   80                  NaN                 29
#
#    defending_standing_tackle  defending_sliding_tackle  goalkeeping_diving  \
# 0                         21                        20                   6
# 1                         31                        23                   7
# 4                         25                        25                  87
# 5                         45                        38                  27
# 2                         26                        26                  10
#
#    goalkeeping_handling  goalkeeping_kicking  goalkeeping_positioning  \
# 0                    11                   15                       14
# 1                    11                   15                       14
# 4                    85                   92                       90
# 5                    25                   31                       33
# 2                     8                   11                        5
#
#    goalkeeping_reflexes    ls    st    rs    lw    lf    cf    rf    rw   lam  \
# 0                     8  89+3  89+3  89+3  92+3  90+3  90+3  90+3  92+3  92+3
# 1                    11  91+1  91+1  91+1  89+3  91+1  91+1  91+1  89+3  89+3
# 4                    86  38+3  38+3  38+3  36+3  37+3  37+3  37+3  36+3  36+3
# 5                    37  86+3  86+3  86+3  85+3  86+3  86+3  86+3  85+3  87+3
# 2                    15  84+3  84+3  84+3  88+2  87+3  87+3  87+3  88+2  88+2
#
#     cam   ram    lm   lcm    cm   rcm    rm   lwb   ldm   cdm   rdm   rwb  \
# 0  92+3  92+3  90+3  79+3  79+3  79+3  90+3  62+3  62+3  62+3  62+3  62+3
# 1  89+3  89+3  87+3  77+3  77+3  77+3  87+3  63+3  63+3  63+3  63+3  63+3
# 4  36+3  36+3  38+3  36+3  36+3  36+3  38+3  36+3  40+3  40+3  40+3  36+3
# 5  87+3  87+3  84+3  77+3  77+3  77+3  84+3  67+3  67+3  67+3  67+3  67+3
# 2  88+2  88+2  87+3  78+3  78+3  78+3  87+3  64+3  64+3  64+3  64+3  64+3
#
#      lb   lcb    cb   rcb    rb rank_calc
# 0  54+3  45+3  45+3  45+3  54+3   16155.0
# 1  57+3  52+3  52+3  52+3  57+3   16154.0
# 4  36+3  38+3  38+3  38+3  36+3   16153.0
# 5  62+3  57+3  57+3  57+3  62+3   16150.0
# 2  55+3  46+3  46+3  46+3  55+3   16152.0
#
# [5 rows x 108 columns]

# %% [markdown]
# In the same way, I can make a subset of the dataset with the 5 smallest wage_eur data:

# %%
data.nsmallest(5, "wage_eur")
# Out:
#      sofifa_id                                         player_url  \
# 151     209119  https://sofifa.com/player/209119/francisco-amo...
# 283     178007  https://sofifa.com/player/178007/miguel-luis-p...
# 289     209097  https://sofifa.com/player/209097/omar-luis-car...
# 424     209102  https://sofifa.com/player/209102/marco-aurelio...
# 456     178416  https://sofifa.com/player/178416/jeremain-lens...
#
#          short_name  random_col                 long_name  age        dob  \
# 151  F. Amorebielsa          92     Francisco Amorebielsa   28 1985-10-27
# 283   Miguel Veloso          93  Miguel Luís Pinto Veloso   28 1986-05-11
# 289      O. Cardosa          42         Omar Luis Cardosa   30 1983-11-26
# 424   M. Etxeberría          94  Marco Aurelio Etxeberría   27 1987-04-11
# 456         J. Lens          24             Jeremain Lens   26 1987-11-24
#
#      height_cm  weight_kg  nationality club_name league_name  league_rank  \
# 151        194         83    Venezuela       NaN         NaN          NaN
# 283        180         78     Portugal       NaN         NaN          NaN
# 289        188         84     Paraguay       NaN         NaN          NaN
# 424        183         77     Paraguay       NaN         NaN          NaN
# 456        178         73  Netherlands       NaN         NaN          NaN
#
#      overall  potential  value_eur  wage_eur player_positions preferred_foot  \
# 151       82         82          0         0           CB, LB           Left
# 283       80         80          0         0          CDM, CM           Left
# 289       80         80          0         0               ST           Left
# 424       78         83          0         0           LM, LB           Left
# 456       78         80          0         0           RW, ST          Right
#
#      international_reputation  weak_foot  skill_moves      work_rate  \
# 151                         3          3            2    Medium/High
# 283                         3          4            2  Medium/Medium
# 289                         3          2            2  Medium/Medium
# 424                         1          4            4  Medium/Medium
# 456                         2          4            4     Medium/Low
#
#     body_type real_face  release_clause_eur  \
# 151      Lean        No                 NaN
# 283    Normal        No                 NaN
# 289    Normal        No                 NaN
# 424      Lean        No                 NaN
# 456    Normal        No                 NaN
#
#                                            player_tags team_position  \
# 151                          #Aerial Threat, #Strength           NaN
# 283                                                NaN           NaN
# 289  #Poacher, #Distance Shooter, #FK Specialist, #...           NaN
# 424                                                NaN           NaN
# 456                                                NaN           NaN
#
#      team_jersey_number loaned_from joined  contract_valid_until  \
# 151                 NaN         NaN    NaT                   NaN
# 283                 NaN         NaN    NaT                   NaN
# 289                 NaN         NaN    NaT                   NaN
# 424                 NaN         NaN    NaT                   NaN
# 456                 NaN         NaN    NaT                   NaN
#
#     nation_position  nation_jersey_number  pace  shooting  passing  dribbling  \
# 151             LCB                   3.0  53.0      47.0     56.0       50.0
# 283             LCM                   4.0  68.0      72.0     82.0       78.0
# 289             SUB                  10.0  42.0      87.0     72.0       69.0
# 424              LM                  17.0  88.0      67.0     75.0       80.0
# 456             SUB                  17.0  86.0      75.0     70.0       81.0
#
#      defending  physic  gk_diving  gk_handling  gk_kicking  gk_reflexes  \
# 151       81.0    85.0        NaN          NaN         NaN          NaN
# 283       75.0    74.0        NaN          NaN         NaN          NaN
# 289       36.0    71.0        NaN          NaN         NaN          NaN
# 424       65.0    70.0        NaN          NaN         NaN          NaN
# 456       31.0    71.0        NaN          NaN         NaN          NaN
#
#      gk_speed  gk_positioning  \
# 151       NaN             NaN
# 283       NaN             NaN
# 289       NaN             NaN
# 424       NaN             NaN
# 456       NaN             NaN
#
#                                          player_traits  attacking_crossing  \
# 151              Injury Prone, Dives Into Tackles (AI)                  48
# 283             Long Passer (AI), Long Shot Taker (AI)                  76
# 289  Power Free-Kick, Avoids Using Weaker Foot, Lon...                  67
# 424                            Technical Dribbler (AI)                  78
# 456  Beat Offside Trap, Speed Dribbler (AI), Chip S...                  75
#
#      attacking_finishing  attacking_heading_accuracy  ...  \
# 151                   38                          79  ...
# 283                   64                          66  ...
# 289                   87                          83  ...
# 424                   62                          62  ...
# 456                   75                          62  ...
#
#      movement_sprint_speed  movement_agility  movement_reactions  \
# 151                     53                44                  73
# 283                     67                73                  78
# 289                     51                50                  79
# 424                     90                82                  77
# 456                     88                78                  82
#
#      movement_balance  power_shot_power  power_jumping  power_stamina  \
# 151                43                69             68             68
# 283                75                82             74             75
# 289                31                90             34             53
# 424                74                70             62             76
# 456                82                79             75             74
#
#      power_strength  power_long_shots  mentality_aggression  \
# 151              91                41                    93
# 283              76                83                    70
# 289              84                86                    72
# 424              65                72                    79
# 456              76                74                    52
#
#      mentality_interceptions  mentality_positioning  mentality_vision  \
# 151                       77                     49                59
# 283                       83                     70                83
# 289                       29                     87                75
# 424                       66                     74                73
# 456                       22                     68                72
#
#      mentality_penalties  mentality_composure  defending_marking  \
# 151                   56                  NaN                 81
# 283                   72                  NaN                 70
# 289                   84                  NaN                 30
# 424                   71                  NaN                 60
# 456                   66                  NaN                 21
#
#      defending_standing_tackle  defending_sliding_tackle  goalkeeping_diving  \
# 151                         84                        83                  15
# 283                         78                        75                  15
# 289                         32                        34                  12
# 424                         70                        70                  12
# 456                         38                        31                  15
#
#      goalkeeping_handling  goalkeeping_kicking  goalkeeping_positioning  \
# 151                     5                   12                        6
# 283                     6                    8                        7
# 289                     7                    6                       14
# 424                    12                   15                       13
# 456                    15                   13                       14
#
#      goalkeeping_reflexes    ls    st    rs    lw    lf    cf    rf    rw  \
# 151                    12  56+1  56+1  56+1  53+1  55+1  55+1  55+1  53+1
# 283                    14  73+1  73+1  73+1  76+1  76+1  76+1  76+1  76+1
# 289                    11  79+1  79+1  79+1  70+1  78+1  78+1  78+1  70+1
# 424                     6  72+0  72+0  72+0  78+0  74+0  74+0  74+0  78+0
# 456                     5  76+0  76+0  76+0  78+0  76+0  76+0  76+0  78+0
#
#       lam   cam   ram    lm   lcm    cm   rcm    rm   lwb   ldm   cdm   rdm  \
# 151  56+1  56+1  56+1  55+1  61+1  61+1  61+1  55+1  68+1  72+1  72+1  72+1
# 283  78+1  78+1  78+1  78+1  80+0  80+0  80+0  78+1  77+1  79+1  79+1  79+1
# 289  75+1  75+1  75+1  68+1  68+1  68+1  68+1  68+1  53+1  58+1  58+1  58+1
# 424  76+0  76+0  76+0  78+0  74+0  74+0  74+0  78+0  74+0  71+0  71+0  71+0
# 456  76+0  76+0  76+0  75+0  66+0  66+0  66+0  75+0  58+0  56+0  56+0  56+0
#
#       rwb    lb   lcb    cb   rcb    rb rank_calc
# 151  68+1  74+1  81+1  81+1  81+1  74+1     156.0
# 283  77+1  76+1  75+1  75+1  75+1  76+1     156.0
# 289  53+1  51+1  52+1  52+1  52+1  51+1     156.0
# 424  74+0  72+0  68+0  68+0  68+0  72+0     156.0
# 456  58+0  52+0  48+0  48+0  48+0  52+0     156.0
#
# [5 rows x 108 columns]

# %% [markdown]
# df.explode()
# Explode can be useful when you have a list of data in some rows. It is hard to analyze, visualize or perform some predictive modeling when you have integers in some columns and lists in some columns. Explode helps to break down those lists. For example, look at this DataFrame:

# %%
data1 = pd.DataFrame({"city": ['A', 'B', 'C'],
                   "day1": [22, 25, 21],
                   'day2':[31, 12, 67],
                   'day3': [27, 20, 15],
                   'day4': [34, 37, [41, 45, 67, 90, 21]],
                   'day5': [23, 54, 36]})
data1
# Out:
#   city  day1  day2  day3                  day4  day5
# 0    A    22    31    27                    34    23
# 1    B    25    12    20                    37    54
# 2    C    21    67    15  [41, 45, 67, 90, 21]    36
